# %%
import numpy as np
import pandas as pd
import pickle
import warnings
warnings.filterwarnings('ignore')

import os
import sys
np.set_printoptions(threshold=sys.maxsize)

from time import time
import spacy
nlp = spacy.load("en_core_web_sm")


from utils import preprocess, preprocess1, pd_explode, sentiment
from stopwords import get_stopwords
STOPWORDS = get_stopwords()

t=time()

# READ IN REVIEWS
print('Loading Dataset...')
reviews = pd.read_csv('data/amazon_reviews_us_Electronics_v1_00.tsv', sep='\t', error_bad_lines=False)
print('Dataset Loaded: ', round(time()-t,2),'s')
print("Full Size:", reviews.shape[0], ' reviews')
reviews.head()

print('Cleaning dataframe...')
# DROP USELESS ROWS
E_simple = reviews[['product_id', 'product_title', 'star_rating', 'review_headline','review_body',
                    'review_id', 'review_date']]

# DROP NULLS
print('Pre-.dropna size: ', E_simple.shape)
E_simple.dropna(inplace=True)
print("Post-.dropna size:", E_simple.shape)

# RENAME COLUMNS FOR CONVENIENCE
E_simple.rename(columns={'star_rating':'stars'}, inplace=True)
print('Clean: ', round(time()-t,2),'s')

# DROP SHORT REVIEWS, see EDA below
E_simple = E_simple[E_simple.review_body.apply(lambda x: len(x.split())>4)]
print('Dropped short reviews: ', round(time()-t,2),'s')
print('Reviews remaining: ', E_simple.shape[0])
E_simple.to_json('data/E_clean.json')

# #SAVE
# print('Saving clean dataframe...')
# # E_simple.to_json('data/Electronics_cleaned.json')
# print('Saved: ', round(time()-t,2),'s')

total_products = E_simple.product_id.unique().shape[0]
count100_500 = E_simple.groupby('product_id').count().iloc[:,0].between(100,500).sum()
total_reviews = E_simple.shape[0]
short_reviews = E_simple[E_simple.review_body.apply(lambda x: len(x.split())<5)].shape[0]
print('# Total products: ', total_products)
print('# Total products with 100-500 reviews: ', count100_500)
print('# Total reviews: ', total_reviews)

# print('# Total reviews w/ <5 words: ', short_reviews)
print(round(time()-t,2),'s')
print()

# BREAK INTO SENTENCES
print('Breaking into sentences...')
E_sentences = E_simple
E_sentences['sentences'] = E_simple.review_body.apply(lambda rev: [sent.text for sent in nlp(rev)])
E_sentences.drop('review_body', axis=1, inplace =True)
E_sentences.to_json('data/E_sentences.json')
print('Done', round(time()-t,2),'s')

# APPLY SENTIMENT ANALYSIS
#----------->>> GO BACK AND ADJUST POLARITY SCORE
# GET polarity of each sentence #let stars skew polarity
print('Analyzing sentiment...')
E_sentences['sentence_polarity'] = E_sentences.apply(lambda row: sentiment(row.sentence, row.stars), axis=1)
print('Done', round(time()-t,2),'s')
E_sentences.to_json('data/E_sentences.json')

# #.........VALIDATION - WHAT REVIEWS ARE IN 123 STARS AND POSTIVE? 45 STARS AND NEGATIVE? NEUTRAL?
# #Negative 
# stars12 = one_sentences[(one_sentences.stars<3) & (one_sentences.sentence_polarity>0)]
# stars12

# #Positive
# stars45 = one_sentences[(one_sentences.stars>3) & (one_sentences.sentence_polarity<0)]
# stars45

# #Neutral
# stars4 = one_sentences[(one_sentences.stars==4) & (one_sentences.sentence_polarity==0)]
# stars4
# # ^^^^^^^^^^VALIDATION

# DROP ROWS


# TOKENIZE TEXT
print('Tokenizing Text. Grab a coffee. This may take a while....')
processed_corpus, bigrammer, trigrammer = preprocess(E_sentences.review_body, stopwords=STOPWORDS, max_gram=3)
print('Tokenized Text: ', round(time()-t,2),'s')

print('Saving Data & Trained Tokenizer....')
E_sentences['tokened'] = processed_corpus
E_sentences.to_json('data/Electronics_tokenized_2.json')

with open('models/bigrammer.pkl', 'wb') as f:
    pickle.dump(bigrammer,f)
with open('models/trigrammer.pkl', 'wb') as f:
    pickle.dump(trigrammer,f)
    
    #//////////// new code to get number of sentences
# SAVE A SMALLER SET FOR PRODUCTS THAT HAVE BETWEEN 20 AND 1000 REVIEWS FOR DEMO
review_counts = E_sentence.groupby('product_id').count().iloc[:,0]
products20_1000 = list(review_counts[review_counts.between(20,1000)].index)
E_small = E_sentences[E_sentences.product_id.isin(products20_1000)]
E_small.to_json('data/Electronics_tokened_20to1000_2.json')
    
print('Saved', round(time()-t,2),'s')
print('Please run vectorize.py next :)')


-------- EDA/VALIDATION --------#
## Electronics DF Validation 
> lost ~100 rows of 3,090,877 <br>
> all review_id are unique, no duplicates <br>
> start rating ranges from 1 to 5 <br>
> US marketplace only<br>
> All in Electronic category<br>
> No '' in product_title, review_headline, review_body <br>
> Reviews from June 9 1999 to Aug 31 2015<br>
> 2,315,686 4-5 stars<br>
>  775,191 1-3 stars<br>
> Somehow reduced file size down to 188.7MB from 377.3MB, but actual filesize 1.85GB


## Data EDA
### Prior to dropping short reviews
<br> num Total products:  (185766,)
<br> num Total products with 100-500 reviews:  4778
<br> num Total reviews:  3090877
<br> num Total reviews w/ <5 words:  254733
<br> reviews start being useful around 5 words long

### Post dropping short reviews
> <br> num Total products:  (176878,)
<br> num Total products with 100-500 meaningful reviews:  4406
<br> num Total reviews:  2836144
<br> num Total reviews w/ <5 words:  0
# Out:
# Loading Dataset...
# b'Skipping line 9076: expected 15 fields, saw 22\nSkipping line 19256: expected 15 fields, saw 22\nSkipping line 24313: expected 15 fields, saw 22\nSkipping line 47211: expected 15 fields, saw 22\nSkipping line 54295: expected 15 fields, saw 22\nSkipping line 56641: expected 15 fields, saw 22\nSkipping line 63067: expected 15 fields, saw 22\n'
# b'Skipping line 93796: expected 15 fields, saw 22\n'
# b'Skipping line 132806: expected 15 fields, saw 22\nSkipping line 164631: expected 15 fields, saw 22\nSkipping line 167019: expected 15 fields, saw 22\nSkipping line 167212: expected 15 fields, saw 22\n'
# b'Skipping line 198103: expected 15 fields, saw 22\nSkipping line 199191: expected 15 fields, saw 22\nSkipping line 202841: expected 15 fields, saw 22\nSkipping line 218228: expected 15 fields, saw 22\nSkipping line 235900: expected 15 fields, saw 22\n'
# b'Skipping line 277761: expected 15 fields, saw 22\nSkipping line 304582: expected 15 fields, saw 22\nSkipping line 312029: expected 15 fields, saw 22\n'
# b'Skipping line 343692: expected 15 fields, saw 22\nSkipping line 352291: expected 15 fields, saw 22\nSkipping line 363414: expected 15 fields, saw 22\nSkipping line 378087: expected 15 fields, saw 22\nSkipping line 378720: expected 15 fields, saw 22\nSkipping line 378760: expected 15 fields, saw 22\nSkipping line 379336: expected 15 fields, saw 22\n'
# b'Skipping line 402682: expected 15 fields, saw 22\n'
# b'Skipping line 466560: expected 15 fields, saw 22\nSkipping line 486823: expected 15 fields, saw 22\nSkipping line 489036: expected 15 fields, saw 22\nSkipping line 496148: expected 15 fields, saw 22\nSkipping line 522330: expected 15 fields, saw 22\n'
# b'Skipping line 552961: expected 15 fields, saw 22\nSkipping line 577388: expected 15 fields, saw 22\nSkipping line 582182: expected 15 fields, saw 22\n'
# b'Skipping line 590653: expected 15 fields, saw 22\nSkipping line 608846: expected 15 fields, saw 22\nSkipping line 615442: expected 15 fields, saw 22\nSkipping line 645607: expected 15 fields, saw 22\nSkipping line 654323: expected 15 fields, saw 22\n'
# b'Skipping line 714935: expected 15 fields, saw 22\n'
# b'Skipping line 749608: expected 15 fields, saw 22\nSkipping line 753868: expected 15 fields, saw 22\nSkipping line 762504: expected 15 fields, saw 22\nSkipping line 771706: expected 15 fields, saw 22\nSkipping line 773376: expected 15 fields, saw 22\n'
# b'Skipping line 792407: expected 15 fields, saw 22\nSkipping line 793933: expected 15 fields, saw 22\nSkipping line 813269: expected 15 fields, saw 22\nSkipping line 835491: expected 15 fields, saw 22\nSkipping line 841176: expected 15 fields, saw 22\nSkipping line 844604: expected 15 fields, saw 22\n'
# b'Skipping line 857952: expected 15 fields, saw 22\nSkipping line 859568: expected 15 fields, saw 22\nSkipping line 860789: expected 15 fields, saw 22\nSkipping line 863093: expected 15 fields, saw 22\nSkipping line 881608: expected 15 fields, saw 22\nSkipping line 891157: expected 15 fields, saw 22\nSkipping line 893799: expected 15 fields, saw 22\nSkipping line 906438: expected 15 fields, saw 22\nSkipping line 914856: expected 15 fields, saw 22\n'
# b'Skipping line 940736: expected 15 fields, saw 22\nSkipping line 965818: expected 15 fields, saw 22\n'
# b'Skipping line 993840: expected 15 fields, saw 22\nSkipping line 1019036: expected 15 fields, saw 22\nSkipping line 1019205: expected 15 fields, saw 22\n'
# b'Skipping line 1058122: expected 15 fields, saw 22\n'
# b'Skipping line 1144887: expected 15 fields, saw 22\nSkipping line 1147255: expected 15 fields, saw 22\nSkipping line 1164497: expected 15 fields, saw 22\nSkipping line 1166930: expected 15 fields, saw 22\n'
# b'Skipping line 1218319: expected 15 fields, saw 22\nSkipping line 1232868: expected 15 fields, saw 22\n'
# b'Skipping line 1307335: expected 15 fields, saw 22\n'
# b'Skipping line 1621422: expected 15 fields, saw 22\n'
# b'Skipping line 1857720: expected 15 fields, saw 22\n'
# b'Skipping line 1935753: expected 15 fields, saw 22\n'
# b'Skipping line 1988449: expected 15 fields, saw 22\n'
# Dataset Loaded:  35.12 s
# Full Size: 3091024  reviews
# Cleaning dataframe...
# Pre-.dropna size:  (3091024, 7)
# Post-.dropna size: (3090877, 7)
# Clean:  38.48 s
# Dropped short reviews:  52.55 s
# Reviews remaining:  2836144
# # Total products:  176878
# # Total products with 100-500 reviews:  4406
# # Total reviews:  2836144
# 79.12 s
#
# Breaking into sentences...

# %% [markdown]
# ## EDA - all ngrams

# %%
E_simple = pd.read_json('data/D11Electronics_tokenized.json')

# %%
ngrams = []
for review in processed_corpus:
    for tok in review:
        if '_' in tok:
            ngrams.append(tok)
            
len(np.array(list(set(ngrams)))), np.array(list(set(ngrams)))
# Out:
# (1710, array(['pd_cp_p_', 'isolation_____', 'woot_deals', 'just___',
#         'dave_brubeck', 'afqjcnghd_s', 'xw_nas', 'blue_ray', 'races_',
#         'olp_cg_pop', 'dihle_lvsve', 'fcc_gov', 'v_moda', 'w___',
#         'chaper_', 'dell_latitude', 't___t', 'mech_mods', 'dd_wrt',
#         'cm_cr_pr_perm', 'strain_relief', 'sr_ph_', 'braven_lux',
#         'buyers_remorse', 'f_ucking', 'brand_', 'nb_sb_noss', 'purple__',
#         'vw_jetta', 'half_', 'b_', 'boston_acoustics', 'andrew_jones',
#         'ntsc_m', 'southern_california', 'avr_power', 'atonline_com',
#         'player_it', 'pp_play', 'iapp_controlapp', 'da_ned', 'bronco_',
#         'extension_cords', 'pct_amp', 'cat_id', 'x_xywksbeiqa', 'fine_',
#         'i______', 'lvxaohg_', 'bare_bone', 'you_', 'horror_stories',
#         'jury_rig', 'bee_dac', 'rome_florence', 'shopping_help', 'girls_',
#         'soundmatters_foxl', 'rp_hje', 'adrian_landeira', 'cricket_post',
#         'u_u', 'rockford_fosgate', 'list_satish', 'page_headphones',
#         'up_directions', 'den_n', 's__t', 'superlux_hd', 'glenn_miller',
#         'au_ction', 'ct_bw', 'sewell_deadbolt', 'aux_in', 'feat_diplo',
#         'geforce_gtx', 'likely_', 'vdr_m', 'zombie_apocalypse',
#         'button_cell', 'aether_cone', 'i_phones', 'smart_parts_usa',
#         'memorex___drive', 'hello_kitty', 'murphy_law', 'hind_sight',
#         'chpt_', 'estoy_muy', 'pd_cp_mov_', 'san_diego', 'todo_bien',
#         'hdmi_drive', 'order___nice', 'tivo_roamio', 'zg_bs_', 'c_ddvds',
#         'kickstarter_backer', 'white_thank', 'g_sensor', 'oss_product',
#         'kimber_kable', 'senior_citizen', 'bcb_', 'pd_cp_misc_',
#         'fred_meyer', 'audible_alex', 'aogw_', 'este_producto',
#         'harmon_kardon', 'pd_sbs_sg_', 'sega_genesis', 'mp_', 'stm_',
#         'better_bought', 'tractorbeam_u', 'sw_', 'ok_sp', 'eric_clapton',
#         'phoenix_az', 'ac_sx', 'hk_aura', 'features_', 'tenergy_centura',
#         's_cked', 'warehouse_deals', 'how_', 'powerpoint_presentations',
#         'adversely_affect', 'mini_book', 'tsx_', 'airmobi_fcc',
#         'steelseries_siberia', 'gno_cart_title_', 'bic_america',
#         'memories_on_tv', 'u_hooks', 'cr_ppy', 'spk_velo', 'carnegie_hall',
#         'product_detail', 'world_', 'washington_dc', 'str_da',
#         'pink_floyd', 'green_rtn', 'havana_cuba', 'vbus_present', 'rp_sma',
#         'aag_m_pw_dp', 'n___', 'fwd_rev', 'particle_board', 'u_',
#         'intensity_shuttle', 'as_li_tl', 'vhs_c', 'text__', 'avr_change',
#         'alpatronix_ax', 'ie_utf', 'v_v', 'harman_kardon', 'lc_le',
#         'fallroman_ii', 'wing_nuts', 'nomad_iic', 'pf_rd_r', 'but__',
#         'x_x', 'output_', 'ni_mh', 'shop_online', 'title_', 'router_na',
#         'symphonize_nrg', 'c_name', 'eaeaea_', 'charges_',
#         'sleepless_nights', 'rip_off', 'ref_', 'camden_square', 'gen_pur',
#         'billy_vandory', 'hd_ma', 'asset_id', 'jacksonville_fl',
#         'power_supply', 'brightside_sc', 'cm_cd_ql_tlc_al', 'tv_dvd',
#         'buffer_get_ret', 'infinite_wisdom', 'q_', 'm_series',
#         'constructive_criticism', 'highway_robbery', 'however_',
#         'airzone_macaddr', 'clips___', 'authorize_dealer', 'multi_voltage',
#         'all_service', 'thoughts__', 'hdmi_control', 'bone_conduction',
#         'dp_spec_v', 'he__l', 'th_quarter_', 'maker_period', 'sylvie_rdlg',
#         'trails_', 'thermal_paste', 'pd_sim_cps_', 'bd_re',
#         'dp_ob_title_ce', 'hdmi_safe', 'ti____', 'it_', 'cough_cough',
#         'gel_caps', 'boombot_rex', 'im_no_angel', 'tv_protector',
#         'winegard_lna', 'pd_sim_sbs_pc_', 'mini_sd', 'ac_sy',
#         'microsoft_user', 'gordon_brothers', 'your_dir', 'xonar_dg',
#         'mpu_', 'box_power', 'lo_recomiendo', 'son_kdf', 'c_amazon',
#         'ekhsibm_', 's__k', 'y_k', 'shovel_snow', 'rj_tech', 'hdmi_switch',
#         'a__', 'rene_roman', 'airmobi_xxxx', 'revision_', 'g_grunfeld',
#         'mdr_ed', 'muy_bien', 'muchas_gracias', 'pd_bbs_', 'pd_sim_pc_',
#         'hdmi_hdmi', 'pd_ys_iyr_img', 'in_line', 'marcosr_', 'daughte_',
#         'xycsuep_j', 'a_id', 'cm_cr_dp_title', 'cpu_fan', 'tv_wall_mounts',
#         'interphone_', 'context_', 'chapter_', 'music__', 'shi_',
#         'awesome_sound', 'time_', 'scuba_dive', 'r_', 'nay_sayers',
#         'tecsun_pl', 'cambridge_soundworks', 'meaning_don', 'asus_xonar',
#         'cush_fin', 'athena_ivoice', 'buenas_condiciones',
#         'znvm_pcpatch_la', 'jelly_bean', 'wa____k',
#         'public_transportation', 'tom_fox', 'soundmate_', 'in_law',
#         'cm_cr_rdp_perm', 'plus_plus', 'hair_dryers', 'micro_sd',
#         'mohu_leaf', 'hilly_terrain', 'sn_v', 'pd_sbs_a_',
#         'elliptical_trainer', 'asus_zenbook', 'max_mart', 'xx_psrp',
#         'audio_ts', 'ntsc_m_j', 'yo_ii_img', 'h_pas', 'xonar_u', 'wesv_lp',
#         'dvd_writers', 'period___', 'tom_tom', 'sr_ph', 'hd_dvr',
#         'trans_atlantic', 'son_replacement', 'rm_vl', 'dunu_dn',
#         'smoke_detectors', 'vault_ceilings', 'mdr_', 'properly_',
#         'c____guys', 'sansa_m', 'dave_matthews', 'notes___',
#         'irobot_roomba', 'guy_', 'jia_george', 'x___', 'f__', 'llego_en',
#         'v_o_r', 'self_destruct', 'cable_type', 'pci_atsc_hybrid',
#         'ali_julia', 'plug_in', 'd_re', 'manual_oarno', 'tennis_ball',
#         'blu_ray', 'ear_buds', 'four_hundred', 'pixie_willner', 'en_us',
#         'dm_mu_dp_trk', 'blue_kanga', 'a_', 'd_', 'utm_campaign',
#         'nec_optiarc', 'trrs_standards', 'ಠ_ಠ', 'db_hp', 'crackberry_com',
#         'verizon_fios', 'dumas_mc', 'x_update_xxx', 'vcc_mcu', 'y_',
#         'llego_tiempo', 'bi_wire', 'recording_', 'category_id',
#         'alt_delete', 'yht_bl', 'kindle_', 'vice_versa', 'flypage_sc',
#         'arduino_uno', 'motherf___', 'as______', 'oss_t', 'ifox_creations',
#         'nad_viso', 'hifimediy_sabre', 'f_', 'htr_', 'sc_', 'h_d_t_v',
#         's____', 'dcr_dvd', 'max_value', 'powerdvd_', 'debut_carbon',
#         'slippery_sleeve', 'p__s', 'knick_knacks', 'qmffmuet_o',
#         'urbanite_xl', 'b___', 'ciem_review', 'dgmbrc_',
#         'structural_integrity', 'fault_', 'dolby_truehd', 'fragile_',
#         'pal_b', 'clam_shell', 'cathedral_ceilings', 'cd_r', 'dst_g',
#         'plantronics_backbeat', 'razr_maxx', 'effo_t', 'portta_pet',
#         'fbcpudu_qgy', 'canon_eos', 'nuforce_udac', 'rionitrusflash_',
#         'g_d', 'sc_hc', 'sa_', 'roger_russell', 'dozen_', 'twister_b',
#         'svs_pb', 'epson_artisan', 'sd_baja', 'pd_cp_pc_', 'pd_sim_hi_',
#         'comma___', 'p_dp_', 'completely_', 'l___', 'suc_', 'pd_bxgy_',
#         'mb_data', 'nknbekc_e', 'trans_pacific', 'cyber_acoustics',
#         'co_worker', 'liquidcristal_i', 'vpl_hw', 'cat_meow',
#         'portland_oregon', 'soundbot_sb', 'ni_cad', 'pd_sim_sg_',
#         'raleigh_nc', 'mipow_boomax', 'cm_sw_r_awd_rrw',
#         'otterbox_defender', 'spoofed_ans', 'neodymium_magnets',
#         'ge_superadio', 'm_____r', 'line_', 'pa_systems', 'def_tech',
#         'cameo_artists', 'bruce_springsteen', 'content_', 'pd_cp_e_',
#         'nvidia_gtx', 'braven_brv', 'red_', 'icf_s', 'spdif_out',
#         'as_sl_pc_ss_til', 'link_', 'co_workers', 'steve_is',
#         'usrp_interfaces', 'composite_video', 'rice_cooker', 'cp_pfclcd',
#         'pd_vtp_e_', 'fix_the_knob', 'dvi_d', 'overscan_left',
#         'limestone_lenny', 'buyer_remorse', 'basketball_court', 'bk_shark',
#         'providence_ri', 'bq_cc', 'foo_input_sacd', 'oh_o', 'd_skins',
#         'component_video', 'a__ed', 'region_id', 'ma__', 'mdrxb_ap',
#         'gpio_in_pin', 'pf_rd_m', 'bo_e', 'are_', 'bob_marley',
#         'hair_straightener', 'dvi_adapter', 'at_', 'd_ita', 'rxyxgo_pmvs',
#         'this__', 'front_back', 'cm_cr_dp_cmt', 'cm_sw_r_tw_acp', 'ip_d',
#         'p_', 'david_underland', 'start_up', 'ehthfbmya_g', 'ml_ipod',
#         'hall_mmf', 'pipe_organ', 'donald_', 'pd_rhf_cr_s_cp_',
#         'ferrite_core', 'slimx_imp', 'intel_nuc', 'http_amzn',
#         'elephants_print', 'b__t', 'e___', 'bad_', 'j_hilbert', 'q_q',
#         'maha_mh', 'college_student', 'cp_id', 's_video',
#         'rocket_scientist', 'lp_', 'flathead_screwdriver', 'cs_id',
#         'rc_keymaps', 'r_dl', 'mike_helms', 'one_battery', 'e_bikes',
#         'lame_ecn', 'dsp_corrections', 'radar_detector', 'boot_delay',
#         'jaybird_bluebud', 'nad_bee', 'pe_', 'play_', 'mediasonic_hw',
#         'ath_anc', 'pd_cp_hi_', 'm_f', 'product_im', 'wl_it_dp_o_pc',
#         'prospective_buyers', 'happy_sellers', 'voltage_divider', 'h_ll',
#         'emotiva_xda', 'pd_ecc_rvi_', 'iomega_hipzip', 'sp_c',
#         'fta_express', 'iaudio_', 'conrad_p', 'unite_kingdom', 'jay_bird',
#         'voipad_', 'rtl_tcp', 'schiit_magni', 'so_', 'jphhq__rk',
#         'ambiance_', 'holy_cow', 'brightech_brightplay', 'annotation_',
#         'onkyo_usa', 'words___', 'alcohol_', 'products_id', 'inch_',
#         'o_oa', 'p___ks', 'bang_olufsen', 'b_at', 'cp_avrlcd',
#         'repeat_mode', 'yyy_seq', 'sr_nr_p_', 'bit_w',
#         'blackberry_playbook', 'curl_iron', 'microwave_ovens',
#         'medical_transcription', 'cfb_at_prodpg', 'sr_', 'cable_',
#         'review____', 'tread_mill', 'easycap_d', 'ferrite_bead', 'med_',
#         'shut_off', 'x_boom', 'lawn_mower', 'synology_nas', 'h_uc',
#         'cyberpower_cpxxxpfclcd', 'whoo_hoo', 'upstate_ny', 'clueless_',
#         'bye_bye', 'boco_fw_wcb', 'all__', 'sine_wave', 'search_query',
#         'turtle_beach', 'very_good', 'max_fur_eng', 't_t',
#         'allman_brothers', 'north_carolina', 'slo_o_o_o_owly',
#         'sdbr_pcdrv_l', 'annotation_id', 'diagram_',
#         'instant_gratification', 'viera_tc', 'la_vie', 'any_better_job',
#         'c_', 'dlfb_data', 'worked_', 'snow_leopard', 'av_receiver',
#         'singer_songwriter', 'hours_', 'then_', 'beware_',
#         'infinity_primus', 'soundtouch_app', 're_chargeable',
#         'skull_crushers', 'mr_gt_mustang', 'passive_radiators', 'rtl_sdr',
#         'cd_itrr', 'ff_rew', 'f_cking', 'setup____', 'lame_enc', 'icf_mk',
#         'fenix_pd', 'pdu_', 'shared_assets', 'phone_', 'scr_wed', 's_air',
#         'vol_', 'lmr_', 'comments__this', 'dell_inspiron', 'p_qk',
#         'fiber_optic', 'clip_', 'restock_fee', 'rtl_', 'bach_toccata',
#         'rev_', 'my_song', 'rkelly_', 'reception_', 'l_v', 'dental_floss',
#         'artist_name', 'jds_labs', 'seve_al', 'y_tepdy', 'micros__t',
#         'neil_young', 'moda_crossfade', 'pt_ae', 'lithium_polymer',
#         'cirrus_logic', 'toyota_corolla', 'hp_rel_topic', 'headphone_pro',
#         'pre_paid', 'grossly_overstate', 'abt_bm', 'mdr_ex',
#         'faux_leather', 'aem_hbdo', 't_fwkrdbv', 'ping_pong', 'dvd_rw',
#         'south_africa', 'topic_id', 'et_pwifud', 'lithium_ion',
#         'lenovo_thinkpad', 'jd_', 'cons________', 'vid_', 'epson_ub',
#         'nu_force', 'if_tg', 'kailani_jordan', 'proven_choice',
#         'projector_', 'shshs___', 'wma_pro', 'leonard_bise',
#         'beyerdynamic_edt', 'kobo_aura', 'home_en', 'cd_da',
#         'ya_aw_oh_pii', 'accessories_tab', 'sony_wm', 'latex_gloves',
#         'rating_', 'nerve_wrack', 'saudi_arabia', 'timely_manner',
#         'pd_rate_rs', 'utm_term', 'tj_maxx', 'toyota_tacoma',
#         'howard_stern', 'slam_dunk', 'r____o', 'audio_input',
#         'isopropyl_alcohol', 'westone_um', 'htc_evo', 'jof_n',
#         'sega_saturn', 'hwcxjwz_lk', 'ss_cn', 't_', 'david_carlin',
#         'car_dvr', 'ws_ftp', 'edit_', 'south_carolina', 'dvd_',
#         'muy_bueno', 'media_universe', 'o__o', 'sony_dvd', 'psc_redirect',
#         'sound_rating', 'packing_inc', 'vh_', 'schiit_bifrost', 'rock_it',
#         'kio_ifp', 'ser_mac_zip', 'daft_punk', 'true_depth',
#         'dp_proddesc_', 'ypbpr_ansi', 'i_manual', 'allen_wrench',
#         'taotronics_tt', 'play_record', 'plwitua_lhzlku', 'cm_cr_wr_img',
#         'timely_manor', 'tablet_w', 'droid_razr', 'rf_', 'jason_m',
#         'rtl_adr', 'orion_', 'brooklyn_ny', 'co_ax', 'us_en',
#         'los_recomiendo', 'the_', 'rp_hc', 'layer_jump', 'airmobi_xxxxxx',
#         'smv_encode', 'sales_pitch', 'sort_by', 'srf_m', 'number_', 'sh__',
#         'syl_scr', 'formatter_', 'fh_lcr', 'muti_point', 'oontz_xl',
#         'acer_aspire', 'trs_connector', 'i_love_having', 'toyota_sienna',
#         'd_a_b', 'wal_', 'great_very', 'denon_avr', 'lazy_susan',
#         'ultra_sturdy', 'jurassic_park', 'tv_dvr', 'wal_mart',
#         'schiit_asgard', 'fb_defio', 'what_______', 'o_e', 'isolation__',
#         'plug_and_play', 'happy_', 'al_vendedor', 'mount_be',
#         'cyberpower_cp', 'b_buy', 'gopro_hero', 'west_coast', 'rertyiop_',
#         'video_ts', 'oss_rev', 'pd_sbs_hg_', 'low_', 'arlington_lv',
#         'overscan_bottom', 'sega_dreamcast', 'highres_', 'san_jose',
#         'hanni_buzz', 'model_search', 'mlopez_', 'in_ear', 'str_de',
#         'datasheets_pdf', 'utm_source', 'cons____', 'beyerdynamic_dt',
#         'aidozybq_', 'swiss_army', 'question_the', 'bc_rsatb',
#         'album_name', 'sammy_k', 'powerex_mh', 'stainless_steel',
#         'new_earbudi', 'quality___', 'https_www', 'ex_bc', 'private_ryan',
#         'wl_it_dp_o', 'gb_c', 'a_c', 'display_entry', 'sd_',
#         'louisville_ky', 'deadbolt_banana', 'bxyhwx_uhcc', 'photive_bth',
#         'these_', 'hdmi_', 'a___', 'download_start', 'chp_vr',
#         'wsp_message', 'i______i', 'p_egnant', 'h_hx_x', 'krk_rokit',
#         'b_x', 'v__v', 'pd_sxp_grid_i_', 'snaec_ag', 's__thouse',
#         'east_coast', 'cm_cr_dp_synop', 'docks_base', 'tennis_court',
#         'package_', 'mechanically_incline', 'cwhog_nlr', 'parrot_zik',
#         'yourself_', 'dpd_sim_sg_', 'frank_sinatra', 'razor_blade',
#         'noise_removal', 'woo_hoo', 'pros________', 'e_r', 'pf_rd_t',
#         'in_thy_light', 'nintendo_ds', 'gusto_mucho', 'petroleum_jelly',
#         'seeyqkz_a', 'passive_radiator', 'erpzb_vc',
#         'situational_awareness', 'pf_rd_p', 'jabra_revo', 'sub_woofer',
#         'utm_content', 'razer_kraken', 'dpe_', 'view_question', 'high_',
#         'tl_dr', 'att_uverse', 'p__k', 'h_t_c', 'basement_', 'music_lover',
#         'again_____more', 'evga_gtx', 'nose_pliers', 'diesel_vektr',
#         'nema_connector', 'persist_app', 'buen_producto', 'it_it',
#         'nba_finals', 'scotland_ace', 'yusuf_burke', 'mengo_aquacube',
#         'c_id', 'm_rec', 'works_', 'f___ed', 'delete_file',
#         'magick_karma_', 'powder_coat', 'dp_image_z_', 'celebrity_endorse',
#         'krazy_glue', 'pete_sake', 'hsb_', 'aune_t', 'yst_sw', 'go_to',
#         'pd_cp_vg_', 'viking_usa', 'barnes_noble', 'high_vhf',
#         'visa_versa', 'b_y', 'mikjcgq_', 'u_s_b', 'build_rating',
#         'emi_rfi', 'denon_e', 'product_name', 'fiber_optics',
#         'wl_mb_recs_', 'soap_operas', 'atf_title_', 'trinity_', 'wp_',
#         'cm_cd_asin_lnk', 'user_interfaces', 'headfi_org', 'p_ds',
#         'nokia_bh', 'mad_lynn', 'fallroman_i', 'xtrememac_tango', 'sh_t',
#         'bert_', 'b_o_l_s_e', 'backwards_', 'seconds_', 'screen_size',
#         'tii_', 'bs_lr', 'st_louis', 'com_wrapper', 'indv_k', 'am_fm',
#         'smsl_sa', 'dot_clean', 'foo_upnp', 'planar_magnetic', 'mp_s_a_',
#         'god_forbid', 'time_set', 'lh_ni_t', 'pd_rhf_p_t_', 'ear_bud',
#         'best_buy_outlet', 'psdc_', 'czech_republic', 're_order',
#         'digital_modes', 'da__', 'veriz_n', 'senior_citizens',
#         'cm_cr_pr_pb_t', 'wl_it_dp_o_pdt', 'device_size', 'f___',
#         'parrot_ziks', 'etekcity_roverbeats', 'b__s_', 'hdmi_mode',
#         'fl_flatwave', 'ntt_srch_drd_b', 'main_sr', 'ta_da',
#         'salvation_army', 'watchespn_com', 'gp_converter', 'b__se',
#         'pearl_jam', 'jewel_', 'speaker_wire', 'kinivo_bn',
#         'cm_wl_huc_item', 'update_', 'amd_radeon', 'ir_manual',
#         'trsvyxyuo_m', 'sabrent_a', 'nelson_cartier', 'dennis_aiken',
#         'sound_', 'mike_tina', 'lkdqyx_koem', 'rx_v', 'silly_p',
#         'mpow_freego', 'zombie_x', 'stcroix_man', 'eng_chi',
#         'cyber_monday', 'dvr_a', 'cm_sw_r_awd_rgt', 'qsg_s', 'd_release',
#         'trtyiuop_', 'b__', 'cm_cd_et_jump', 'x_', 'set_par', 'pet_peeve',
#         'm_audio', 'the_strokes', 'k_____', 'ser_linux_zip', 'pre_amp',
#         'w_price', 'h_ww', 'product_id', 'raspberry_pi', 'sam_club',
#         'czech_kid', 'xy_', 'veb_esgiekg', 'pa_', 'filemanager_', 'sti_gl',
#         'sams_club', 'isport_immersion', 'n_blqfq', 'ezcap_vista',
#         'national_geographic', 'pm_jess', 'buds______', 'looks_',
#         'com_frontpage', 'tv_', 'cigarette_lighter', 'injection_mold',
#         'willie_nelson', 'airport_express', 'reply_', 'dvd_r',
#         'max_fum_eng', 'version_', 'harbor_freight', 'i___', 'live_sound',
#         'soundlink_on', 'pre_out', 'd__che', 'h_d', 'clap_on', 'ima_adpcm',
#         'p_id', 'good_', 'line____', 'follow_up', 'music_on', 'neuf_',
#         'pd_cp_k_', 'pf_rd_s', 'product__i', 'rcfn_jdzuka', 'cm_cr_dp_pdp',
#         'taiyo_yuden', 'oregon_scientific', 'menagerie_print',
#         'the_connection', 'behave_erratically', 'whoop_', 'peanut_butter',
#         'a_e', 'red_phones', 'eq_mode', 'sr_st', 'archos_devices',
#         'installer_', 'cotton_swab', 'hl_', 'counter_strike',
#         'elechouse_cc', 'ultrasone_hfi', 'taylor_swift', 'roomba_roomba',
#         'up_great', 'major_league', 'santa_fe', 'lfqv_uya', 'weekend_',
#         'xvt_sv', 'rv_cl', 'riva_turbo', 'chris_himself', 'dx_c', 'rm_hla',
#         'thinksound_ts', 'c____', 'common_gwzx', 'dvds_cds', 'sh_ts',
#         'severe_thunderstorm', 'i_____', 'dvd_rom', 'pro_eb',
#         'symphonize_glxy', 'pig_tail', 'jeep_wrangler', 'swag_swag',
#         'os_id', 'bbp_s_iphone', 'supra_aural', 'nc_ztjkw', 'mt_wilson',
#         'molly_dog', 'base_sku', 'wharfedale_diamond', 'headphone_price',
#         'anxiously_await', 'song_renumber', 'srs_btx', 'clear_', 'cr_p',
#         'nes_snes', 'rapid_succession', 'buffer_get_int', 'blah_blah',
#         'brite_view', 'beersheb_books', 'jc_sounds', 'bi_amping',
#         'rd_generation', 'whatever_', 'znrg_mejhx', 'srs_wow',
#         'frequent_flier', 'crawl_', 'paosanhueza_', 'hdmi_which_one',
#         'itty_bitty', 'golf_cart', 'service_info', 'bgg_p',
#         'cm_cr_thx_pdp', 'nstc_m', 'grundig_satellit', 'gadget_guy',
#         'instructions_', 'guesst_t', 'pacific_northwest', 'blue_rtn',
#         'enabled_', 'overscan_top', 'docsis_system', 'rate_converter',
#         'laser_pointer', 'xiaomi_piston', 'aag_d_sh', 'winegard_flatwave',
#         'columbus_ohio', 'p_leftorright', 'photive_hydra', 'u_cja',
#         'entrega_fue', 'j__', 'lil_wayne', 'small_', 'foo_out_asio',
#         'ogg_vorbis', 'e_q', 'lyrics_sync', 'non_waterproof', 'earth_',
#         'm_rsemrok', 'speaker_', 'back_up', 'external_sd', 'prodfaq_',
#         'mdr_rf', 'active_pwr', 'altec_lansing', 'johnny_cash',
#         'pinguy_os_', 'com_content', 'exacto_knife', 'onecall_com',
#         'cm_cd_naredir', 'shoe_lace', 'vast_majority', 'contact_us',
#         'slight_', 'twist_vein', 'h_', 'http_www', 'gigacity_amn',
#         'wal___t', 'str_dg', 'f___ck', 'sirius_xm', 'kaito_ka',
#         'template_id', 'biddeal_co', 'manner_', 'ak_frost',
#         'microwave_oven', 'wms_ohs_product', 'r_sng', 'pid_', 'wi_fi',
#         'rnskm_', 'a_b', 'lepai_tripath', 'pr_', 'wosang_pro',
#         'nitecore_intellicharger', '흫_흫', 's___', 'xiaomi_pistons',
#         'goo_gl', 'android_n', 'sight_unseen', 'eng_', 'to_',
#         'danger_efest_', 'dji_phantom', 'on_', 'numeric_keypad',
#         'velodyne_vpulse', 'e_son', 'display_', 'trivial_', 'v___',
#         'heaven_forbid', 'hdmi_cable', 'a_rcr', 'j_mount',
#         'pd_bxgy_e_img_c', 'skull_candy', 'amp_and', 'speexrate_best',
#         'movie_', 'pd_bxgy_e_img_b', 'pd_ybh_', 'micca_mb', 'radio_usb_si',
#         'excelente_producto', 'pvc_pipe', 's_lots_of', 'honda_civic',
#         'lenovo_yoga', 'debbie_lee', 'cm_cr', 'soundcast_melody',
#         'product_info', 'techspec_index', 'src_vid', 'dr_dre',
#         'jose_ambriz', 'isolation___', 'zadig_v', 'swapnil_saloni',
#         'cd_quality', 'up____________', 'pinky_powers', 'mow_lawns',
#         'inkjet_printable', 'buddy_boy', 'pl_', 'tt_sk', 'las_vegas',
#         'fact_', 'bebzrig_pws', 'rhkdil_', 'w_', 'dream_', 'not_',
#         'sue_winner', 'davis_tribute', 'dvd_vcr', 'smc_smt', 'hd___',
#         'red_rtn', 'over_the_ear', 'pin_', 's__ks', 'dp_image_',
#         'tv_power', 'ranma_', 'ject_debut', 'is_audio_player', 'ha_eb',
#         'bzuukp_pbfk', 'elbow_grease', 'angry_bird', 'here___',
#         'pacific_rim', 'thumb_down', 'pd_sbs_e_', 'pd_bxgy_e_img_y',
#         'hurricane_sandy', 'dtv_gov', 'perfect__', 'law_enforcement',
#         'size_', 'comfort_rating', 'kjgocyf_i', 'to_dvi', 'station_id',
#         'mini_dv', 'e_drums', 'calidad_del', 'all_', 'twc_japan',
#         'mech_mod', 'paul_simon', 'glimp_', 'muy_buenos', 'br_other_cl',
#         'mdr_v', 'vise_versa', 'obd_fusion', 'nb_sb_noss_', 'usb_sbt',
#         'one_sentence', 's_cks', 'smdk_fat', 'e_ysjmv', 'product_details',
#         't_money_', 'theater__it', 'rtl_fm', 't_v', 'yp_mt', 'gulf_coast',
#         'he__', 'bfilter_by', 'resource_tools', 'file_id', 'mickey_mouse',
#         'slice_bread', 'ez_rc', 'any_questions', 'el_producto',
#         'thought_how', 'ord_cart_shr', 'pf_rd_i', 'cm_sw_su_dp',
#         'star_power', 'unite_arab', 'cm_cr_pr_cmt', 'woefully_inadequate',
#         'burr_brown', 'di_c', 'hp_pavilion', 'etc_', 'ice_cream',
#         'vj_vortex', 'isport_victory', 'tek_pal', 'non_organic', 'one_m',
#         'flat_', 'line_in', 'nokia_lumia', 'sr_sp', 'science_', 'ug_xw',
#         'cm_rdp_product', 'tracks____', 'lord_ad', 'p___', 'whole_',
#         'hx_p', 'specially_', 'dp_return_', 'joe_tomico', 'amazing_deal',
#         'pd_rhf_se_p_t_', 'pd_sxp_f_pt', 'm_vc', 'nex_ia',
#         'natalie_wilson_', 'kinivo_bth', 'sox_eq', 'i____',
#         'most_powerful', 'tron_legacy', 'batteries_', 'builtin_dd', 'lot_',
#         'um_', 'btf_title_', 'k_khz', 'w_a_y', 'spdif_o', 'slightly_',
#         's______t', 'sb_', 'bluetooth_win', 'ocean_reef',
#         'product_arrived', 'emotiva_xpa', 'ess_sabre', 'p_ssed', 'black_',
#         'muy_buen', 'cp_', 'cain_ak', 'et_al', 'bn_guide',
#         'thermal_compound', 'de_p_', 'canon_power', 'asus_video', 'a_name',
#         'mitchell_', 'was_er', 'dt___', 'vsonic_vsd', 'sr_nr_n_',
#         'jaybird_bluebuds', 'thumbs_up', 'update____', 'manual_en',
#         'helen_n', 'lawn_mowers', 'wesleys_dad', 'bl_sr_wireless',
#         'mysony_reciever', 'wolfson_wm', 'cd_rw', 'altitude_',
#         'yoga_style', 'peking_hotels', 'z_fgek', 'd_skin', 'kb_columns',
#         'b_s_', 'like_pa', 's_', 'violin_concerto', 'sa_xr', 'ifu_eng',
#         'amazon_bt', 'charging_source', 'sonnofa_______', 'e_yl',
#         'overscan_right', 'days_', 'http_boldlist', 'dknight_magicbox',
#         'zadig_xp_v', 'str_dn', 'kickstarter_campaign', 'pd_ys_iyr',
#         'tx_nr', 'maha_powerex', 'louis_armstrong', 'su_ks', 'hd_sdi',
#         'lame_cam', 'sh_', 'sol_republic', 'alpha_numeric', 'silk_dome',
#         'mmc_bdr', 'o_ou', 'el_precio', 'nat_king', 'b_name',
#         'adpater_mini', 'bs_', 'rom_v', 'symphonize_xtc', 'l_cbl',
#         'moore_', 'nvidia_geforce', 'anodize_aluminum', 'icf_c',
#         'rocket_science', 'o_', 'ninja_turtle', 'oppo_bdp', 'cerwin_vegas',
#         'soundware_xs', 'p_m', 'social_writeup', 'fuse_protected',
#         'hd_dvd', 'cc_', 'xonar_dx', 'michael_jackson', 'bla_bla',
#         'jerry_rig', 'quality__', 'frequent_flyer', 'tragus_pierce',
#         'manual_frx', 'pd_sxp_grid_pt_', 'ostry_kc', 'rahul_bhatia',
#         'photive_cyren', 'schiit_modi', 'fox_hd', 'utm_medium', 'um_rcr',
#         'kbt__inc', 'cdp_ce', 'b_repeat', 'advertised_', 'martin_logan',
#         'ati_radeon', 'doxir_idwaw', 'weed_eater', 'san_antonio',
#         'negative_aa', 'hi_md', 'song__', 'li_ion', 'pd_zg_hrsr_e_',
#         'the_road', 'american_idol', 'baofeng_uv', 'foo_input_dts',
#         'systematic_habit', 'flash_drive', 'thing_if', 'input_',
#         'iron_maiden', 'o_o', 'sigh_', 'jo_pim', 'fernando_f',
#         'martin_logans', 'tv_change', 'br_lf_m_', 'img_xxxx',
#         'cm_aya_asin', 'l__', 'tornado_alley', 'promo_key', 'power_sentry',
#         'st_jx', 'link_faqs', 'u_infqiu', 'm_kwz', 'homeworx_hw',
#         'dell_xps', 'tripp_lite', 'as_li_ss_tl', 'har_har', 'dec_trd_c',
#         'hq_', 'microsd_reader', 'fifty_bucks', 'kubik_evo', 'b__e',
#         'bald_eagle', 'cm_cr_thx_view', 'n_n', 'two_hundred', 'g_eng_esp',
#         'cerwin_vega', 'bic_venturi', 'xxx_xxx', 'problem_____the',
#         'hsp_hfp', 'hp_common', 'commercials_off', 'afternoon_', 'cd_dvd',
#         'shortly_thereafter', 'bi_amp_able', 'nascar_race', 'price_', 'v_',
#         's_fbvqvra', 'pd_sim_sbs_e_', 'amzl_us', 'toaster_oven',
#         'wpa_supplicant', 'stagepas_', 'notmad_explorer', 't__t',
#         'ignore_db', 'bl_sr_mp', 'product_', 'soundmate_xxx', 'bi_amp',
#         'elechouse_', 'lmhl__w', 'vsonic_gr', 'bic_acoustech',
#         'average_rating', 'bi_amped', 'lyra_sys', 'm____', 'x__',
#         'hdmi_group', 'omni_directional', 'ap_', 'gpio_out_pin', 'a_s',
#         'cm_cr_pr_sims_t', 'phi_log', 'g_dve', 'pd_sim_', 'kidz_gear',
#         'my_life', 'bit_', 'mz_rh', 'honda_odyssey', 'hockey_puck',
#         'handling_', 'pd_cp_', 'quality_', 'sor_ree', 'ds_store',
#         'pd_bbs_sr_', 'o_stk', 'compaq_presario', 'fahcore_', 'on_for',
#         'wacom_cintiq', 'nb_sb_ss_i_', 'system_', 'firestorm_xl', 'amp_',
#         'iaudio_u', 'videoid_mo', 'garmin_nuvi', 'icom_ic', 'hsu_vtf',
#         'tcc_tc', 'curtain_rod', 'oh_details_o', 'jay_z', 'muy_buena',
#         'edocs_public', 'john_williams', 'plantronics_voyager', 'n_wn_',
#         'ql_nqs', 'zowie_fk', 'very_very', 'img_', 'keyboa_d',
#         'astro_mixamp', 'khv_k', 'jason_', 'i_pod', 'my_vsonic_gr',
#         'a____', 'post_', 'call_______', 'str_dh', 't_t_t_t_t_that',
#         'bafghwdh_', 'j_tech', 'tv_only', 'fernando_r', 'jet_engines',
#         'photo_', 'hvdvd_ts', 'scout_outrack', 'bower_wilkins',
#         'vendor_info', 'udnxilq_x', 'ibasso_dx', 'antennaweb_org',
#         'pd_sim_e_', 'says_', 'buena_calidad', 'rp_htx', 'cm_cd_asin_link',
#         'anti_skate', 'noontec_zoro', 'scientific_atlanta', 'c________d',
#         'station_finder', 'extension_cord', 'box_', 'wt_', 'roar_'],
#        dtype='<U24'))

# %% [markdown]
# ### Convert tokens to keyword counts

# %%
from utils import kw2counts
counts = kw2counts(processed_corpus)
ngram_counts = np.array([tup for tup in counts if '_' in tup[0]])
ngram_counts.shape, ngram_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a8dddcef4197> in <module>
#       1 from utils import kw2counts
# ----> 2 counts = kw2counts(processed_corpus)
#       3 ngram_counts = np.array([tup for tup in counts if '_' in tup[0]])
#       4 ngram_counts.shape, ngram_counts
#
# NameError: name 'processed_corpus' is not defined

# %% [markdown]
# ## Plotting a distribution - some seaborn issue

# %%
t = time()

# number of unique products
x = [i for i in range(total_products)]

#SORTED/ NOT SORTED
rev_counts = E_simple.groupby('product_id').count().iloc[:,0].sort_values(ascending=False)

plt.figure(figsize=(26,8))
plt.bar(x[::20], rev_counts[::20], color='r', linewidth=0) #[::10] to reduce process time
plt.title('Qty Reviews for each product',{'fontsize':40})
plt.tick_params(labelsize='xx-large')
plt.ylim(0,250)

# place a text box in upper left in axes coords
textstr = '\n'.join((
                    'mean: %.1f' % np.mean(rev_counts),
                    'median: %.1f' % np.median(rev_counts)
                    ))              
props = dict(boxstyle='round', facecolor='wheat', alpha=0.8)
plt.text(0.05, 200, textstr, fontsize=24,
        verticalalignment='top', bbox=props)

plt.savefig('saved_data_models/D11Review_count_distribution.png')
plt.show()
plt.close()
print(time()-t,'s')
