# %% [markdown]
# ## Converting tokenized reviews to word embeddings

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

import os
import sys
np.set_printoptions(threshold=sys.maxsize)

from time import time

from gensim.models import Word2Vec
from utils import meaning_test
                          

t=time()

# READ IN REVIEWS
print('Loading Dataset...')
E_tokened = pd.read_json('data/Electronics_tokenized.json')
print('Dataset Loaded: ', round(time()-t,2),'s')

processed_corpus = E_tokened.tokened

print('Training Word Embeddings...', round(time()-t,2),'s')

w2v = Word2Vec(processed_corpus, # input tokenized text
                 min_count=5,   # Ignore words that appear less than this
                 size=300,      # Dimensionality of word embeddings
                 workers=99,     # Number of processors (parallelisation)
                 window=6,     # Context window for words during training
                 max_vocab_size= 40*1000, #
                 compute_loss=True,
                 iter=10)       

print('Trained', round(time()-t,2),'s')

print('# reviews: ', w2v.corpus_count)
print('Total words: ', w2v.corpus_total_words)
print('Latest Training Loss: ', w2v.get_latest_training_loss())
print('Vocab size: ', len(w2v.wv.vocab))

w2v.save('models/E_w2v_gensim10.model')
print('Saved', round(time()-t,2),'s')


print('For fun, and for to test the word embeddings....')
print('Words most similar to *windows*.')
print(meaning_test(['windows'], None,  w2v))
print()
print('Words most similar to *Mac*.')
print(meaning_test(['mac'], None,  w2v))
print()
print('Words most similar to *cat*.')
print(meaning_test('cat', None, w2v))
print()
print('Words most similar to *father*.')
print(meaning_test('father', None, w2v))
print()
print('father + mother - boy')
print(meaning_test(['father','mother'],['boy'],w2v))
print()
print("Thanks :D. You're ready to run the main program!")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Loading Dataset...
# Dataset Loaded:  62.4 s
# Training Word Embeddings... 62.41 s
# Trained 63.08 s
# # reviews:  2836144
# Total words:  81666138
# Latest Training Loss:  12094783.0
# Vocab size:  18053
# Saved 63.08 s
# For fun, and for to test the word embeddings....
# Words most similar to *windows*.
#     words          similarity
# 0   winxp  0.6862816214561462
# 1   vista  0.6787523031234741
# 2  ubuntu  0.6680481433868408
# 3      os  0.6254222989082336
# 4   linux  0.6235475540161133
#
# Words most similar to *Mac*.
#           words          similarity
# 0          imac   0.687383770942688
# 1          macs  0.6585511565208435
# 2     mavericks  0.6501476764678955
# 3  snow_leopard  0.6488965153694153
# 4           osx   0.646578311920166
#
# Words most similar to *cat*.
#     words          similarity
# 0     utp  0.6351267695426941
# 1    gnaw  0.5743775963783264
# 2  kitten  0.5678672790527344
# 3   kitty  0.5519692301750183
# 4  baluns  0.5317671895027161
#
# Words most similar to *father*.
#     words          similarity
# 0  mother  0.8623847961425781
# 1     dad  0.7707857489585876
# 2     mom   0.727999210357666
# 3    aunt  0.7158770561218262
# 4  sister  0.6951234340667725
#
# father + mother - boy
#          words          similarity
# 0          mom  0.6373394131660461
# 1         aunt  0.6369031667709351
# 2  grandmother  0.6358923316001892
# 3          dad  0.6182491183280945
# 4       sister   0.570649266242981
#
# Thanks :D. You're ready to run the main program!

# %% [markdown]
# # <br>
# # EDA

# %%
# # LOAD A PRETRAINED MODEL TO SAVE TIME
# from time import time
# import numpy as np
# from gensim.models import Word2Vec
# w2v = Word2Vec.load('models/E_w2v_gensim10_2.model')
# E_tokened = pd.read_json('data/Electronics_tokenized.json')
# processed_corpus = E_tokened.tokened

# %% [markdown]
# ## All ngrams before Word2Vec

# %%
from utils import kw2counts

ngrams = []
for review in processed_corpus:
    for tok in review:
        if '_' in tok:
            ngrams.append(tok)
            
len(np.array(list(set(ngrams)))), np.array(list(set(ngrams)))
# Out:
# (1616, array(['car_dvr', 'cm_cr_dp_cmt', 'nashville_tn', 'a_e', 'as_li_tl',
#         'a_s', 'seeyqkz_a', 'um_rcr', 'infinity_primus', 'number_',
#         'san_jose', 'southern_california', 'highres_', 'w___',
#         'paul_frank', 'schiit_bifrost', 'fix_the_knob', 'dknight_magicbox',
#         'muy_bien', 'speexrate_best', 'speaker_', 'sams_club', 'tek_pal',
#         'cm_sw_su_dp', 'aag_m_pw_dp', 'cs_id', 'model_search', 'ni_cad',
#         'mdrzx_blk', 'isport_victory', 'pin_', 'baofeng_uv', 'dot_clean',
#         'j_hilbert', 'ya_aw_oh_pii', 'trails_', 'h_d_t_v', 'the_road',
#         'boco_fw_wcb', 'ignore_db', 'bruno_mar', 'mdr_v', 'yyy_seq',
#         'solitude_xcs', 'snow_leopard', 'play_record', 'four_hundred',
#         'zadig_xp_v', 'superlux_hd', 'def_tech', 'c_name', 'a_id',
#         'better_bought', 'pd_sim_sbs_pc_', 'needlenose_pliers',
#         'bafghwdh_', 'jay_bird', 're_order', 'lepai_tripath', 'powerex_mh',
#         'scotland_ace', 'x_', 'natalie_wilson_', 'kdl_hx', 'meaning_don',
#         'swiss_army', 'braven_brv', 'kobo_aura', 'garmin_nuvi',
#         'liquidcristal_i', 'pinguy_os_', 'mlopez_', 'src_vid', 'b__',
#         'donald_', 'laredo_texas', 'nknbekc_e', 'fallroman_ii', 'a_b',
#         'powerdvd_', 'a_rcr', 'denon_avr', 'rapid_succession', 'stagepas_',
#         'i_phones', 'n_n', 'mike_tina', 'schiit_magni',
#         'powerpoint_presentations', 'sp_c', 'ifu_eng', 'cm_cr_thx_pdp',
#         'mech_mod', 'projector_', 'motherf___', 'rf_', 'warehouse_deals',
#         'backwards_', 'extension_cord', 'problem_____the', 'syl_scr',
#         'droid_bionic', 'tread_mill', 'homeworx_hw', 'moore_',
#         'utmost_importance', 'nvidia_geforce', 'title_', 'wms_ohs_product',
#         'dp_return_', 'dmp_bdt', 'overscan_right', 'cambridge_soundworks',
#         'federal_regulations', 'pa_', 'small_', 'p_leftorright',
#         'product_details', 'et_al', 'template_id', 'kinivo_bth',
#         'lazy_susan', 'llego_tiempo', 'im_no_angel', 'cm_cr_wr_img',
#         'b_buy', 'fv_bb', 'mitchell_', 's_cked', 'tron_legacy',
#         'properly_', 'vj_vortex', 'rkelly_', 'anc_quietpoint',
#         'perfecto_estado', 'then_', 'says_', 'kindle_', 'hwcxjwz_lk',
#         'rxyxgo_pmvs', 'component_video', 'harbor_freight', 'products_id',
#         'phoenix_az', 'celebrity_endorse', 'cm_cd_asin_link',
#         'henry_kloss', 'category_id', 's_', 'bluetooth_win',
#         'horror_stories', 'usb_sbt', 'xx_psrp', 'http_amzn',
#         'swapnil_saloni', 'product__i', 'sh__', 'nb_sb_noss_', 'd_a_b',
#         'fta_express', 'h_', 'one_sentence', 'period___', 'in_line',
#         'hdmi_which_one', 'price_', 'tsx_', 'velodyne_vpulse', 'basement_',
#         'skull_crushers', 'pe_', 'nitty_gritty', 'cm_cr_dp_synop',
#         'station_finder', 'nad_viso', 'bone_conduction', 'jeep_wrangler',
#         'hq_', 'flypage_sc', 'dvd_rw', 'pinky_powers', 'hurricane_irene',
#         'raspberry_pi', 'g_grunfeld', 'mt_wilson', 'fiber_optics',
#         'lkdqyx_koem', 'khv_k', 'qmffmuet_o', 'radio_usb_si', 'upstate_ny',
#         'limestone_lenny', 'alcohol_', 'completely_', 'gdi_irc',
#         'nc_ztjkw', 'wpa_supplicant', 'abt_bm', 'ti____', 'hsp_hfp',
#         'czech_kid', 'rertyiop_', 'mp_', 'to_', 'docks_base', 'st_jx',
#         'bfilter_by', 'rocket_science', 'kaito_ka', 'the_',
#         'pd_sxp_grid_i_', 'znvm_pcpatch_la', 'l_v', 'prodfaq_',
#         'silk_dome', 'airmobi_xxxxxx', 'psc_redirect', 'icf_s', 'asset_id',
#         'oss_product', 'back_up', 'hilly_terrain', 'high_', 'orion_',
#         'fallroman_i', 'str_de', 'plantronics_backbeat', 'm_f',
#         'altec_lance', 'srf_m', 'cush_fin', 'anxiously_await', 'gdi_btar',
#         'instructions_', 'eagerly_await', 'bzuukp_pbfk', 'cain_ak',
#         'todas_las', 'img_xxxx', 'tractorbeam_u', 'review____', 'pid_',
#         'rp_sma', 'slice_bread', 'img_', 'buddy_boy', 'ypbpr_ansi', 'sr_',
#         'fox_hd', 'rhkdil_', 't_t_t_t_t_that', 'gno_cart_title_',
#         'jia_george', 'beersheb_books', 'magick_karma_', 'm_rec',
#         'rcfn_jdzuka', 'gel_caps', 'qsg_s', 'cm_rdp_product', 'b_',
#         'ni_mh', 'bit_w', 'xonar_dx', 'cr_p', 'on_for', 'onkyo_usa',
#         's____', 'nes_snes', 'u_hooks', 'e_r', 'guy_', 'intel_nuc',
#         'reign_supreme', 'plug_and_play', 'router_na',
#         'cathedral_ceilings', 'cm_cr', 'd_ita', 's__thouse', 'diagram_',
#         'isolation___', 'dennis_aiken', 'ip_d', 'rock_it', 'glimp_',
#         'base_sku', 'best_buy_outlet', 'dpd_sim_sg_', 'negative_aa',
#         'alpha_numeric', 'denon_e', 'goo_gl', 'dvd_', 'good_',
#         'integra_dtr', 'jason_m', 'razer_kraken', 'revision_', 'bit_',
#         'pd_sxp_f_pt', 'fifty_bucks', 'ex_bc', 'words___', 'i______',
#         'song__', 'oregon_scientific', 'line____', 'micro_sd',
#         'asus_xonar', 'muti_point', 'terk_hdtva', 'sr_nr_n_', 'gdi_ira',
#         'display_entry', 'pearl_jam', 'sc_', 'hanni_buzz', 'dm_mu_dp_trk',
#         'da__', 'pixie_willner', 'las_vegas', 'e_bikes', 'dp_ob_title_ce',
#         'tcc_tc', 'mediasonic_hw', 'commercials_off', 'bad_', 'dunu_dn',
#         'fl_flatwave', 'mow_lawns', 'ser_linux_zip', 'zombie_x',
#         'hockey_puck', 'athena_ivoice', 'archos_devices', 'jose_ambriz',
#         'ear_buds', 'fh_lcr', 'gogear_vibe', 'c____', 'datasheets_pdf',
#         'dvds_cds', 'lmhl__w', 'g_eng_esp', 'new_earbudi', 'tv_dvr',
#         'vbus_present', 'astro_mixamp', 'emotiva_upa', 'brand_', 'j_mount',
#         'woo_hoo', 'rtl_sdr', 'pd_sbs_a_', 'pd_ybh_', 'cm_cr_pr_cmt',
#         'dp_spec_v', 'what_______', 'cwhog_nlr', 'nokia_lumia',
#         'yoga_style', 'rating_', 'x_xywksbeiqa', 'xycsuep_j', 'um_',
#         'sales_pitch', 'notes___', 'ml_ipod', 'music__', 'p_id', 'p_m',
#         'xiaomi_piston', 'fragile_', 'o_stk', 'n_wn_', 'roger_russell',
#         'a_', 'honda_civic', 'jay_z', 'e___', 'player_it', 'sr_st',
#         'f___ed', 'sue_winner', 'zombie_apocalypse', 'p__s', 'earth_',
#         'i___', 'd_skins', 'pd_cp_', 'jensen_jta', 'sd_baja',
#         'thermal_compound', 'sa_', 'pellet_stave', 'active_pwr',
#         'counter_strike', 'sti_gl', 'inkjet_printable', 'i______i',
#         'pd_bbs_sr_', 'was_er', 'm_____r', 'cm_cd_ql_tlc_al', 'sr_nr_p_',
#         'beard_trimmer', 'again_____more', 'circus_tent', 'e_q', 'home_en',
#         'comments__this', 'sammy_k', 'fiber_optic', 'nec_optiarc',
#         'etekcity_roverbeats', 'm____', 'v_v', 'pf_rd_r', 'mikjcgq_',
#         'elechouse_cc', 'muy_buen', 'toaster_oven', 'mdr_rf', 'fb_defio',
#         'product_detail', 'days_', 'dvi_adapter', 'gadget_guy', 'dgmbrc_',
#         's__k', 'tracks____', 'howard_stern', 'box_', 'e_yl', 'quality_',
#         'hdmi_', 'hdmi_control', 'dsp_corrections', 'cm_cd_asin_lnk',
#         'keyboa_d', 's__t', 'as______', 'fernando_f', 'michael_jackson',
#         'ez_rc', 'sabrent_a', 'hp_rel_topic', 'recording_', 'doxir_idwaw',
#         'i_pod', 'not_', 'i____', 'olp_cg_pop', 'san_diego', 'roar_',
#         'mp_s_a_', 'feat_diplo', 'soap_operas', 'lo_recomiendo',
#         'eagle_aspen', 'fanny_wang', 'sansa_m', 'a__', 's_air',
#         'toyota_camry', 'j__', 'vol_', 'comma___', 'nb_sb_ss_i_', 'bert_',
#         'veb_esgiekg', 'it_it', 'hd_ma', 'pd_sim_sg_', 'memorex___drive',
#         'rome_florence', 'x_update_xxx', 'cmc_magnetics', 'bcb_',
#         'region_id', 'roomba_roomba', 'clap_on', 'g_sensor', 'https_www',
#         'xw_sma', 'page_headphones', 'so_', 'rm_vl', 'atf_title_',
#         'cameo_artists', 'erpzb_vc', 'w_a_y', 'dcr_dvd', 'sega_dreamcast',
#         'looks_', 'bo_e', 'ct_bw', 'pl_', 'v_moda', 'rj_tech', 'clip_',
#         'oss_rev', 'irobot_roomba', 'razr_maxx', 'lvxaohg_',
#         'infinity_tss', 'au_ction', 'azo_dye', 'over_the_ear', 'all_',
#         'time_', 'bronco_', 'wal_mart', 'btf_title_', 'plus_plus',
#         'pacific_rim', 'pd_rhf_p_t_', 'dream_', 'p_qk', 'as_li_ss_tl',
#         'buds______', 'gun_roses', 'music_on', 'k_____', 'db_hp', 't__t',
#         'white_thank', 's_fbvqvra', 'r_dl', 'product_arrived', 'version_',
#         'thought_how', 'jesus_christ', 'dental_floss', 'pre_paid', 'g_d',
#         'here___', 'techspec_index', 'sonnofa_______', 'social_writeup',
#         'buen_precio', 'h_d', 'soundlink_on', 'jaybird_bluebud',
#         'maker_period', 'sr_ph_', 'mutually_exclusive', 'science_',
#         'magnasonic_mag', 'mdrrf_rk', 'curl_iron', 'extension_cords',
#         'louisville_ky', 'chpt_', 'text__', 'ok_sp', 'x_x', 'h_pas',
#         'bbp_s_iphone', 'j_tech', 'lh_ni_t', 'eacute_cor', 'bower_wilkins',
#         'wireworld_starlight', 'm_rsemrok', 'foo_out_asio', 'ds_store',
#         'noontec_zoro', 'soundtouch_app', 'bxyhwx_uhcc', 'rm_hla',
#         'iaudio_', 'ak_frost', 'xy_', 'av_receiver', 'f_', 'cr_ppy',
#         'utf_qid', 'm_series', 'device_size', 'czech_republic',
#         'button_cell', 'audible_alex', 'download_start', 'bd_re',
#         'cd_itrr', 'rp_htx', 'any_better_job', 'xonar_u', 'dpe_',
#         'bee_dac', 'bi_wire', 'lithium_ion', 'charges_', 'p_dp_',
#         'wing_nuts', 'photive_cyren', 'b_at', 'pf_rd_p', 'pd_bxgy_e_img_y',
#         'steve_is', 'e_son', 'vhs_c', 'my_vsonic_gr', 'rp_hje',
#         'los_recomiendo', 'str_dn', 'lord_ad', 'stainless_steel', 'jewel_',
#         'audyssey_multeq', 'pd_rhf_se_p_t_', 'sega_saturn', 's_lots_of',
#         'pig_tail', 'cricket_post', 'rocket_scientist', 'at_',
#         'charging_source', 'delete_file', 'fenix_pd', 'p__k', 'link_faqs',
#         'sam_club', 'u_infqiu', 'digital_modes', 'tv_change',
#         'instant_gratification', 'rv_cl', 'trsvyxyuo_m', 'artist_name',
#         'manual_oarno', 'elliptical_trainer', 'sub_woofer',
#         'pd_bxgy_e_img_b', 'gogroove_airband', 'b__t', 'pa_systems',
#         'f_ucking', 'to_dvi', 'isopropyl_alcohol', 'toyota_tacoma',
#         'in_thy_light', 'reception_', 'tv_protector', 'whole_', 'li_ion',
#         'videoid_mo', 'eric_clapton', 'dlfb_data', 'worked_',
#         'annotation_', 'setup____', 'ma__', 'blah_blah', 'amazon_bt',
#         'ranma_', 'cerwin_vegas', 'mini_book', 'hdmi_safe', 'ati_radeon',
#         'airmobi_xxxx', 'interphone_', 'pct_amp', 'rp_htf', 's_cks',
#         'chaper_', 'c_ddvds', 'entrega_fue', 'cd_rw', 'sol_republic',
#         'woefully_inadequate', 'cm_cr_pr_perm', 'i_love_having', 'tom_fox',
#         'viking_usa', 'mechanically_incline', 'inch_', 'search_query',
#         'este_producto', 'movie_', 'quality___', 'cd_quality',
#         'yusuf_burke', 'oontz_xl', 'amp_and', 'private_ryan',
#         'ntt_srch_drd_b', 'notmad_explorer', 'vice_versa', 'mipow_boomax',
#         'utm_term', 'yo_ii_img', 'thermal_paste', 'o__o', 'p_',
#         'debbie_lee', 'sega_genesis', 'ser_mac_zip', 'aogw_', 'clear_',
#         'you_', 'pro_eb', 'rc_keymaps', 'aidozybq_', 'tv_dvd',
#         'astell_kern', 'multi_voltage', 'chris_himself', 'maha_mh',
#         'mengo_aquacube', 'z_fgek', 'whatever_', 'most_powerful', 'rom_v',
#         'david_underland', 'compaq_presario', 'visa_versa', 'muy_buenos',
#         'andrew_jones', 'annotation_id', 'dec_trd_c', 'lame_cam', 'in_law',
#         'tv_power', 'onecall_com', 'ql_nqs', 'this__', 'blu_ray', 'on_',
#         'package_', 'happy_', 'portland_oregon', 'product_name',
#         'barnes_noble', 'pd_cp_k_', 'black_', 'rtl_', 'contact_us',
#         'us_en', 'sh_t', 'thumbs_up', 'gigacity_amn', 'cm_wl_huc_item',
#         'jof_n', 'external_sd', 'handling_', 'mb_data', 'arlington_lv',
#         'jphhq__rk', 'cirrus_logic', 'veriz_n', 'znrg_mejhx',
#         'utm_campaign', 'twc_japan', 'yuin_pk', 'o_oa', 'whoop_',
#         'hp_common', 'vise_versa', 'bye_bye', 'headphone_price', 'half_',
#         'dihle_lvsve', 'purple__', 'iomega_hipzip', 'lady_gaga',
#         'th_quarter_', 'airzone_macaddr', 'sr_ph', 'gb_c', 'oh_details_o',
#         'soundmatters_foxl', 'wi_fi', 'nvidia_gtx', 't_v', 'tx_nr',
#         'thumb_down', 'l___', 'r_sng', 'sewell_deadbolt', 'slimx_imp',
#         'hx_p', 'tornado_alley', 'v_o_r', 'eng_chi', 'ultrasone_hfi',
#         'vsonic_gr', 'spdif_o', 'p_egnant', 'packing_inc', 'mdr_ex',
#         'manual_frx', 'pd_zg_hrsr_e_', 'str_dh', 'e_drums', 'cp_id',
#         'lyrics_sync', 'evo_lte', 'gordon_brothers', 'persist_app',
#         'honda_odyssey', 'chp_vr', 'kanye_west', 'aem_hbdo', 'ali_julia',
#         'slam_dunk', 'audio_ts', 'order___nice', 'pd_cp_mov_', 'santa_fe',
#         'brightside_sc', 'jurassic_park', 'pd_cp_vg_', 'silly_p',
#         'lame_ecn', 'rate_converter', 'am_fm', 'lawn_mower', 'c________d',
#         'hd_dvr', 'flathead_screwdriver', 'kio_ifp', 'android_n',
#         'lawn_mowers', 'smc_smt', 'smoke_detectors', 'pd_cp_e_',
#         'smdk_fat', 'cdp_ce', 'chili_pepper', 'h_ww', 'nelson_cartier',
#         'tv_wall_mounts', 'beyerdynamic_edt', 'etc_', 'neuf_',
#         'holy_grail', 'aune_t', 'ultra_sturdy', 'go_to', 'mz_nh',
#         'flammable_liquids', 'pd_bxgy_', 'leonard_bise', 'bs_lr', 'h_hx_x',
#         'hd_sdi', 'basketball_court', 'r____o', 'rnskm_', 'u_s_b', 'sn_v',
#         'thorens_td', 't___t', 'strain_reliefs', 'pd_ecc_rvi_',
#         'daisy_chain', 'buen_estado', 'easycap_d', 'vdr_m', 'pd_sim_e_',
#         'symphonize_nrg', 'profit_margins', 'zg_bs_', 'pf_rd_m', 'scr_wed',
#         'low_', 'sigh_', 'speaker_wire', 'jd_', 'isolation_____',
#         'snaec_ag', 'swag_swag', 'elephants_print', 'update____', 'icf_c',
#         'crawl_', 'american_idol', 'sony_wm', 'sr_sp', 'radiant_barrier',
#         'wacom_cintiq', 'overscan_bottom', 'avr_power', 'et_pwifud',
#         'list_satish', 'c_', 'ntsc_m_j', 'stcroix_man', 'photo_',
#         'boombot_rex', 'hdmi_switch', 'iâ_tm', 'rd_generation', 'fine_',
#         'kailani_jordan', 'if_tg', 'how_', 'hvdvd_ts', 'harman_kardon',
#         'da_ned', 'bi_amping', 'p_ds', 'synology_nas', 'buffer_get_ret',
#         'krk_rokit', 'svs_pb', 'p_ssed', 'buffer_get_int', 'di_c',
#         'gee_whiz', 'south_carolina', 'mpu_', 'amazing_deal',
#         'up_directions', 'wosang_pro', 'blue_kanga', 'adrian_landeira',
#         'microsoft_user', 'p___ks', 'kb_columns', 'bob_dylan',
#         'mpow_freego', 'bi_amped', 'u_cja', 'gen_pur', 'hsb_', 'fact_',
#         'trivial_', 'edocs_public', 'song_renumber', 'bn_guide',
#         'ge_superradio', 'amzl_us', 'joe_tomico', 'ac_sx', 'sort_by',
#         'oss_t', 'q_', 'shshs___', 'dx_c', 'q_q', 'dt___', 'pd_sim_pc_',
#         'one_battery', 'john_williams', 'tii_', 'ath_anc', 'fernando_r',
#         'infinite_wisdom', 'braven_lux', 'likely_', 'mike_helms',
#         'pd_bbs_', 'tom_tom', 'http_youtu', 'pd_sim_hi_', 'rene_roman',
#         'ug_xw', 'c_id', 'altitude_', 'jabra_solemate', 'bl_sr_mp', 'shi_',
#         'sa_xr', 'headphone_pro', 'kinivo_bn', 'bk_shark', 'live_sound',
#         'max_value', 'guesst_t', 'pd_rate_rs', 'd_', 'buen_producto',
#         'cd_da', 'cm_cr_rdp_perm', 'tt_sk', 'breast_cancer',
#         'north_carolina', 'vcc_mcu', 'com_wrapper', 'oh_o', 'allen_wrench',
#         'a___', 'wharfedale_diamond', 'but__', 'as_sl_pc_ss_til',
#         'vw_jetta', 'dp_proddesc_', 'mon_fri', 'rahul_bhatia',
#         'ecoxgear_ecoxbt', 'o_e', 'fuse_protected', 'product_id',
#         'exacto_knife', 'up_great', 'c____guys', 'girls_', 'pd_ys_iyr',
#         'hl_', 'nema_connector', 'iapp_controlapp', 'very_good', 'sh_ts',
#         'he__', 'trans_pacific', 'o_o', 'mr_gt_mustang', 'rice_cooker',
#         'pd_sbs_sg_', 'mini_sd', 'xonar_dg', 'microwave_oven',
#         'rinky_dink', 'jason_', 'richmond_va', 'mount_be', 'parrot_ziks',
#         'ಠ_ಠ', 'wolfson_wm', 'just___', 'airmobi_fcc', 'paosanhueza_',
#         'buena_compra', 'shoe_lace', 'filemanager_',
#         'structural_integrity', 'kjgocyf_i', 'cd_r', 'lyra_sys', 'sor_ree',
#         'soundmate_', 'b__s_', 'buenas_condiciones', 'sox_eq',
#         'aether_cone', 'ciem_review', 'album_name', 'jds_labs',
#         'co_workers', 'sd_', 'hdmi_drive', 'voipad_', 'smart_parts_usa',
#         'noise_removal', 'your_dir', 'muy_buena', 'size_', 'b_name',
#         'mdr_ed', 'radar_detector', 'ws_ftp', 'sound_rating', 'ann_arbor',
#         'boot_delay', 't_fwkrdbv', 'oculus_rift', 'file_id', 'pr_',
#         'pet_peeve', 'audio_input', 'context_', 'one_m', 'pd_sxp_grid_pt_',
#         'stm_', 'walkie_talkie', 's______t', 'pf_rd_t', 'product_info',
#         'kubik_evo', 'lc_le', 'c_amazon', 'h_uc', 'service_info',
#         'wl_it_dp_o_pdt', 'skull_candy', 'eq_mode', 'buena_calidad',
#         'pd_rhf_cr_s_cp_', 'cons____', 'smv_encode', 'symphonize_glxy',
#         'rp_hc', 'woot_deals', 'aux_in', 'en_us', 'features_', 'sw_',
#         'cm_sw_r_tw_acp', 'oppo_bdp', 'elechouse_', 'trrs_standards',
#         'music_lover', 'n___', 'cable_', 'pci_atsc_hybrid', 'h_t_c',
#         'scull_candy', 'menagerie_print', 'fbcpudu_qgy', 'adpater_mini',
#         'a__ed', 'u_', 'har_har', 'ntsc_m', 'max_fum_eng', 'ima_adpcm',
#         'pt_ae', 'cm_cr_dp_title', 'weekend_', 'pd_cp_p_', 'my_life',
#         'holy_cow', 'afternoon_', 'viewsonic_pjd', 'red_', 'a_c',
#         'twister_b', 'mini_dv', 'dp_image_', 'comfort_rating', 'blue_rtn',
#         'isport_immersion', 'zadig_v', 'formatter_', 'd_re', 'ap_',
#         'mysony_reciever', 'pf_rd_s', 'pdu_', 'wal_', 'scream_meanie',
#         'utf_psc', 'rtl_tcp', 'phi_log', 'two_hundred', 'i_manual',
#         'nascar_race', 'soundmate_xxx', 'enabled_', 'photive_bth',
#         'yourself_', 'srs_btx', 'hd___', 'dumas_mc', 'advertised_',
#         'south_africa', 'muy_bueno', 'sh_', 'l_cbl', 'acto_knife',
#         'the_connection', 'wa____k', 'trtyiuop_', 'it_', 'play_',
#         'lil_wayne', 'br_other_cl', 'fcc_gov', 'trs_connector',
#         'hdmi_group', 'scuba_dive', 'however_', 'jabra_revo', 'content_',
#         'alpatronix_ax', 'martin_logans', 'highway_robbery', 'clips___',
#         'shared_assets', 'altec_lansing', 'spdif_out', 'like_pa',
#         'call_______', 'accessories_tab', 'dvd_rom', 'spk_velo', 'x__',
#         'kbt__inc', 'usrp_interfaces', 'gopro_hero', 'srs_wow',
#         'utm_medium', 'wesleys_dad', 'max_fur_eng', 'dvi_d', 'edit_',
#         'dst_g', 'fahcore_', 'e_ysjmv', 'cc_', 'rip_off',
#         'steelseries_siberia', 'ehthfbmya_g', 'wesv_lp', 'hdmi_hdmi',
#         'builtin_dd', 'eaeaea_', 'utm_source', 'k_khz', 'any_questions',
#         'ear_bud', 'sdbr_pcdrv_l', 'p___', 'flash_drive', 'achilles_heel',
#         'co_ax', 'line_', 'effo_t', 'schiit_lyr', 'stereophile_magazine',
#         'david_carlin', 'pros________', 'bi_amp_able', 'manner_',
#         'media_universe', 'bi_amp', 'v___', 'output_', 'd_release',
#         'winegard_freevision', 'theater__it', 'chit_chat', 'arduino_uno',
#         'resource_tools', 'mercedes_benz', '흫_흫', 'eyeglass_wearers',
#         'pre_amp', 'valley_enterprises', 'slight_', 'hk_aura',
#         'hdmi_cable', 'harmon_kardon', 'b_o_l_s_e', 'de_p_',
#         'memories_on_tv', 'ezcap_vista', 'otterbox_defender',
#         'pd_sim_sbs_e_', 'lenovo_yoga', 'time_set', 't_t', 'pd_ys_iyr_img',
#         'schiit_modi', 'slo_o_o_o_owly', 'ha_eb', 'foo_upnp',
#         'salvation_army', 'pd_cp_pc_', 'afqjcnghd_s', 'main_sr',
#         'wsp_message', 'chapter_', 'brooklyn_ny', 'peking_hotels',
#         'jelly_bean', 'daft_punk', 'pre_out', 't_', 'promo_key', 'link_',
#         'very_very', 'jaybird_bluebuds', 'avr_change', 'gusto_mucho',
#         'my_song', 'helen_n', 'sb_', 'scout_outrack', 'overscan_top',
#         'tj_maxx', 'ninja_turtle', 'overscan_left', 'u_u', 'red_phones',
#         'cm_cd_et_jump', 'maha_powerex', 'trinity_', 'cpu_fan',
#         'view_question', 'cp_', 'question_the', 'mdr_', 'asus_video',
#         'bebzrig_pws', 'soundfreaq_sfq', 'ocean_reef', 'quality__',
#         'installer_', 'sirius_xm', 'works_', 'tripp_lites', 'emotiva_xda',
#         'ject_debut', 'sony_dvd', 'crackberry_com', 'http_www',
#         'rionitrusflash_', 'emi_rfi', 's_video', 'are_', 'product_',
#         'cm_cr_dp_pdp', 'fault_', 'wma_pro', 'evga_gtx', 'bald_eagle',
#         'hours_', 'a_name', 'pd_cp_hi_', 'vault_ceilings', 'neil_young',
#         'sewell_silverback', 'pd_vtp_e_', 'dd_wrt', 'hi_md',
#         'frank_sinatra', 'b_s_', 'toyota_sienna', 'ambiance_', 'reply_',
#         'dozen_', 'conrad_p', 'cm_cr_thx_view', 'w_', 'med_',
#         'trans_atlantic', 'mirage_omd', 'in_ear', 'manual_en', 'pd_sbs_e_',
#         'ref_', 'micros__t', 'dvd_r', 'shut_off', 'schiit_asgard',
#         'max_mart', 'tripp_lite', 'shopping_help', 'micca_mb',
#         'medical_transcription', 'indv_k', 'ff_rew', 'box_power',
#         'screen_size', 'o_', 'f_cking', 'su_ks', 'cm_cd_naredir',
#         'pp_play', 'blue_ray', 'jc_sounds', 'biddeal_co',
#         'pd_bxgy_e_img_c', 'pd_sbs_hg_', 'dvr_a', 'epson_artisan',
#         'com_content', 'b__se', 'vh_', 'att_uverse', 'video_ts',
#         'martin_logan', 'red_rtn', 'hello_kitty', 'rtl_fm', 'aag_d_sh',
#         'antennaweb_org', 'non_organic', 'seve_al', 'riva_turbo',
#         'estoy_muy', 'l__', 'layer_jump', 'danger_efest_', 'ibasso_dx',
#         'gpio_out_pin', 'mad_lynn', 'wl_it_dp_o_pc', 'rohs_compliant',
#         'f___', 'scientific_atlanta', 'system_', 'shop_online',
#         'davis_tribute', 'all__', 'cm_sw_r_awd_rgt', 'bla_bla',
#         'emotiva_xpa', 'happy_sellers', 'x___', 'cm_aya_asin', 'xw_nas',
#         'build_rating', 'lp_', 'tenergy_centura', 'fenix_tk', 'nex_ia',
#         'r_', 'taotronics_tt', 'poo_poo', 'flat_', 'dvd_writers',
#         'brite_view', 'supra_aural', 'canon_power', 'gp_converter', 'htr_',
#         'ferrite_bead', 'gpio_in_pin', 'lenovo_thinkpad', 'non_waterproof',
#         'icom_ic', 'geek_squad', 'datacomm_wh', 'product_im', 'pete_sake',
#         'star_power', 'pd_cp_misc_', 'daughte_', 'sledge_hammer',
#         'start_up', 'peanut_butter', 'hdmi_mode', 'follow_up', 'co_worker',
#         'm_kwz', 'average_rating', 'true_depth', 'b_y', 'composite_video',
#         'h_ll', 'hurricane_sandy', 'burr_brown', 'mis_expectativas',
#         'post_', 'alt_delete', 'cerwin_vega', 'ekhsibm_', 'batteries_',
#         'proven_choice', 'ir_manual', 'ac_sy', 'pf_rd_i', 'marcosr_',
#         'y_tepdy', 'high_vhf', 'nb_sb_noss', 'nu_force', 'docsis_system',
#         'perfect__', 'm_audio', 'a____', 'unite_kingdom', 't_money_',
#         'bc_rsatb', 'foo_input_sacd', 'numeric_keypad', 'd_skin', 'b_x',
#         'acer_aspire', 'amp_', 'excelente_producto', 'n_blqfq',
#         'spoofed_ans', 'w_price', 'common_gwzx', 'diesel_vektr',
#         'neodymium_magnets', 'cm_cr_pr_pb_t', 'xxx_xxx', 'rev_',
#         'essence_stx', 'dvd_vcr', 'rx_v', 'specially_', 'rtl_adr',
#         'voltage_divider', 'microsd_reader', 'utm_content',
#         'plantronics_voyager', 'grundig_satellit', 'suc_', 'martial_arts',
#         'foo_input_dts', 'winegard_lna', 'wal___t', 'cons________',
#         'power_sentry', 'f__', 'g_dve', 'hd_dvd', 'taylor_swift', 'eng_',
#         'iaudio_u', 'sylvie_rdlg', 'ord_cart_shr', 'atonline_com', 's__ks',
#         'sound_', 'beware_', 'y_', 'supertooth_disco', 'input_',
#         'tecsun_pl', 'cjm_clearstream', 'geforce_gtx', 'all_service',
#         'watchespn_com', 'slightly_', 'plug_in', 'mmc_bdr', 'v__v',
#         'debut_carbon', 'nstc_m', 's___', 'tablet_w', 'bob_marley',
#         'tragus_pierce', 'udnxilq_x', 'senior_citizen', 'thoughts__',
#         'phone_', 'lmr_', 'update_', 'isolation__', 'asus_eee', 'wp_',
#         'green_rtn', 'wreak_havoc', 'parrot_zik', 'races_', 'thing_if',
#         'x_boom', 'com_frontpage', 'lame_enc', 'clueless_', 'b___',
#         'major_league', 'front_back', 'f___ck', 'up____________', 'den_n',
#         'mz_rh', 'tv_only', 'wl_it_dp_o', 'weed_eater', 'senior_citizens',
#         'photive_hydra', 'cotton_swab', 'power_supply', 'cfb_at_prodpg',
#         'display_', 'awesome_sound', 're_chargeable', 'v_',
#         'bl_sr_wireless', 'line_in', 'dp_image_z_', 'xvt_sv', 'pal_b',
#         'tv_', 'seconds_', 'he__l', 'o_ou', 'pd_sim_', 'molly_dog',
#         'son_replacement', 'is_audio_player', 'd__che', 'pd_sim_cps_',
#         'cat_id', 'bs_', 'paradigm_atoms', 'these_', 'bgg_p', 'y_k',
#         'station_id', 'user_interfaces', 'great_very', 'billy_vandory',
#         'cm_sw_r_awd_rrw', 'world_', 'm_vc', 'lfqv_uya', 'plwitua_lhzlku',
#         'b_repeat', 'son_kdf', 'i_____', 'psdc_', 'topic_id', 'bq_cc',
#         'lot_', 'b__e', 'os_id', 'dav_hdx', 'str_dg', 'wt_',
#         'kimber_kable', 'iron_maiden', 'elbow_grease', 'the_strokes',
#         'vendor_info', 'cd_dvd', 'wl_mb_recs_', 'br_lf_m_',
#         'cm_cr_pr_sims_t', 'set_par', 'repeat_mode', 'cable_type', 'vid_',
#         'slippery_sleeve'], dtype='<U24'))

# %%
counts = kw2counts(processed_corpus)
ngram_counts = np.array([tup for tup in counts if '_' in tup[0]])
ngram_counts.shape, ngram_counts
# Out:
# ((1616, 2), array([['skull_candy', '4827'],
#         ['altec_lansing', '4221'],
#         ['http_www', '4219'],
#         ['tripp_lite', '3038'],
#         ['swag_swag', '2987'],
#         ['harman_kardon', '2767'],
#         ['wal_mart', '2639'],
#         ['harmon_kardon', '1605'],
#         ['co_workers', '1329'],
#         ['li_ion', '1297'],
#         ['lithium_ion', '1288'],
#         ['raspberry_pi', '1278'],
#         ['fiber_optic', '1219'],
#         ['vice_versa', '1198'],
#         ['ni_mh', '1184'],
#         ['martin_logan', '1160'],
#         ['sol_republic', '1123'],
#         ['videoid_mo', '1093'],
#         ['daisy_chain', '1081'],
#         ['allen_wrench', '1047'],
#         ['cambridge_soundworks', '1043'],
#         ['cerwin_vega', '998'],
#         ['stainless_steel', '912'],
#         ['co_worker', '887'],
#         ['blah_blah', '723'],
#         ['curl_iron', '685'],
#         ['hello_kitty', '685'],
#         ['sr_', '682'],
#         ['south_africa', '653'],
#         ['utf_qid', '637'],
#         ['antennaweb_org', '601'],
#         ['utf_psc', '582'],
#         ['san_diego', '538'],
#         ['bower_wilkins', '533'],
#         ['https_www', '502'],
#         ['terk_hdtva', '469'],
#         ['rocket_science', '452'],
#         ['lawn_mower', '445'],
#         ['bye_bye', '436'],
#         ['lo_recomiendo', '435'],
#         ['tecsun_pl', '429'],
#         ['str_dh', '424'],
#         ['str_dn', '421'],
#         ['andrew_jones', '410'],
#         ['scientific_atlanta', '407'],
#         ['jaybird_bluebuds', '393'],
#         ['pet_peeve', '380'],
#         ['kaito_ka', '370'],
#         ['geek_squad', '362'],
#         ['las_vegas', '344'],
#         ['lady_gaga', '341'],
#         ['oh_details_o', '336'],
#         ['slice_bread', '326'],
#         ['otterbox_defender', '321'],
#         ['sam_club', '319'],
#         ['horror_stories', '317'],
#         ['hurricane_sandy', '314'],
#         ['acer_aspire', '310'],
#         ['holy_cow', '302'],
#         ['kinivo_bn', '298'],
#         ['bi_amped', '294'],
#         ['strain_reliefs', '287'],
#         ['oregon_scientific', '285'],
#         ['supra_aural', '276'],
#         ['muy_bien', '274'],
#         ['muy_buen', '271'],
#         ['et_al', '270'],
#         ['oppo_bdp', '269'],
#         ['bone_conduction', '263'],
#         ['http_amzn', '256'],
#         ['burr_brown', '252'],
#         ['rp_hje', '250'],
#         ['barnes_noble', '249'],
#         ['nokia_lumia', '248'],
#         ['str_dg', '247'],
#         ['co_ax', '246'],
#         ['inkjet_printable', '245'],
#         ['mechanically_incline', '243'],
#         ['muy_bueno', '242'],
#         ['infinity_primus', '241'],
#         ['microwave_oven', '235'],
#         ['muy_buena', '235'],
#         ['bi_amping', '231'],
#         ['rp_hc', '223'],
#         ['razr_maxx', '223'],
#         ['excelente_producto', '221'],
#         ['holy_grail', '215'],
#         ['daft_punk', '215'],
#         ['snow_leopard', '215'],
#         ['parrot_zik', '211'],
#         ['san_jose', '210'],
#         ['att_uverse', '209'],
#         ['hockey_puck', '205'],
#         ['smoke_detectors', '201'],
#         ['senior_citizen', '199'],
#         ['dknight_magicbox', '195'],
#         ['maha_powerex', '195'],
#         ['southern_california', '194'],
#         ['ali_julia', '190'],
#         ['asus_xonar', '187'],
#         ['photive_cyren', '187'],
#         ['thermal_paste', '181'],
#         ['lenovo_thinkpad', '181'],
#         ['este_producto', '180'],
#         ['achilles_heel', '180'],
#         ['vsonic_gr', '180'],
#         ['emi_rfi', '179'],
#         ['baofeng_uv', '179'],
#         ['http_youtu', '176'],
#         ['elbow_grease', '176'],
#         ['plantronics_backbeat', '176'],
#         ['rm_vl', '176'],
#         ['lenovo_yoga', '174'],
#         ['ject_debut', '174'],
#         ['mon_fri', '169'],
#         ['michael_jackson', '169'],
#         ['droid_bionic', '168'],
#         ['bs_lr', '165'],
#         ['cerwin_vegas', '164'],
#         ['asus_eee', '163'],
#         ['radar_detector', '161'],
#         ['garmin_nuvi', '161'],
#         ['swiss_army', '158'],
#         ['ff_rew', '158'],
#         ['tornado_alley', '157'],
#         ['neil_young', '157'],
#         ['ni_cad', '157'],
#         ['maha_mh', '156'],
#         ['plantronics_voyager', '155'],
#         ['ultrasone_hfi', '154'],
#         ['audyssey_multeq', '153'],
#         ['fanny_wang', '152'],
#         ['fiber_optics', '150'],
#         ['toaster_oven', '149'],
#         ['frank_sinatra', '148'],
#         ['czech_republic', '147'],
#         ['rp_htx', '147'],
#         ['north_carolina', '146'],
#         ['lc_le', '144'],
#         ['gogear_vibe', '144'],
#         ['eagle_aspen', '144'],
#         ['jurassic_park', '141'],
#         ['rocket_scientist', '140'],
#         ['sams_club', '140'],
#         ['private_ryan', '140'],
#         ['slam_dunk', '139'],
#         ['bob_marley', '139'],
#         ['harbor_freight', '139'],
#         ['emotiva_xpa', '137'],
#         ['debbie_lee', '137'],
#         ['tread_mill', '135'],
#         ['bla_bla', '135'],
#         ['taotronics_tt', '134'],
#         ['astell_kern', '133'],
#         ['honda_civic', '133'],
#         ['vault_ceilings', '131'],
#         ['thermal_compound', '129'],
#         ['ref_', '129'],
#         ['buena_calidad', '129'],
#         ['symphonize_nrg', '126'],
#         ['debut_carbon', '126'],
#         ['mt_wilson', '126'],
#         ['gopro_hero', '125'],
#         ['martin_logans', '124'],
#         ['tenergy_centura', '121'],
#         ['astro_mixamp', '121'],
#         ['honda_odyssey', '120'],
#         ['winegard_lna', '119'],
#         ['wharfedale_diamond', '118'],
#         ['powerex_mh', '116'],
#         ['henry_kloss', '116'],
#         ['howard_stern', '113'],
#         ['jeep_wrangler', '112'],
#         ['dmp_bdt', '111'],
#         ['anc_quietpoint', '110'],
#         ['tron_legacy', '109'],
#         ['structural_integrity', '109'],
#         ['woo_hoo', '108'],
#         ['instant_gratification', '108'],
#         ['jds_labs', '107'],
#         ['sega_genesis', '106'],
#         ['rtl_sdr', '105'],
#         ['nitty_gritty', '105'],
#         ['rice_cooker', '105'],
#         ['hurricane_irene', '105'],
#         ['fh_lcr', '105'],
#         ['brooklyn_ny', '104'],
#         ['grundig_satellit', '104'],
#         ['jay_bird', '103'],
#         ['pig_tail', '103'],
#         ['rp_htf', '103'],
#         ['dd_wrt', '103'],
#         ['taylor_swift', '102'],
#         ['epson_artisan', '102'],
#         ['compaq_presario', '102'],
#         ['irobot_roomba', '102'],
#         ['mech_mod', '101'],
#         ['silk_dome', '101'],
#         ['powerpoint_presentations', '101'],
#         ['ati_radeon', '101'],
#         ['photive_bth', '99'],
#         ['schiit_magni', '98'],
#         ['paul_frank', '98'],
#         ['woefully_inadequate', '97'],
#         ['tj_maxx', '95'],
#         ['psc_redirect', '94'],
#         ['salvation_army', '93'],
#         ['jabra_revo', '92'],
#         ['lepai_tripath', '92'],
#         ['vise_versa', '91'],
#         ['ibasso_dx', '91'],
#         ['cdp_ce', '91'],
#         ['nvidia_gtx', '90'],
#         ['intel_nuc', '90'],
#         ['cmc_magnetics', '90'],
#         ['photive_hydra', '90'],
#         ['eric_clapton', '90'],
#         ['alpha_numeric', '90'],
#         ['srs_btx', '89'],
#         ['eagerly_await', '88'],
#         ['visa_versa', '87'],
#         ['anxiously_await', '86'],
#         ['azo_dye', '86'],
#         ['walkie_talkie', '86'],
#         ['schiit_modi', '85'],
#         ['bq_cc', '84'],
#         ['numeric_keypad', '84'],
#         ['fenix_tk', '84'],
#         ['yuin_pk', '84'],
#         ['viewsonic_pjd', '83'],
#         ['shoe_lace', '83'],
#         ['gun_roses', '83'],
#         ['nascar_race', '82'],
#         ['noontec_zoro', '81'],
#         ['isport_victory', '81'],
#         ['isopropyl_alcohol', '81'],
#         ['isport_immersion', '80'],
#         ['nvidia_geforce', '80'],
#         ['jabra_solemate', '80'],
#         ['unite_kingdom', '79'],
#         ['neodymium_magnets', '79'],
#         ['svs_pb', '79'],
#         ['kanye_west', '78'],
#         ['toyota_sienna', '78'],
#         ['hilly_terrain', '78'],
#         ['fl_flatwave', '78'],
#         ['xvt_sv', '78'],
#         ['gordon_brothers', '78'],
#         ['portland_oregon', '77'],
#         ['buen_producto', '77'],
#         ['exacto_knife', '77'],
#         ['nad_viso', '77'],
#         ['phoenix_az', '77'],
#         ['tek_pal', '77'],
#         ['ocean_reef', '77'],
#         ['fcc_gov', '76'],
#         ['pellet_stave', '76'],
#         ['kubik_evo', '76'],
#         ['tom_tom', '76'],
#         ['lil_wayne', '76'],
#         ['magnasonic_mag', '76'],
#         ['los_recomiendo', '76'],
#         ['oh_o', '76'],
#         ['trans_atlantic', '75'],
#         ['profit_margins', '75'],
#         ['dunu_dn', '75'],
#         ['arduino_uno', '74'],
#         ['chili_pepper', '74'],
#         ['elliptical_trainer', '74'],
#         ['evo_lte', '74'],
#         ['jelly_bean', '73'],
#         ['dav_hdx', '73'],
#         ['alpatronix_ax', '72'],
#         ['senior_citizens', '72'],
#         ['cm_cr_rdp_perm', '72'],
#         ['ferrite_bead', '72'],
#         ['american_idol', '72'],
#         ['jaybird_bluebud', '72'],
#         ['synology_nas', '71'],
#         ['eacute_cor', '71'],
#         ['highway_robbery', '71'],
#         ['gdi_irc', '71'],
#         ['fv_bb', '71'],
#         ['wreak_havoc', '70'],
#         ['pacific_rim', '70'],
#         ['skull_crushers', '70'],
#         ['utmost_importance', '70'],
#         ['beyerdynamic_edt', '69'],
#         ['stereophile_magazine', '69'],
#         ['estoy_muy', '69'],
#         ['circus_tent', '69'],
#         ['ge_superradio', '68'],
#         ['gdi_ira', '68'],
#         ['mdrrf_rk', '68'],
#         ['iron_maiden', '68'],
#         ['infinity_tss', '68'],
#         ['braven_brv', '67'],
#         ['ug_xw', '67'],
#         ['soundfreaq_sfq', '67'],
#         ['peanut_butter', '66'],
#         ['fenix_pd', '66'],
#         ['tt_sk', '66'],
#         ['mz_rh', '66'],
#         ['flathead_screwdriver', '65'],
#         ['south_carolina', '65'],
#         ['bob_dylan', '65'],
#         ['aether_cone', '65'],
#         ['cush_fin', '64'],
#         ['cathedral_ceilings', '63'],
#         ['ninja_turtle', '63'],
#         ['trans_pacific', '63'],
#         ['supertooth_disco', '62'],
#         ['kobo_aura', '62'],
#         ['homeworx_hw', '62'],
#         ['altec_lance', '62'],
#         ['kdl_hx', '62'],
#         ['geforce_gtx', '61'],
#         ['nes_snes', '61'],
#         ['scuba_dive', '61'],
#         ['medical_transcription', '61'],
#         ['oculus_rift', '61'],
#         ['riva_turbo', '60'],
#         ['winegard_freevision', '60'],
#         ['diesel_vektr', '60'],
#         ['rinky_dink', '60'],
#         ['notmad_explorer', '60'],
#         ['dental_floss', '59'],
#         ['pd_sim_e_', '59'],
#         ['steelseries_siberia', '59'],
#         ['kinivo_bth', '59'],
#         ['davis_tribute', '59'],
#         ['as_li_tl', '58'],
#         ['mis_expectativas', '58'],
#         ['pete_sake', '57'],
#         ['sledge_hammer', '57'],
#         ['toyota_camry', '57'],
#         ['todas_las', '57'],
#         ['infinite_wisdom', '56'],
#         ['tragus_pierce', '56'],
#         ['cotton_swab', '56'],
#         ['cirrus_logic', '55'],
#         ['mirage_omd', '55'],
#         ['perfecto_estado', '55'],
#         ['basketball_court', '54'],
#         ['mercedes_benz', '54'],
#         ['breast_cancer', '53'],
#         ['essence_stx', '53'],
#         ['schiit_asgard', '53'],
#         ['celebrity_endorse', '53'],
#         ['lawn_mowers', '53'],
#         ['tcc_tc', '52'],
#         ['beard_trimmer', '52'],
#         ['reign_supreme', '52'],
#         ['sewell_deadbolt', '52'],
#         ['gee_whiz', '52'],
#         ['smc_smt', '52'],
#         ['buen_precio', '52'],
#         ['jensen_jta', '51'],
#         ['muy_buenos', '51'],
#         ['schiit_lyr', '51'],
#         ['bald_eagle', '51'],
#         ['llego_tiempo', '51'],
#         ['sega_saturn', '50'],
#         ['zombie_apocalypse', '50'],
#         ['valley_enterprises', '50'],
#         ['schiit_bifrost', '50'],
#         ['slimx_imp', '50'],
#         ['rapid_succession', '49'],
#         ['john_williams', '49'],
#         ['arlington_lv', '49'],
#         ['thorens_td', '49'],
#         ['xiaomi_piston', '48'],
#         ['velodyne_vpulse', '48'],
#         ['louisville_ky', '48'],
#         ['parrot_ziks', '47'],
#         ['rohs_compliant', '47'],
#         ['tripp_lites', '47'],
#         ['wolfson_wm', '47'],
#         ['evga_gtx', '47'],
#         ['oss_product', '47'],
#         ['kimber_kable', '46'],
#         ['ecoxgear_ecoxbt', '46'],
#         ['symphonize_glxy', '45'],
#         ['lazy_susan', '45'],
#         ['upstate_ny', '45'],
#         ['athena_ivoice', '45'],
#         ['o_o', '44'],
#         ['emotiva_upa', '44'],
#         ['datacomm_wh', '44'],
#         ['xxx_xxx', '44'],
#         ['mdrzx_blk', '43'],
#         ['radiant_barrier', '43'],
#         ['sega_dreamcast', '43'],
#         ['etekcity_roverbeats', '42'],
#         ['icom_ic', '42'],
#         ['mow_lawns', '42'],
#         ['wms_ohs_product', '42'],
#         ['gogroove_airband', '42'],
#         ['goo_gl', '41'],
#         ['mediasonic_hw', '41'],
#         ['soundmatters_foxl', '41'],
#         ['toyota_tacoma', '40'],
#         ['soap_operas', '40'],
#         ['acto_knife', '40'],
#         ['krk_rokit', '40'],
#         ['richmond_va', '40'],
#         ['vw_jetta', '40'],
#         ['santa_fe', '40'],
#         ['entrega_fue', '40'],
#         ['sewell_silverback', '39'],
#         ['boombot_rex', '39'],
#         ['bruno_mar', '39'],
#         ['weed_eater', '39'],
#         ['jesus_christ', '39'],
#         ['hsp_hfp', '38'],
#         ['martial_arts', '38'],
#         ['x_', '38'],
#         ['mz_nh', '38'],
#         ['chit_chat', '37'],
#         ['nashville_tn', '37'],
#         ['gdi_btar', '37'],
#         ['scull_candy', '37'],
#         ['flammable_liquids', '37'],
#         ['razer_kraken', '36'],
#         ['laredo_texas', '36'],
#         ['nex_ia', '36'],
#         ['roomba_roomba', '36'],
#         ['mutually_exclusive', '35'],
#         ['emotiva_xda', '35'],
#         ['cjm_clearstream', '35'],
#         ['integra_dtr', '35'],
#         ['xw_sma', '34'],
#         ['buenas_condiciones', '34'],
#         ['buen_estado', '34'],
#         ['solitude_xcs', '33'],
#         ['braven_lux', '33'],
#         ['scream_meanie', '32'],
#         ['wacom_cintiq', '32'],
#         ['ann_arbor', '31'],
#         ['gusto_mucho', '31'],
#         ['buena_compra', '31'],
#         ['needlenose_pliers', '30'],
#         ['mpow_freego', '30'],
#         ['social_writeup', '30'],
#         ['paradigm_atoms', '29'],
#         ['rome_florence', '29'],
#         ['eyeglass_wearers', '29'],
#         ['federal_regulations', '29'],
#         ['iâ_tm', '29'],
#         ['poo_poo', '28'],
#         ['iomega_hipzip', '28'],
#         ['wireworld_starlight', '27'],
#         ['a_id', '21'],
#         ['cm_cr', '21'],
#         ['pd_cp_e_', '18'],
#         ['pe_', '17'],
#         ['cm_cr_pr_perm', '16'],
#         ['t_t', '15'],
#         ['revision_', '15'],
#         ['ntsc_m', '14'],
#         ['blu_ray', '14'],
#         ['video_ts', '13'],
#         ['jason_', '13'],
#         ['mp_s_a_', '12'],
#         ['service_info', '12'],
#         ['pd_sim_sbs_e_', '11'],
#         ['as_li_ss_tl', '11'],
#         ['pf_rd_m', '11'],
#         ['pf_rd_s', '11'],
#         ['pf_rd_r', '11'],
#         ['pf_rd_t', '11'],
#         ['pf_rd_p', '11'],
#         ['pf_rd_i', '11'],
#         ['xw_nas', '11'],
#         ['en_us', '10'],
#         ['cfb_at_prodpg', '10'],
#         ['cm_cr_dp_title', '10'],
#         ['mitchell_', '10'],
#         ['pro_eb', '10'],
#         ['nb_sb_noss_', '9'],
#         ['pal_b', '9'],
#         ['sr_ph', '9'],
#         ['active_pwr', '9'],
#         ['wp_', '8'],
#         ['nb_sb_noss', '8'],
#         ['pd_bbs_', '8'],
#         ['d_', '7'],
#         ['p_id', '7'],
#         ['pd_sim_', '7'],
#         ['cd_rw', '7'],
#         ['donald_', '7'],
#         ['utm_source', '6'],
#         ['utm_medium', '6'],
#         ['p_', '6'],
#         ['pd_bxgy_e_img_y', '6'],
#         ['s_', '6'],
#         ['amazon_bt', '6'],
#         ['nb_sb_ss_i_', '6'],
#         ['hdmi_mode', '6'],
#         ['cr_p', '6'],
#         ['zombie_x', '6'],
#         ['sammy_k', '6'],
#         ['sh_t', '6'],
#         ['pearl_jam', '6'],
#         ['post_', '5'],
#         ['dp_ob_title_ce', '5'],
#         ['pd_bxgy_', '5'],
#         ['cm_cd_asin_lnk', '5'],
#         ['cm_rdp_product', '5'],
#         ['cm_cr_dp_synop', '5'],
#         ['x_x', '5'],
#         ['page_headphones', '5'],
#         ['not_', '5'],
#         ['a__', '5'],
#         ['foo_upnp', '5'],
#         ['ds_store', '5'],
#         ['pct_amp', '5'],
#         ['d_skins', '5'],
#         ['time_set', '5'],
#         ['cm_cr_pr_sims_t', '4'],
#         ['cm_cr_thx_pdp', '4'],
#         ['headphone_price', '4'],
#         ['average_rating', '4'],
#         ['sound_rating', '4'],
#         ['build_rating', '4'],
#         ['comfort_rating', '4'],
#         ['vid_', '4'],
#         ['gno_cart_title_', '4'],
#         ['g_d', '4'],
#         ['hdmi_group', '4'],
#         ['hdmi_drive', '4'],
#         ['c_id', '4'],
#         ['cp_id', '4'],
#         ['cs_id', '4'],
#         ['tx_nr', '4'],
#         ['s__t', '4'],
#         ['s___', '4'],
#         ['o_', '4'],
#         ['i_pod', '4'],
#         ['low_', '4'],
#         ['med_', '4'],
#         ['product_id', '4'],
#         ['cm_cr_pr_pb_t', '4'],
#         ['price_', '4'],
#         ['hd_dvr', '4'],
#         ['l___', '4'],
#         ['go_to', '4'],
#         ['elechouse_cc', '4'],
#         ['dumas_mc', '4'],
#         ['t_', '4'],
#         ['lh_ni_t', '3'],
#         ['smdk_fat', '3'],
#         ['utm_campaign', '3'],
#         ['file_id', '3'],
#         ['aag_m_pw_dp', '3'],
#         ['ac_sx', '3'],
#         ['airmobi_xxxxxx', '3'],
#         ['cd_r', '3'],
#         ['sabrent_a', '3'],
#         ['pid_', '3'],
#         ['t_v', '3'],
#         ['sr_sp', '3'],
#         ['asset_id', '3'],
#         ['contact_us', '3'],
#         ['a_e', '3'],
#         ['p_m', '3'],
#         ['v_moda', '3'],
#         ['gigacity_amn', '3'],
#         ['plug_and_play', '3'],
#         ['cm_cr_dp_cmt', '3'],
#         ['system_', '3'],
#         ['nstc_m', '3'],
#         ['line_', '3'],
#         ['h_', '3'],
#         ['vcc_mcu', '3'],
#         ['category_id', '3'],
#         ['com_wrapper', '3'],
#         ['cc_', '3'],
#         ['pd_ys_iyr', '3'],
#         ['sort_by', '3'],
#         ['erpzb_vc', '3'],
#         ['e___', '3'],
#         ['n___', '3'],
#         ['period___', '3'],
#         ['pd_bxgy_e_img_b', '3'],
#         ['r_sng', '3'],
#         ['pd_rhf_p_t_', '3'],
#         ['dvd_rw', '3'],
#         ['ml_ipod', '3'],
#         ['cricket_post', '3'],
#         ['proven_choice', '3'],
#         ['a_', '3'],
#         ['happy_sellers', '3'],
#         ['your_dir', '3'],
#         ['ac_sy', '3'],
#         ['ok_sp', '3'],
#         ['psdc_', '3'],
#         ['earth_', '2'],
#         ['cm_cd_asin_link', '2'],
#         ['da__', '2'],
#         ['b_', '2'],
#         ['s____', '2'],
#         ['the_', '2'],
#         ['clip_', '2'],
#         ['model_search', '2'],
#         ['ser_linux_zip', '2'],
#         ['ser_mac_zip', '2'],
#         ['mengo_aquacube', '2'],
#         ['pd_sim_cps_', '2'],
#         ['pd_ybh_', '2'],
#         ['pd_cp_pc_', '2'],
#         ['pd_sxp_f_pt', '2'],
#         ['pd_sim_sg_', '2'],
#         ['rtl_tcp', '2'],
#         ['tv_protector', '2'],
#         ['bxyhwx_uhcc', '2'],
#         ['m____', '2'],
#         ['cm_cr_pr_cmt', '2'],
#         ['digital_modes', '2'],
#         ['mp_', '2'],
#         ['spdif_o', '2'],
#         ['buddy_boy', '2'],
#         ['s_video', '2'],
#         ['lp_', '2'],
#         ['aem_hbdo', '2'],
#         ['img_', '2'],
#         ['wa____k', '2'],
#         ['eq_mode', '2'],
#         ['t__t', '2'],
#         ['rtl_fm', '2'],
#         ['micro_sd', '2'],
#         ['cm_cr_thx_view', '2'],
#         ['atf_title_', '2'],
#         ['n_wn_', '2'],
#         ['twister_b', '2'],
#         ['hdmi_hdmi', '2'],
#         ['template_id', '2'],
#         ['region_id', '2'],
#         ['w_', '2'],
#         ['edit_', '2'],
#         ['dsp_corrections', '2'],
#         ['micca_mb', '2'],
#         ['star_power', '2'],
#         ['a_s', '2'],
#         ['song__', '2'],
#         ['b___', '2'],
#         ['glimp_', '2'],
#         ['rv_cl', '2'],
#         ['sox_eq', '2'],
#         ['hdmi_safe', '2'],
#         ['nu_force', '2'],
#         ['r_', '2'],
#         ['cm_cr_dp_pdp', '2'],
#         ['sdbr_pcdrv_l', '2'],
#         ['cable_', '2'],
#         ['sub_woofer', '2'],
#         ['biddeal_co', '2'],
#         ['u_s_b', '2'],
#         ['etc_', '2'],
#         ['aag_d_sh', '2'],
#         ['phi_log', '2'],
#         ['am_fm', '2'],
#         ['ip_d', '2'],
#         ['ntsc_m_j', '2'],
#         ['update_', '2'],
#         ['product_details', '2'],
#         ['noise_removal', '2'],
#         ['manual_en', '2'],
#         ['pd_cp_hi_', '2'],
#         ['techspec_index', '2'],
#         ['base_sku', '2'],
#         ['brightside_sc', '2'],
#         ['back_up', '2'],
#         ['common_gwzx', '2'],
#         ['foo_out_asio', '2'],
#         ['red_phones', '2'],
#         ['station_id', '2'],
#         ['wl_it_dp_o_pdt', '2'],
#         ['pd_sim_hi_', '2'],
#         ['sh__', '2'],
#         ['pre_out', '2'],
#         ['rev_', '2'],
#         ['ಠ_ಠ', '2'],
#         ['img_xxxx', '2'],
#         ['g_eng_esp', '2'],
#         ['seeyqkz_a', '2'],
#         ['aux_in', '2'],
#         ['high_vhf', '2'],
#         ['builtin_dd', '2'],
#         ['pd_sxp_grid_i_', '2'],
#         ['overscan_left', '2'],
#         ['overscan_right', '2'],
#         ['overscan_top', '2'],
#         ['overscan_bottom', '2'],
#         ['n_n', '2'],
#         ['red_rtn', '2'],
#         ['green_rtn', '2'],
#         ['blue_rtn', '2'],
#         ['cm_sw_su_dp', '2'],
#         ['dpe_', '2'],
#         ['time_', '2'],
#         ['vhs_c', '2'],
#         ['src_vid', '2'],
#         ['annotation_id', '2'],
#         ['annotation_', '2'],
#         ['guy_', '2'],
#         ['xonar_dg', '2'],
#         ['hq_', '2'],
#         ['roger_russell', '2'],
#         ['link_', '2'],
#         ['wl_it_dp_o_pc', '2'],
#         ['bo_e', '2'],
#         ['shopping_help', '2'],
#         ['trs_connector', '2'],
#         ['j_mount', '2'],
#         ['slo_o_o_o_owly', '2'],
#         ['sony_dvd', '2'],
#         ['external_sd', '2'],
#         ['v_o_r', '2'],
#         ['quality_', '2'],
#         ['works_', '2'],
#         ['quality___', '2'],
#         ['words___', '2'],
#         ['j_tech', '2'],
#         ['slightly_', '2'],
#         ['quality__', '2'],
#         ['thoughts__', '2'],
#         ['cameo_artists', '2'],
#         ['dvd_r', '2'],
#         ['gel_caps', '2'],
#         ['advertised_', '2'],
#         ['a___', '2'],
#         ['comma___', '2'],
#         ['ord_cart_shr', '2'],
#         ['to_', '2'],
#         ['vbus_present', '2'],
#         ['audio_ts', '2'],
#         ['fifty_bucks', '2'],
#         ['xy_', '2'],
#         ['trivial_', '2'],
#         ['c_', '2'],
#         ['microsoft_user', '2'],
#         ['packing_inc', '2'],
#         ['pd_bbs_sr_', '2'],
#         ['warehouse_deals', '2'],
#         ['ath_anc', '2'],
#         ['good_', '2'],
#         ['lame_enc', '2'],
#         ['chapter_', '2'],
#         ['enabled_', '2'],
#         ['sa_xr', '2'],
#         ['likely_', '2'],
#         ['onecall_com', '2'],
#         ['cm_aya_asin', '2'],
#         ['rionitrusflash_', '2'],
#         ['max_value', '2'],
#         ['fernando_f', '2'],
#         ['helen_n', '2'],
#         ['lot_', '2'],
#         ['trinity_', '2'],
#         ['title_', '2'],
#         ['e_drums', '2'],
#         ['mb_data', '2'],
#         ['prodfaq_', '2'],
#         ['how_', '2'],
#         ['pinky_powers', '2'],
#         ['aidozybq_', '2'],
#         ['input_', '2'],
#         ['output_', '2'],
#         ['max_mart', '2'],
#         ['p__k', '2'],
#         ['phone_', '1'],
#         ['kjgocyf_i', '1'],
#         ['instructions_', '1'],
#         ['olp_cg_pop', '1'],
#         ['soundmate_', '1'],
#         ['altitude_', '1'],
#         ['pd_sim_sbs_pc_', '1'],
#         ['sti_gl', '1'],
#         ['world_', '1'],
#         ['rene_roman', '1'],
#         ['cat_id', '1'],
#         ['v___', '1'],
#         ['utm_content', '1'],
#         ['m_kwz', '1'],
#         ['non_waterproof', '1'],
#         ['bafghwdh_', '1'],
#         ['w_a_y', '1'],
#         ['s_cked', '1'],
#         ['t___t', '1'],
#         ['p_dp_', '1'],
#         ['promo_key', '1'],
#         ['bi_amp', '1'],
#         ['com_content', '1'],
#         ['jc_sounds', '1'],
#         ['ambiance_', '1'],
#         ['sonnofa_______', '1'],
#         ['manual_frx', '1'],
#         ['fta_express', '1'],
#         ['trrs_standards', '1'],
#         ['over_the_ear', '1'],
#         ['white_thank', '1'],
#         ['woot_deals', '1'],
#         ['conrad_p', '1'],
#         ['e_ysjmv', '1'],
#         ['syl_scr', '1'],
#         ['com_frontpage', '1'],
#         ['dp_spec_v', '1'],
#         ['product_detail', '1'],
#         ['spk_velo', '1'],
#         ['station_finder', '1'],
#         ['rxyxgo_pmvs', '1'],
#         ['interphone_', '1'],
#         ['rate_converter', '1'],
#         ['speexrate_best', '1'],
#         ['zg_bs_', '1'],
#         ['pd_cp_mov_', '1'],
#         ['qmffmuet_o', '1'],
#         ['hl_', '1'],
#         ['mpu_', '1'],
#         ['g_dve', '1'],
#         ['airmobi_fcc', '1'],
#         ['rhkdil_', '1'],
#         ['snaec_ag', '1'],
#         ['br_other_cl', '1'],
#         ['liquidcristal_i', '1'],
#         ['rtl_', '1'],
#         ['specially_', '1'],
#         ['jewel_', '1'],
#         ['product_info', '1'],
#         ['products_id', '1'],
#         ['order___nice', '1'],
#         ['tv_wall_mounts', '1'],
#         ['cm_cd_ql_tlc_al', '1'],
#         ['dpd_sim_sg_', '1'],
#         ['onkyo_usa', '1'],
#         ['tv_dvr', '1'],
#         ['y_tepdy', '1'],
#         ['pd_cp_', '1'],
#         ['clear_', '1'],
#         ['bad_', '1'],
#         ['trtyiuop_', '1'],
#         ['rertyiop_', '1'],
#         ['all_service', '1'],
#         ['sales_pitch', '1'],
#         ['di_c', '1'],
#         ['was_er', '1'],
#         ['slippery_sleeve', '1'],
#         ['adpater_mini', '1'],
#         ['it_', '1'],
#         ['then_', '1'],
#         ['kindle_', '1'],
#         ['better_bought', '1'],
#         ['product_im', '1'],
#         ['btf_title_', '1'],
#         ['hk_aura', '1'],
#         ['h_t_c', '1'],
#         ['bi_wire', '1'],
#         ['pd_cp_k_', '1'],
#         ['mike_tina', '1'],
#         ['in_law', '1'],
#         ['udnxilq_x', '1'],
#         ['flat_', '1'],
#         ['start_up', '1'],
#         ['p__s', '1'],
#         ['molly_dog', '1'],
#         ['sh_', '1'],
#         ['ntt_srch_drd_b', '1'],
#         ['peking_hotels', '1'],
#         ['feat_diplo', '1'],
#         ['repeat_mode', '1'],
#         ['srs_wow', '1'],
#         ['b_repeat', '1'],
#         ['lyrics_sync', '1'],
#         ['delete_file', '1'],
#         ['d_re', '1'],
#         ['ultra_sturdy', '1'],
#         ['says_', '1'],
#         ['fallroman_i', '1'],
#         ['fallroman_ii', '1'],
#         ['d_ita', '1'],
#         ['x__', '1'],
#         ['plus_plus', '1'],
#         ['new_earbudi', '1'],
#         ['xx_psrp', '1'],
#         ['rnskm_', '1'],
#         ['wi_fi', '1'],
#         ['button_cell', '1'],
#         ['rtl_adr', '1'],
#         ['u_hooks', '1'],
#         ['e_son', '1'],
#         ['to_dvi', '1'],
#         ['guesst_t', '1'],
#         ['denon_e', '1'],
#         ['bl_sr_wireless', '1'],
#         ['on_', '1'],
#         ['brand_', '1'],
#         ['wal_', '1'],
#         ['ma__', '1'],
#         ['pin_', '1'],
#         ['kailani_jordan', '1'],
#         ['ciem_review', '1'],
#         ['utm_term', '1'],
#         ['yoga_style', '1'],
#         ['b__t', '1'],
#         ['b_y', '1'],
#         ['mlopez_', '1'],
#         ['mipow_boomax', '1'],
#         ['negative_aa', '1'],
#         ['airmobi_xxxx', '1'],
#         ['mysony_reciever', '1'],
#         ['fix_the_knob', '1'],
#         ['very_good', '1'],
#         ['d_a_b', '1'],
#         ['cons____', '1'],
#         ['z_fgek', '1'],
#         ['bert_', '1'],
#         ['hdmi_control', '1'],
#         ['docsis_system', '1'],
#         ['races_', '1'],
#         ['k_khz', '1'],
#         ['what_______', '1'],
#         ['version_', '1'],
#         ['suc_', '1'],
#         ['voltage_divider', '1'],
#         ['so_', '1'],
#         ['projector_', '1'],
#         ['any_questions', '1'],
#         ['b__', '1'],
#         ['c________d', '1'],
#         ['au_ction', '1'],
#         ['mike_helms', '1'],
#         ['ear_bud', '1'],
#         ['sp_c', '1'],
#         ['it_it', '1'],
#         ['iapp_controlapp', '1'],
#         ['cr_ppy', '1'],
#         ['fine_', '1'],
#         ['pinguy_os_', '1'],
#         ['like_pa', '1'],
#         ['l_cbl', '1'],
#         ['soundtouch_app', '1'],
#         ['m_audio', '1'],
#         ['mdr_', '1'],
#         ['m_series', '1'],
#         ['hdmi_switch', '1'],
#         ['sd_baja', '1'],
#         ['highres_', '1'],
#         ['k_____', '1'],
#         ['lame_ecn', '1'],
#         ['y_', '1'],
#         ['rip_off', '1'],
#         ['re_chargeable', '1'],
#         ['f___ck', '1'],
#         ['sylvie_rdlg', '1'],
#         ['twc_japan', '1'],
#         ['nelson_cartier', '1'],
#         ['n_blqfq', '1'],
#         ['on_for', '1'],
#         ['def_tech', '1'],
#         ['hp_common', '1'],
#         ['pre_amp', '1'],
#         ['mikjcgq_', '1'],
#         ['trsvyxyuo_m', '1'],
#         ['lkdqyx_koem', '1'],
#         ['tii_', '1'],
#         ['android_n', '1'],
#         ['m_rec', '1'],
#         ['de_p_', '1'],
#         ['bfilter_by', '1'],
#         ['reply_', '1'],
#         ['thumb_down', '1'],
#         ['p_qk', '1'],
#         ['jd_', '1'],
#         ['hsb_', '1'],
#         ['diagram_', '1'],
#         ['bs_', '1'],
#         ['adrian_landeira', '1'],
#         ['d_release', '1'],
#         ['zadig_xp_v', '1'],
#         ['zadig_v', '1'],
#         ['fahcore_', '1'],
#         ['eaeaea_', '1'],
#         ['one_battery', '1'],
#         ['aune_t', '1'],
#         ['basement_', '1'],
#         ['doxir_idwaw', '1'],
#         ['boot_delay', '1'],
#         ['bbp_s_iphone', '1'],
#         ['router_na', '1'],
#         ['review____', '1'],
#         ['this__', '1'],
#         ['dp_proddesc_', '1'],
#         ['crawl_', '1'],
#         ['girls_', '1'],
#         ['mini_book', '1'],
#         ['tv_dvd', '1'],
#         ['the_connection', '1'],
#         ['persist_app', '1'],
#         ['rom_v', '1'],
#         ['flypage_sc', '1'],
#         ['non_organic', '1'],
#         ['rm_hla', '1'],
#         ['pd_ys_iyr_img', '1'],
#         ['nema_connector', '1'],
#         ['extension_cord', '1'],
#         ['extension_cords', '1'],
#         ['live_sound', '1'],
#         ['pa_systems', '1'],
#         ['stagepas_', '1'],
#         ['b_buy', '1'],
#         ['sh_ts', '1'],
#         ['ex_bc', '1'],
#         ['e_r', '1'],
#         ['p_ds', '1'],
#         ['speaker_wire', '1'],
#         ['elephants_print', '1'],
#         ['menagerie_print', '1'],
#         ['here___', '1'],
#         ['d__che', '1'],
#         ['buds______', '1'],
#         ['product_', '1'],
#         ['batteries_', '1'],
#         ['cpu_fan', '1'],
#         ['amp_', '1'],
#         ['h_pas', '1'],
#         ['v_', '1'],
#         ['br_lf_m_', '1'],
#         ['sirius_xm', '1'],
#         ['hp_rel_topic', '1'],
#         ['f___ed', '1'],
#         ['eng_', '1'],
#         ['movie_', '1'],
#         ['perfect__', '1'],
#         ['blue_kanga', '1'],
#         ['ak_frost', '1'],
#         ['wsp_message', '1'],
#         ['m_f', '1'],
#         ['foo_input_dts', '1'],
#         ['foo_input_sacd', '1'],
#         ['pd_rhf_se_p_t_', '1'],
#         ['jphhq__rk', '1'],
#         ['radio_usb_si', '1'],
#         ['spdif_out', '1'],
#         ['music_lover', '1'],
#         ['amazing_deal', '1'],
#         ['limestone_lenny', '1'],
#         ['pd_cp_misc_', '1'],
#         ['worked_', '1'],
#         ['moore_', '1'],
#         ['view_question', '1'],
#         ['ypbpr_ansi', '1'],
#         ['headphone_pro', '1'],
#         ['leonard_bise', '1'],
#         ['dlfb_data', '1'],
#         ['fb_defio', '1'],
#         ['set_par', '1'],
#         ['son_kdf', '1'],
#         ['son_replacement', '1'],
#         ['however_', '1'],
#         ['sr_nr_p_', '1'],
#         ['cp_', '1'],
#         ['ha_eb', '1'],
#         ['plwitua_lhzlku', '1'],
#         ['dp_image_', '1'],
#         ['p_ssed', '1'],
#         ['b_o_l_s_e', '1'],
#         ['pd_sbs_sg_', '1'],
#         ['thought_how', '1'],
#         ['e_bikes', '1'],
#         ['kbt__inc', '1'],
#         ['sn_v', '1'],
#         ['chris_himself', '1'],
#         ['su_ks', '1'],
#         ['pdu_', '1'],
#         ['airzone_macaddr', '1'],
#         ['at_', '1'],
#         ['vj_vortex', '1'],
#         ['pr_', '1'],
#         ['pd_cp_vg_', '1'],
#         ['sr_st', '1'],
#         ['pl_', '1'],
#         ['handling_', '1'],
#         ['features_', '1'],
#         ['manual_oarno', '1'],
#         ['usb_sbt', '1'],
#         ['any_better_job', '1'],
#         ['buffer_get_ret', '1'],
#         ['buffer_get_int', '1'],
#         ['tractorbeam_u', '1'],
#         ['scout_outrack', '1'],
#         ['re_order', '1'],
#         ['cd_itrr', '1'],
#         ['shut_off', '1'],
#         ['usrp_interfaces', '1'],
#         ['i____', '1'],
#         ['bl_sr_mp', '1'],
#         ['display_', '1'],
#         ['fox_hd', '1'],
#         ['inch_', '1'],
#         ['gb_c', '1'],
#         ['tablet_w', '1'],
#         ['icf_s', '1'],
#         ['wl_mb_recs_', '1'],
#         ['wosang_pro', '1'],
#         ['play_', '1'],
#         ['pt_ae', '1'],
#         ['cm_cd_et_jump', '1'],
#         ['dec_trd_c', '1'],
#         ['dp_image_z_', '1'],
#         ['the_road', '1'],
#         ['pd_sbs_a_', '1'],
#         ['song_renumber', '1'],
#         ['setup____', '1'],
#         ['blue_ray', '1'],
#         ['tsx_', '1'],
#         ['g_grunfeld', '1'],
#         ['rp_sma', '1'],
#         ['lmr_', '1'],
#         ['rx_v', '1'],
#         ['great_very', '1'],
#         ['cain_ak', '1'],
#         ['number_', '1'],
#         ['l_v', '1'],
#         ['amzl_us', '1'],
#         ['yo_ii_img', '1'],
#         ['happy_', '1'],
#         ['et_pwifud', '1'],
#         ['silly_p', '1'],
#         ['recording_', '1'],
#         ['a____', '1'],
#         ['xonar_u', '1'],
#         ['xonar_dx', '1'],
#         ['yyy_seq', '1'],
#         ['mini_dv', '1'],
#         ['a_c', '1'],
#         ['pd_sxp_grid_pt_', '1'],
#         ['power_supply', '1'],
#         ['charging_source', '1'],
#         ['update____', '1'],
#         ['m_____r', '1'],
#         ['q_q', '1'],
#         ['marcosr_', '1'],
#         ['ir_manual', '1'],
#         ['jay_z', '1'],
#         ['stm_', '1'],
#         ['bk_shark', '1'],
#         ['dvi_d', '1'],
#         ['s______t', '1'],
#         ['just___', '1'],
#         ['v_v', '1'],
#         ['oss_rev', '1'],
#         ['true_depth', '1'],
#         ['v__v', '1'],
#         ['pd_vtp_e_', '1'],
#         ['vol_', '1'],
#         ['chpt_', '1'],
#         ['o_e', '1'],
#         ['in_ear', '1'],
#         ['sw_', '1'],
#         ['mdr_ed', '1'],
#         ['rock_it', '1'],
#         ['hdmi_cable', '1'],
#         ['pp_play', '1'],
#         ['i_phones', '1'],
#         ['ap_', '1'],
#         ['bit_w', '1'],
#         ['yusuf_burke', '1'],
#         ['pd_sbs_hg_', '1'],
#         ['watchespn_com', '1'],
#         ['ez_rc', '1'],
#         ['hd_ma', '1'],
#         ['isolation_____', '1'],
#         ['tracks____', '1'],
#         ['docks_base', '1'],
#         ['pre_paid', '1'],
#         ['dvi_adapter', '1'],
#         ['fault_', '1'],
#         ['shop_online', '1'],
#         ['isolation___', '1'],
#         ['fernando_r', '1'],
#         ['car_dvr', '1'],
#         ['r____o', '1'],
#         ['isolation__', '1'],
#         ['red_', '1'],
#         ['purple__', '1'],
#         ['pci_atsc_hybrid', '1'],
#         ['sb_', '1'],
#         ['dcr_dvd', '1'],
#         ['line_in', '1'],
#         ['wpa_supplicant', '1'],
#         ['tv_power', '1'],
#         ['tv_change', '1'],
#         ['avr_power', '1'],
#         ['avr_change', '1'],
#         ['box_power', '1'],
#         ['voipad_', '1'],
#         ['he__', '1'],
#         ['pa_', '1'],
#         ['shi_', '1'],
#         ['czech_kid', '1'],
#         ['i___', '1'],
#         ['f_', '1'],
#         ['asus_video', '1'],
#         ['follow_up', '1'],
#         ['bronco_', '1'],
#         ['photo_', '1'],
#         ['bit_', '1'],
#         ['size_', '1'],
#         ['shshs___', '1'],
#         ['days_', '1'],
#         ['dx_c', '1'],
#         ['up_directions', '1'],
#         ['tv_only', '1'],
#         ['os_id', '1'],
#         ['lord_ad', '1'],
#         ['g_sensor', '1'],
#         ['tv_', '1'],
#         ['one_m', '1'],
#         ['motherf___', '1'],
#         ['completely_', '1'],
#         ['dennis_aiken', '1'],
#         ['wal___t', '1'],
#         ['in_thy_light', '1'],
#         ['tom_fox', '1'],
#         ['wesv_lp', '1'],
#         ['properly_', '1'],
#         ['notes___', '1'],
#         ['har_har', '1'],
#         ['are_', '1'],
#         ['cd_dvd', '1'],
#         ['ezcap_vista', '1'],
#         ['powerdvd_', '1'],
#         ['s_fbvqvra', '1'],
#         ['he__l', '1'],
#         ['c____guys', '1'],
#         ['alcohol_', '1'],
#         ['fuse_protected', '1'],
#         ['alt_delete', '1'],
#         ['memories_on_tv', '1'],
#         ['j_hilbert', '1'],
#         ['major_league', '1'],
#         ['i_____', '1'],
#         ['pd_bxgy_e_img_c', '1'],
#         ['pd_zg_hrsr_e_', '1'],
#         ['user_interfaces', '1'],
#         ['h_hx_x', '1'],
#         ['pd_rate_rs', '1'],
#         ['gpio_in_pin', '1'],
#         ['gpio_out_pin', '1'],
#         ['best_buy_outlet', '1'],
#         ['dvd_writers', '1'],
#         ['ya_aw_oh_pii', '1'],
#         ['afternoon_', '1'],
#         ['icf_c', '1'],
#         ['whoop_', '1'],
#         ['all_', '1'],
#         ['wt_', '1'],
#         ['canon_power', '1'],
#         ['seconds_', '1'],
#         ['hanni_buzz', '1'],
#         ['wl_it_dp_o', '1'],
#         ['maker_period', '1'],
#         ['flash_drive', '1'],
#         ['microsd_reader', '1'],
#         ['mr_gt_mustang', '1'],
#         ['crackberry_com', '1'],
#         ['denon_avr', '1'],
#         ['a__ed', '1'],
#         ['dm_mu_dp_trk', '1'],
#         ['play_record', '1'],
#         ['front_back', '1'],
#         ['w___', '1'],
#         ['s_air', '1'],
#         ['up____________', '1'],
#         ['product_arrived', '1'],
#         ['if_tg', '1'],
#         ['brite_view', '1'],
#         ['b__se', '1'],
#         ['half_', '1'],
#         ['b__e', '1'],
#         ['as______', '1'],
#         ['oss_t', '1'],
#         ['pros________', '1'],
#         ['cons________', '1'],
#         ['rahul_bhatia', '1'],
#         ['lame_cam', '1'],
#         ['f__', '1'],
#         ['s__k', '1'],
#         ['elechouse_', '1'],
#         ['smart_parts_usa', '1'],
#         ['hd___', '1'],
#         ['ear_buds', '1'],
#         ['i______i', '1'],
#         ['effo_t', '1'],
#         ['daughte_', '1'],
#         ['p_egnant', '1'],
#         ['keyboa_d', '1'],
#         ['seve_al', '1'],
#         ['text__', '1'],
#         ['ima_adpcm', '1'],
#         ['hvdvd_ts', '1'],
#         ['cm_cr_wr_img', '1'],
#         ['rj_tech', '1'],
#         ['easycap_d', '1'],
#         ['bd_re', '1'],
#         ['swapnil_saloni', '1'],
#         ['but__', '1'],
#         ['clap_on', '1'],
#         ['sue_winner', '1'],
#         ['mount_be', '1'],
#         ['ifu_eng', '1'],
#         ['line____', '1'],
#         ['viking_usa', '1'],
#         ['high_', '1'],
#         ['datasheets_pdf', '1'],
#         ['c_amazon', '1'],
#         ['r_dl', '1'],
#         ['f_cking', '1'],
#         ['f_ucking', '1'],
#         ['clips___', '1'],
#         ['nec_optiarc', '1'],
#         ['black_', '1'],
#         ['edocs_public', '1'],
#         ['display_entry', '1'],
#         ['chp_vr', '1'],
#         ['one_sentence', '1'],
#         ['sound_', '1'],
#         ['looks_', '1'],
#         ['dvds_cds', '1'],
#         ['o_stk', '1'],
#         ['artist_name', '1'],
#         ['album_name', '1'],
#         ['av_receiver', '1'],
#         ['yourself_', '1'],
#         ['dvd_vcr', '1'],
#         ['atonline_com', '1'],
#         ['four_hundred', '1'],
#         ['beersheb_books', '1'],
#         ['s__thouse', '1'],
#         ['smv_encode', '1'],
#         ['scotland_ace', '1'],
#         ['mini_sd', '1'],
#         ['awesome_sound', '1'],
#         ['thumbs_up', '1'],
#         ['meaning_don', '1'],
#         ['player_it', '1'],
#         ['s__ks', '1'],
#         ['all__', '1'],
#         ['spoofed_ans', '1'],
#         ['o_oa', '1'],
#         ['jia_george', '1'],
#         ['clueless_', '1'],
#         ['eng_chi', '1'],
#         ['is_audio_player', '1'],
#         ['wma_pro', '1'],
#         ['screen_size', '1'],
#         ['device_size', '1'],
#         ['mdr_ex', '1'],
#         ['hours_', '1'],
#         ['znvm_pcpatch_la', '1'],
#         ['these_', '1'],
#         ['manner_', '1'],
#         ['hd_dvd', '1'],
#         ['dozen_', '1'],
#         ['box_', '1'],
#         ['rating_', '1'],
#         ['f___', '1'],
#         ['den_n', '1'],
#         ['chaper_', '1'],
#         ['db_hp', '1'],
#         ['dp_return_', '1'],
#         ['mad_lynn', '1'],
#         ['dihle_lvsve', '1'],
#         ['plug_in', '1'],
#         ['audio_input', '1'],
#         ['s_cks', '1'],
#         ['my_song', '1'],
#         ['cable_type', '1'],
#         ['b_s_', '1'],
#         ['thing_if', '1'],
#         ['gp_converter', '1'],
#         ['small_', '1'],
#         ['two_hundred', '1'],
#         ['sd_', '1'],
#         ['backwards_', '1'],
#         ['rf_', '1'],
#         ['st_jx', '1'],
#         ['steve_is', '1'],
#         ['sansa_m', '1'],
#         ['da_ned', '1'],
#         ['o_ou', '1'],
#         ['product_name', '1'],
#         ['mdr_v', '1'],
#         ['l__', '1'],
#         ['o__o', '1'],
#         ['fact_', '1'],
#         ['kio_ifp', '1'],
#         ['very_very', '1'],
#         ['j__', '1'],
#         ['p___', '1'],
#         ['i______', '1'],
#         ['pd_ecc_rvi_', '1'],
#         ['in_line', '1'],
#         ['filemanager_', '1'],
#         ['x_update_xxx', '1'],
#         ['installer_', '1'],
#         ['t_money_', '1'],
#         ['counter_strike', '1'],
#         ['wesleys_dad', '1'],
#         ['pd_sbs_e_', '1'],
#         ['jose_ambriz', '1'],
#         ['audible_alex', '1'],
#         ['the_strokes', '1'],
#         ['sor_ree', '1'],
#         ['billy_vandory', '1'],
#         ['lyra_sys', '1'],
#         ['fragile_', '1'],
#         ['cd_da', '1'],
#         ['hi_md', '1'],
#         ['shared_assets', '1'],
#         ['us_en', '1'],
#         ['joe_tomico', '1'],
#         ['iaudio_', '1'],
#         ['iaudio_u', '1'],
#         ['charges_', '1'],
#         ['beware_', '1'],
#         ['gen_pur', '1'],
#         ['sony_wm', '1'],
#         ['archos_devices', '1'],
#         ['comments__this', '1'],
#         ['x___', '1'],
#         ['s_lots_of', '1'],
#         ['i_love_having', '1'],
#         ['list_satish', '1'],
#         ['problem_____the', '1'],
#         ['natalie_wilson_', '1'],
#         ['a_name', '1'],
#         ['b_name', '1'],
#         ['c_name', '1'],
#         ['dvr_a', '1'],
#         ['im_no_angel', '1'],
#         ['my_life', '1'],
#         ['max_fum_eng', '1'],
#         ['max_fur_eng', '1'],
#         ['you_', '1'],
#         ['music_on', '1'],
#         ['commercials_off', '1'],
#         ['question_the', '1'],
#         ['reception_', '1'],
#         ['ranma_', '1'],
#         ['mdr_rf', '1'],
#         ['gadget_guy', '1'],
#         ['orion_', '1'],
#         ['dvd_rom', '1'],
#         ['ws_ftp', '1'],
#         ['neuf_', '1'],
#         ['magick_karma_', '1'],
#         ['rkelly_', '1'],
#         ['david_carlin', '1'],
#         ['cm_wl_huc_item', '1'],
#         ['theater__it', '1'],
#         ['oontz_xl', '1'],
#         ['vh_', '1'],
#         ['pixie_willner', '1'],
#         ['ql_nqs', '1'],
#         ['khv_k', '1'],
#         ['vdr_m', '1'],
#         ['formatter_', '1'],
#         ['dt___', '1'],
#         ['afqjcnghd_s', '1'],
#         ['y_k', '1'],
#         ['aogw_', '1'],
#         ['t_fwkrdbv', '1'],
#         ['u_', '1'],
#         ['bn_guide', '1'],
#         ['whatever_', '1'],
#         ['superlux_hd', '1'],
#         ['bzuukp_pbfk', '1'],
#         ['multi_voltage', '1'],
#         ['x_boom', '1'],
#         ['e_yl', '1'],
#         ['dream_', '1'],
#         ['sigh_', '1'],
#         ['weekend_', '1'],
#         ['roar_', '1'],
#         ['trails_', '1'],
#         ['bc_rsatb', '1'],
#         ['rc_keymaps', '1'],
#         ['rcfn_jdzuka', '1'],
#         ['most_powerful', '1'],
#         ['ti____', '1'],
#         ['bcb_', '1'],
#         ['jof_n', '1'],
#         ['sa_', '1'],
#         ['scr_wed', '1'],
#         ['cwhog_nlr', '1'],
#         ['product__i', '1'],
#         ['paosanhueza_', '1'],
#         ['d_skin', '1'],
#         ['my_vsonic_gr', '1'],
#         ['m_rsemrok', '1'],
#         ['h_ll', '1'],
#         ['p___ks', '1'],
#         ['lvxaohg_', '1'],
#         ['cm_sw_r_awd_rgt', '1'],
#         ['p_leftorright', '1'],
#         ['cm_sw_r_tw_acp', '1'],
#         ['accessories_tab', '1'],
#         ['indv_k', '1'],
#         ['lmhl__w', '1'],
#         ['h_ww', '1'],
#         ['bgg_p', '1'],
#         ['u_cja', '1'],
#         ['dst_g', '1'],
#         ['t_t_t_t_t_that', '1'],
#         ['again_____more', '1'],
#         ['memorex___drive', '1'],
#         ['power_sentry', '1'],
#         ['whole_', '1'],
#         ['i_manual', '1'],
#         ['lfqv_uya', '1'],
#         ['hd_sdi', '1'],
#         ['content_', '1'],
#         ['u_u', '1'],
#         ['music__', '1'],
#         ['nc_ztjkw', '1'],
#         ['kb_columns', '1'],
#         ['download_start', '1'],
#         ['vendor_info', '1'],
#         ['mmc_bdr', '1'],
#         ['layer_jump', '1'],
#         ['cm_sw_r_awd_rrw', '1'],
#         ['sr_ph_', '1'],
#         ['a_b', '1'],
#         ['call_______', '1'],
#         ['sr_nr_n_', '1'],
#         ['search_query', '1'],
#         ['pd_cp_p_', '1'],
#         ['dgmbrc_', '1'],
#         ['x_xywksbeiqa', '1'],
#         ['h_d_t_v', '1'],
#         ['srf_m', '1'],
#         ['component_video', '1'],
#         ['composite_video', '1'],
#         ['rd_generation', '1'],
#         ['qsg_s', '1'],
#         ['danger_efest_', '1'],
#         ['amp_and', '1'],
#         ['xycsuep_j', '1'],
#         ['stcroix_man', '1'],
#         ['soundmate_xxx', '1'],
#         ['jason_m', '1'],
#         ['hwcxjwz_lk', '1'],
#         ['bi_amp_able', '1'],
#         ['home_en', '1'],
#         ['h_d', '1'],
#         ['media_universe', '1'],
#         ['veriz_n', '1'],
#         ['pd_sim_pc_', '1'],
#         ['micros__t', '1'],
#         ['ignore_db', '1'],
#         ['b_at', '1'],
#         ['b_x', '1'],
#         ['b__s_', '1'],
#         ['c_ddvds', '1'],
#         ['abt_bm', '1'],
#         ['link_faqs', '1'],
#         ['흫_흫', '1'],
#         ['cm_cd_naredir', '1'],
#         ['slight_', '1'],
#         ['hdmi_which_one', '1'],
#         ['science_', '1'],
#         ['str_de', '1'],
#         ['ekhsibm_', '1'],
#         ['dvd_', '1'],
#         ['sc_', '1'],
#         ['topic_id', '1'],
#         ['as_sl_pc_ss_til', '1'],
#         ['znrg_mejhx', '1'],
#         ['th_quarter_', '1'],
#         ['bebzrig_pws', '1'],
#         ['veb_esgiekg', '1'],
#         ['u_infqiu', '1'],
#         ['muti_point', '1'],
#         ['cd_quality', '1'],
#         ['fbcpudu_qgy', '1'],
#         ['h_uc', '1'],
#         ['hx_p', '1'],
#         ['ehthfbmya_g', '1'],
#         ['q_', '1'],
#         ['package_', '1'],
#         ['main_sr', '1'],
#         ['boco_fw_wcb', '1'],
#         ['dot_clean', '1'],
#         ['up_great', '1'],
#         ['w_price', '1'],
#         ['wing_nuts', '1'],
#         ['nknbekc_e', '1'],
#         ['hdmi_', '1'],
#         ['david_underland', '1'],
#         ['speaker_', '1'],
#         ['soundlink_on', '1'],
#         ['htr_', '1'],
#         ['bee_dac', '1'],
#         ['resource_tools', '1'],
#         ['e_q', '1'],
#         ['m_vc', '1'],
#         ['um_', '1'],
#         ['a_rcr', '1'],
#         ['um_rcr', '1'],
#         ['pd_rhf_cr_s_cp_', '1'],
#         ['bluetooth_win', '1'],
#         ['ct_bw', '1'],
#         ['context_', '1'],
#         ['c____', '1']], dtype='<U24'))

# %% [markdown]
# ## All ngrams after Word2Vec - from ~1600 to 440

# %%
t = time()
print(time()-t,'s')
vocabW = np.array(sorted(list(w2v.wv.vocab.keys())))
print(time()-t,'s')
Wbigrams = np.array(list(set([str(gram) for gram in vocabW if str(gram).count('_') > 0])))
Wtrigrams = np.array(list(set([str(gram) for gram in vocabW if str(gram).count('_') > 1])))
print(time()-t,'s')
len(Wbigrams), len(Wtrigrams)
# Out:
# 4.9114227294921875e-05 s
# 0.01564192771911621 s
# 0.04405784606933594 s
# (440, 5)

# %%
Wbigrams
# Out:
# array(['oh_details_o', 'tivo_roamio', 'taiyo_yuden', 'soundmatters_foxl',
#        'nvidia_gtx', 'tx_nr', 'honda_civic', 'as_li_tl', 'co_ax',
#        'planar_magnetic', 'sewell_deadbolt', 'slimx_imp',
#        'infinity_primus', 'nomad_iic', 'tornado_alley',
#        'zombie_apocalypse', 'ultrasone_hfi', 'vsonic_gr', 'str_dh',
#        'san_jose', 'restock_fee', 'southern_california',
#        'thermal_compound', 'particle_board', 'hifimediy_sabre',
#        'schiit_bifrost', 'dknight_magicbox', 'arduino_uno', 'muy_bien',
#        'gordon_brothers', 'sams_club', 'tek_pal', 'jet_engines',
#        'golf_cart', 'inkjet_printable', 'honda_odyssey', 'el_precio',
#        'ali_julia', 'ni_cad', 'winegard_flatwave', 'singer_songwriter',
#        'slam_dunk', 'injection_mold', 'isport_victory', 'ta_da',
#        'harmon_kardon', 'fred_meyer', 'baofeng_uv', 'itty_bitty',
#        'jurassic_park', 'otterbox_defender', 'cyber_acoustics',
#        'lenovo_yoga', 'time_set', 'schiit_modi', 'fiber_optic',
#        'salvation_army', 'lawn_mower', 'cat_meow', 'nuforce_udac',
#        'flathead_screwdriver', 'lawn_mowers', 'muy_buen', 'smc_smt',
#        'toaster_oven', 'smoke_detectors', 'ge_superadio',
#        'moda_crossfade', 'cdp_ce', 'snow_leopard', 'beyerdynamic_edt',
#        'brooklyn_ny', 'jelly_bean', 'daft_punk', 'frequent_flyer',
#        'dave_matthews', 'howard_stern', 'vast_majority', 'pm_jess',
#        'michael_jackson', 'bs_lr', 'jay_bird', 'lepai_tripath',
#        'basketball_court', 'powerex_mh', 'verizon_fios',
#        'jaybird_bluebuds', 'x_', 'westone_um', 'dtv_gov', 'tl_dr',
#        'swiss_army', 'braven_brv', 'kobo_aura', 'tj_maxx', 'san_diego',
#        'pd_sim_e_', 'droid_razr', 'ninja_turtle', 'hair_dryers',
#        'symphonize_nrg', 'maha_powerex', 'timely_manner', 'powder_coat',
#        'lo_recomiendo', 'swag_swag', 'pipe_organ', 'yp_mt',
#        'american_idol', 'ice_cream', 'hp_pavilion', 'dell_inspiron',
#        'schiit_magni', 'powerpoint_presentations', 'kidz_gear',
#        'mech_mod', 'cp_avrlcd', 'roomba_roomba', 'cyber_monday',
#        'ject_debut', 'https_www', 'beyerdynamic_dt', 'http_www',
#        'emi_rfi', 'tread_mill', 'homeworx_hw', 'harman_kardon',
#        'bi_amping', 'nvidia_geforce', 'synology_nas', 'cyberpower_cp',
#        'krk_rokit', 'wms_ohs_product', 'strain_relief', 'svs_pb',
#        'cambridge_soundworks', 'prospective_buyers', 'south_carolina',
#        'et_al', 'vault_ceilings', 'neil_young', 'irobot_roomba',
#        'razr_maxx', 'muchas_gracias', 'clam_shell', 'kinivo_bth',
#        'bi_amped', 'dd_wrt', 'frank_sinatra', 'llego_tiempo',
#        'toyota_sienna', 'trans_atlantic', 'laser_pointer', 'tron_legacy',
#        'wal_mart', 'ref_', 'pacific_rim', 'cp_pfclcd', 'epson_ub',
#        'schiit_asgard', 'harbor_freight', 'john_williams', 'phoenix_az',
#        'law_enforcement', 'ath_anc', 'tripp_lite', 'celebrity_endorse',
#        'medical_transcription', 'ff_rew', 'horror_stories', 'el_producto',
#        'dental_floss', 'pvc_pipe', 'deadbolt_banana', 'allman_brothers',
#        'http_amzn', 'llego_en', 'ug_xw', 'epson_artisan', 'razor_blade',
#        'self_destruct', 'camden_square', 'jaybird_bluebud', 'att_uverse',
#        'kinivo_bn', 'martin_logan', 'buen_producto', 'dell_xps', 'str_da',
#        'velodyne_vpulse', 'hello_kitty', 'cm_cr_rdp_perm',
#        'skull_crushers', 'tt_sk', 'curl_iron', 'antennaweb_org',
#        'north_carolina', 'oh_o', 'allen_wrench', 'shortly_thereafter',
#        'wharfedale_diamond', 'nad_viso', 'bone_conduction',
#        'public_transportation', 'jeep_wrangler', 'anodize_aluminum',
#        'vw_jetta', 'riva_turbo', 'cigarette_lighter', 'passive_radiators',
#        'raspberry_pi', 'ibasso_dx', 'mt_wilson', 'fiber_optics',
#        'bower_wilkins', 'scientific_atlanta', 'hind_sight',
#        'exacto_knife', 'davis_tribute', 'ferrite_core', 'noontec_zoro',
#        'nose_pliers', 'bla_bla', 'emotiva_xpa', 'san_antonio', 'viera_tc',
#        'tenergy_centura', 'taotronics_tt', 'thinksound_ts',
#        'trans_pacific', 'rocket_science', 'kaito_ka', 'rice_cooker',
#        'lithium_polymer', 'murphy_law', 'microwave_oven', 'silk_dome',
#        'czech_republic', 'psc_redirect', 'supra_aural', 'mickey_mouse',
#        'ferrite_bead', 'intensity_shuttle', 'curtain_rod',
#        'lenovo_thinkpad', 'parrot_ziks', 'hilly_terrain', 'icom_ic',
#        'turtle_beach', 'rp_htx', 'ogg_vorbis', 'rockford_fosgate',
#        'dave_brubeck', 'pete_sake', 'twist_vein', 'plantronics_backbeat',
#        'peanut_butter', 'lithium_ion', 'yst_sw', 'al_vendedor',
#        'co_worker', 'photive_cyren', 'anxiously_await', 'cush_fin',
#        'shoe_lace', 'hurricane_sandy', 'structural_integrity',
#        'burr_brown', 'htc_evo', 'smsl_sa', 'los_recomiendo', 'rp_hje',
#        'str_dn', 'cerwin_vega', 'washington_dc', 'aether_cone',
#        'stainless_steel', 'jds_labs', 'co_workers', 'sega_saturn',
#        'dr_dre', 'icf_mk', 'soundbot_sb', 'tennis_ball', 'pig_tail',
#        'muy_buena', 'rp_sma', 'unite_kingdom', 'slice_bread',
#        'rocket_scientist', 'bic_venturi', 'numeric_keypad',
#        'radar_detector', 'acer_aspire', 'fenix_pd', 'excelente_producto',
#        'sr_', 'passive_radiator', 'neodymium_magnets', 'johnny_cash',
#        'sam_club', 'pet_peeve', 'xxx_xxx', 'bic_america', 'hall_mmf',
#        'instant_gratification', 'bach_toccata', 'elliptical_trainer',
#        'st_louis', 'kubik_evo', 'lc_le', 'hair_straightener',
#        'skull_candy', 'heaven_forbid', 'isopropyl_alcohol',
#        'toyota_tacoma', 'plantronics_voyager', 'buena_calidad',
#        'dell_latitude', 'grundig_satellit', 'ni_mh', 'li_ion', 'rp_hc',
#        'winegard_lna', 'videoid_mo', 'eric_clapton', 'nerve_wrack',
#        'krazy_glue', 'blah_blah', 'nes_snes', 'cerwin_vegas', 'oppo_bdp',
#        'taylor_swift', 'east_coast', 'intel_nuc', 'cathedral_ceilings',
#        'ati_radeon', 'bic_acoustech', 'sol_republic', 'tecsun_pl',
#        'woefully_inadequate', 'nintendo_ds', 'authorize_dealer',
#        'pink_floyd', 'mechanically_incline', 'jury_rig', 'este_producto',
#        'debut_carbon', 'raleigh_nc', 'bob_marley', 'tragus_pierce',
#        'senior_citizen', 'holy_cow', 'west_coast', 'angry_bird', 'la_vie',
#        'private_ryan', 'sine_wave', 'notmad_explorer', 'vice_versa',
#        'airport_express', 'thermal_paste', 'amd_radeon',
#        'situational_awareness', 'portta_pet', 'oregon_scientific',
#        'debbie_lee', 'sega_genesis', 'parrot_zik', 'asus_xonar',
#        'omni_directional', 'mz_rh', 'boston_acoustics', 'las_vegas',
#        'tcc_tc', 'buyers_remorse', 'maha_mh', 'weed_eater', 'dunu_dn',
#        'senior_citizens', 'photive_hydra', 'nascar_race', 'cotton_swab',
#        'fl_flatwave', 'photive_bth', 'mow_lawns', 'sc_hc', 'srs_btx',
#        'visa_versa', 'muy_buenos', 'xvt_sv', 'south_africa',
#        'andrew_jones', 'muy_bueno', 'hockey_puck', 'buyer_remorse',
#        'lil_wayne', 'bang_olufsen', 'fh_lcr', 'cyberpower_cpxxxpfclcd',
#        'fcc_gov', 'timely_manor', 'ie_utf', 'god_forbid',
#        'college_student', 'portland_oregon', 'severe_thunderstorm',
#        'barnes_noble', 'scuba_dive', 'jabra_revo', 'mohu_leaf',
#        'alpatronix_ax', 'faux_leather', 'blackberry_playbook',
#        'martin_logans', 'highway_robbery', 'todo_bien', 'astro_mixamp',
#        'altec_lansing', 'bare_bone', 'woo_hoo', 'bq_cc', 'anti_skate',
#        'jerry_rig', 'rtl_sdr', 'arlington_lv', 'str_dg', 'cirrus_logic',
#        'adversely_affect', 'kimber_kable', 'gopro_hero', 'iron_maiden',
#        'nad_bee', 'elbow_grease', 'nokia_lumia', 'dolby_truehd',
#        'vise_versa', 'bye_bye', 'steelseries_siberia', 'sight_unseen'],
#       dtype='<U24')
