# %% [markdown]
# ## From D11_full_attempt

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

import os
import sys
np.set_printoptions(threshold=sys.maxsize)

from time import time

from gensim.models import Word2Vec
from utils import meaning_test
                          

t=time()

# READ IN REVIEWS
print('Loading Dataset...')
E_tokened = pd.read_json('data/Electronics_tokenized_2.json')
print('Dataset Loaded: ', round(time()-t,2),'s')

processed_corpus = E_tokened.tokened

print('Training Word Embeddings...', round(time()-t,2),'s')

# # mc3, sz300, iter10, maxvocab10k
# w2v = Word2Vec(processed_corpus, # input tokenized text
#                  min_count=5,   # Ignore words that appear less than this
#                  size=300,      # Dimensionality of word embeddings
#                  workers=99,     # Number of processors (parallelisation)
#                  window=6,     # Context window for words during training
#                  max_vocab_size= 40*1000, #
#                  compute_loss=True,
#                  iter=10)       

w2v = Word2Vec.load('models/E_w2v_gensim10_2.model')
print('Trained', round(time()-t,2),'s')

print('# reviews: ', w2v.corpus_count)
print('Total words: ', w2v.corpus_total_words)
print('Latest Training Loss: ', w2v.get_latest_training_loss())
print('Vocab size: ', len(w2v.wv.vocab))

# w2v.save('models/E_w2v_gensim10_2.model')
print('Saved', round(time()-t,2),'s')


print('For fun, and for to test the word embeddings....')
print('Words most similar to *windows*.')
print(meaning_test(['windows'], None,  w2v))
print()
print('Words most similar to *Mac*.')
print(meaning_test(['mac'], None,  w2v))
print()
print('Words most similar to *cat*.')
print(meaning_test('cat', None, w2v))
print()
print('Words most similar to *father*.')
print(meaning_test('father', None, w2v))
print()
print('father + mother - boy')
print(meaning_test(['father','mother'],['boy'],w2v))
print()
print("Thanks :D. You're ready to run the main program!")
# Out:
# Loading Dataset...
# Dataset Loaded:  76.93 s
# Training Word Embeddings... 76.93 s
# Trained 77.61 s
# # reviews:  2836144
# Total words:  81666138
# Latest Training Loss:  12094783.0
# Vocab size:  18053
# Saved 77.61 s
# For fun, and for to test the word embeddings....
# Words most similar to *windows*.
#     words          similarity
# 0   winxp  0.6862816214561462
# 1   vista  0.6787523031234741
# 2  ubuntu  0.6680481433868408
# 3      os  0.6254222989082336
# 4   linux  0.6235475540161133
#
# Words most similar to *Mac*.
#           words          similarity
# 0          imac   0.687383770942688
# 1          macs  0.6585511565208435
# 2     mavericks  0.6501476764678955
# 3  snow_leopard  0.6488965153694153
# 4           osx   0.646578311920166
#
# Words most similar to *cat*.
#     words          similarity
# 0     utp  0.6351267695426941
# 1    gnaw  0.5743775963783264
# 2  kitten  0.5678672790527344
# 3   kitty  0.5519692301750183
# 4  baluns  0.5317671895027161
#
# Words most similar to *father*.
#     words          similarity
# 0  mother  0.8623847961425781
# 1     dad  0.7707857489585876
# 2     mom   0.727999210357666
# 3    aunt  0.7158770561218262
# 4  sister  0.6951234340667725
#
# father + mother - boy
#          words          similarity
# 0          mom  0.6373394131660461
# 1         aunt  0.6369031667709351
# 2  grandmother  0.6358923316001892
# 3          dad  0.6182491183280945
# 4       sister   0.570649266242981
#
# Thanks :D. You're ready to run the main program!

# %% [markdown]
# # <br>
# # Validation : ngrams

# %% [markdown]
# ### After:

# %%
t = time()
print(time()-t,'s')
vocabW = np.array(sorted(list(w2v.wv.vocab.keys())))
print(time()-t,'s')
Wbigrams = np.array(list(set([str(gram) for gram in vocabW if str(gram).count('_') > 0])))
Wtrigrams = np.array(list(set([str(gram) for gram in vocabW if str(gram).count('_') > 1])))
print(time()-t,'s')
len(Wbigrams), len(Wtrigrams)
# Out:
# 4.649162292480469e-05 s
# 0.01406240463256836 s
# 0.04240608215332031 s
# (440, 5)

# %%
(616, 22) # 1, 50k
(532, 5) # 3 , 50k
(33, 0) # 3 10k
(440, 5) # 5, 40k
# Out:
# (440, 5)

# %%
Wbigrams
# Out:
# array(['howard_stern', 'daft_punk', 'homeworx_hw', 'lenovo_yoga',
#        'weed_eater', 'ali_julia', 'god_forbid', 'supra_aural',
#        'parrot_ziks', 'ogg_vorbis', 'bic_acoustech', 'time_set',
#        'pete_sake', 'vault_ceilings', 'kinivo_bn', 'jabra_revo',
#        'nintendo_ds', 'skull_crushers', 'deadbolt_banana', 'el_producto',
#        'dell_xps', 'adversely_affect', 'mech_mod', 'pacific_rim',
#        'vice_versa', 'ge_superadio', 'bang_olufsen', 'honda_civic',
#        'winegard_lna', 'frank_sinatra', 'asus_xonar', 'schiit_asgard',
#        'american_idol', 'lc_le', 'anodize_aluminum', 'as_li_tl',
#        'braven_brv', 'toyota_tacoma', 'dd_wrt', 'roomba_roomba',
#        'harmon_kardon', 'neodymium_magnets', 'str_dh', 'noontec_zoro',
#        'yst_sw', 'slam_dunk', 'shoe_lace', 'faux_leather',
#        'soundmatters_foxl', 'droid_razr', 'bq_cc', 'ibasso_dx',
#        'isport_victory', 'honda_odyssey', 'bach_toccata', 'sc_hc',
#        'lo_recomiendo', 'pvc_pipe', 'elliptical_trainer',
#        'rocket_scientist', 'curtain_rod', 'verizon_fios', 'rice_cooker',
#        'x_', 'tivo_roamio', 'tcc_tc', 'highway_robbery', 'kobo_aura',
#        'razr_maxx', 'cotton_swab', 'rocket_science', 'kaito_ka',
#        'pipe_organ', 'mow_lawns', 'slice_bread', 'toyota_sienna',
#        'nose_pliers', 'hockey_puck', 'salvation_army', 'authorize_dealer',
#        'isopropyl_alcohol', 'burr_brown', 'czech_republic', 'iron_maiden',
#        'xvt_sv', 'jerry_rig', 'singer_songwriter', 'symphonize_nrg',
#        'las_vegas', 'soundbot_sb', 'cyberpower_cp', 'str_dn',
#        'maha_powerex', 'rp_htx', 'ultrasone_hfi', 'debut_carbon',
#        'murphy_law', 'trans_atlantic', 'emotiva_xpa', 'private_ryan',
#        'harbor_freight', 'hair_dryers', 'nad_viso', 'tragus_pierce',
#        'bic_america', 'winegard_flatwave', 'infinity_primus',
#        'schiit_magni', 'hp_pavilion', 'sega_genesis', 'bob_marley',
#        'grundig_satellit', 'cigarette_lighter', 'los_recomiendo',
#        'pm_jess', 'videoid_mo', 'south_africa', 'passive_radiator',
#        'llego_tiempo', 'nuforce_udac', 'krazy_glue',
#        'public_transportation', 'srs_btx', 'san_diego', 'thermal_paste',
#        'buyers_remorse', 'san_jose', 'hind_sight', 'lil_wayne',
#        'bi_amped', 'buen_producto', 'cyber_monday', 'riva_turbo',
#        'andrew_jones', 'dtv_gov', 'trans_pacific', 'jelly_bean',
#        'fiber_optics', 'bla_bla', 'oh_details_o', 'oppo_bdp',
#        'timely_manner', 'jeep_wrangler', 'johnny_cash', 'astro_mixamp',
#        'al_vendedor', 'celebrity_endorse', 'cerwin_vegas', 'ta_da',
#        'dave_matthews', 'frequent_flyer', 'gopro_hero', 'sams_club',
#        'heaven_forbid', 'airport_express', 'icom_ic',
#        'instant_gratification', 'cathedral_ceilings', 'llego_en',
#        'fcc_gov', 'ice_cream', 'nvidia_geforce', 'st_louis',
#        'strain_relief', 'peanut_butter', 'lawn_mowers', 'blah_blah',
#        'cirrus_logic', 'nokia_lumia', 'senior_citizens', 'lepai_tripath',
#        'jaybird_bluebud', 'cyberpower_cpxxxpfclcd', 'tennis_ball',
#        'vw_jetta', 'swiss_army', 'rtl_sdr', 'cp_avrlcd', 'neil_young',
#        'ninja_turtle', 'powder_coat', 'parrot_zik', 'laser_pointer',
#        'http_amzn', 'microwave_oven', 'flathead_screwdriver', 'str_dg',
#        'allen_wrench', 'harman_kardon', 'rp_hje', 'swag_swag', 'pig_tail',
#        'tek_pal', 'rp_hc', 'oh_o', 'muy_bueno', 'zombie_apocalypse',
#        'medical_transcription', 'senior_citizen', 'numeric_keypad',
#        'att_uverse', 'west_coast', 'yp_mt', 'bare_bone', 'bs_lr',
#        'intensity_shuttle', 'dr_dre', 'mt_wilson', 'washington_dc',
#        'tornado_alley', 'str_da', 'clam_shell', 'schiit_bifrost',
#        'portta_pet', 'baofeng_uv', 'wal_mart', 'jds_labs',
#        'mechanically_incline', 'jury_rig', 'co_workers', 'ni_cad',
#        'hilly_terrain', 'este_producto', 'velodyne_vpulse', 'east_coast',
#        'taylor_swift', 'cat_meow', 'cambridge_soundworks', 'sr_',
#        'elbow_grease', 'raleigh_nc', 'mz_rh', 'hurricane_sandy',
#        'bye_bye', 'passive_radiators', 'bic_venturi', 'ie_utf',
#        'cyber_acoustics', 'basketball_court', 'ath_anc', 'timely_manor',
#        'tripp_lite', 'lithium_ion', 'stainless_steel', 'synology_nas',
#        'kinivo_bth', 'golf_cart', 'structural_integrity',
#        'michael_jackson', 'cerwin_vega', 'ferrite_core', 'http_www',
#        'dolby_truehd', 'krk_rokit', 'wms_ohs_product', 'icf_mk',
#        'vsonic_gr', 'viera_tc', 'ug_xw', 'vise_versa', 'ff_rew',
#        'shortly_thereafter', 'martin_logans', 'visa_versa',
#        'eric_clapton', 'unite_kingdom', 'raspberry_pi', 'arlington_lv',
#        'toaster_oven', 'el_precio', 'schiit_modi', 'curl_iron', 'emi_rfi',
#        'dave_brubeck', 'powerpoint_presentations', 'epson_ub', 'la_vie',
#        'wharfedale_diamond', 'sine_wave', 'smsl_sa', 'lithium_polymer',
#        'ferrite_bead', 'svs_pb', 'smoke_detectors', 'nerve_wrack',
#        'altec_lansing', 'injection_mold', 'jet_engines',
#        'plantronics_backbeat', 'bower_wilkins', 'sol_republic',
#        'gordon_brothers', 'skull_candy', 'inkjet_printable',
#        'severe_thunderstorm', 'sega_saturn', 'cush_fin', 'powerex_mh',
#        'law_enforcement', 'bone_conduction', 'tt_sk', 'holy_cow',
#        'pd_sim_e_', 'ref_', 'snow_leopard', 'muy_buenos', 'ni_mh',
#        'fh_lcr', 'self_destruct', 'taotronics_tt', 'aether_cone',
#        'southern_california', 'tron_legacy', 'beyerdynamic_dt',
#        'photive_bth', 'turtle_beach', 'jay_bird', 'pink_floyd',
#        'fiber_optic', 'thinksound_ts', 'woo_hoo', 'allman_brothers',
#        'mohu_leaf', 'fenix_pd', 'fl_flatwave', 'muy_bien',
#        'woefully_inadequate', 'amd_radeon', 'sam_club', 'cm_cr_rdp_perm',
#        'ject_debut', 'maha_mh', 'et_al', 'kimber_kable', 'nes_snes',
#        'jaybird_bluebuds', 'scuba_dive', 'dell_latitude', 'tl_dr',
#        'south_carolina', 'dental_floss', 'itty_bitty', 'razor_blade',
#        'nomad_iic', 'exacto_knife', 'anxiously_await', 'pet_peeve',
#        'sewell_deadbolt', 'bi_amping', 'twist_vein', 'muy_buen',
#        'situational_awareness', 'planar_magnetic', 'nad_bee',
#        'nvidia_gtx', 'muchas_gracias', 'martin_logan', 'slimx_imp',
#        'xxx_xxx', 'silk_dome', 'acer_aspire', 'prospective_buyers',
#        'steelseries_siberia', 'hair_straightener', 'tj_maxx',
#        'excelente_producto', 'hello_kitty', 'hifimediy_sabre', 'co_ax',
#        'cp_pfclcd', 'tread_mill', 'smc_smt', 'debbie_lee', 'sight_unseen',
#        'photive_cyren', 'epson_artisan', 'college_student', 'rp_sma',
#        'lenovo_thinkpad', 'https_www', 'htc_evo', 'taiyo_yuden', 'tx_nr',
#        'oregon_scientific', 'portland_oregon', 'radar_detector',
#        'irobot_roomba', 'brooklyn_ny', 'co_worker', 'lawn_mower',
#        'north_carolina', 'boston_acoustics', 'plantronics_voyager',
#        'particle_board', 'san_antonio', 'todo_bien', 'phoenix_az',
#        'psc_redirect', 'li_ion', 'camden_square', 'westone_um',
#        'tecsun_pl', 'buena_calidad', 'thermal_compound', 'intel_nuc',
#        'hall_mmf', 'vast_majority', 'anti_skate', 'kidz_gear',
#        'buyer_remorse', 'scientific_atlanta', 'ati_radeon',
#        'beyerdynamic_edt', 'dell_inspiron', 'photive_hydra',
#        'barnes_noble', 'dknight_magicbox', 'antennaweb_org',
#        'blackberry_playbook', 'nascar_race', 'mickey_mouse',
#        'moda_crossfade', 'otterbox_defender', 'cdp_ce',
#        'omni_directional', 'restock_fee', 'john_williams', 'muy_buena',
#        'fred_meyer', 'tenergy_centura', 'jurassic_park', 'horror_stories',
#        'angry_bird', 'dunu_dn', 'rockford_fosgate', 'alpatronix_ax',
#        'arduino_uno', 'notmad_explorer', 'davis_tribute', 'kubik_evo'],
#       dtype='<U24')

# %% [markdown]
# ### Before:

# %%
ngrams = []
for review in processed_corpus:
    for tok in review:
        if '_' in tok:
            ngrams.append(tok)
            
len(np.array(list(set(ngrams)))), np.array(list(set(ngrams)))

from utils import kw2counts
counts = kw2counts(processed_corpus)
ngram_counts = np.array([tup for tup in counts if '_' in tup[0]])
ngram_counts.shape, ngram_counts
# Out:
# ((1710, 2), array([['skull_candy', '4827'],
#         ['altec_lansing', '4221'],
#         ['http_www', '4219'],
#         ['timely_manner', '3492'],
#         ['dr_dre', '3332'],
#         ['tripp_lite', '3038'],
#         ['swag_swag', '2987'],
#         ['harman_kardon', '2767'],
#         ['wal_mart', '2639'],
#         ['mohu_leaf', '2264'],
#         ['tx_nr', '2111'],
#         ['boston_acoustics', '1726'],
#         ['harmon_kardon', '1605'],
#         ['ie_utf', '1570'],
#         ['airport_express', '1516'],
#         ['strain_relief', '1516'],
#         ['co_workers', '1329'],
#         ['li_ion', '1297'],
#         ['turtle_beach', '1291'],
#         ['lithium_ion', '1288'],
#         ['raspberry_pi', '1278'],
#         ['fiber_optic', '1219'],
#         ['vice_versa', '1198'],
#         ['ni_mh', '1184'],
#         ['martin_logan', '1160'],
#         ['college_student', '1145'],
#         ['sol_republic', '1123'],
#         ['sine_wave', '1104'],
#         ['videoid_mo', '1093'],
#         ['verizon_fios', '1080'],
#         ['cigarette_lighter', '1065'],
#         ['allen_wrench', '1047'],
#         ['cambridge_soundworks', '1043'],
#         ['cerwin_vega', '998'],
#         ['ath_anc', '987'],
#         ['restock_fee', '954'],
#         ['stainless_steel', '912'],
#         ['co_worker', '887'],
#         ['taiyo_yuden', '878'],
#         ['twist_vein', '855'],
#         ['pink_floyd', '780'],
#         ['blah_blah', '723'],
#         ['authorize_dealer', '707'],
#         ['bic_america', '702'],
#         ['curl_iron', '685'],
#         ['hello_kitty', '685'],
#         ['sr_', '682'],
#         ['south_africa', '653'],
#         ['beyerdynamic_dt', '641'],
#         ['tl_dr', '636'],
#         ['antennaweb_org', '601'],
#         ['moda_crossfade', '600'],
#         ['particle_board', '598'],
#         ['omni_directional', '594'],
#         ['faux_leather', '561'],
#         ['vast_majority', '554'],
#         ['san_diego', '538'],
#         ['htc_evo', '534'],
#         ['bower_wilkins', '533'],
#         ['dell_inspiron', '509'],
#         ['https_www', '502'],
#         ['golf_cart', '496'],
#         ['rocket_science', '452'],
#         ['lawn_mower', '445'],
#         ['bye_bye', '436'],
#         ['lo_recomiendo', '435'],
#         ['tecsun_pl', '429'],
#         ['str_dh', '424'],
#         ['str_dn', '421'],
#         ['dell_xps', '412'],
#         ['andrew_jones', '410'],
#         ['bare_bone', '407'],
#         ['scientific_atlanta', '407'],
#         ['jaybird_bluebuds', '393'],
#         ['public_transportation', '383'],
#         ['pet_peeve', '380'],
#         ['kaito_ka', '370'],
#         ['dolby_truehd', '364'],
#         ['cyber_monday', '361'],
#         ['nintendo_ds', '353'],
#         ['el_producto', '351'],
#         ['las_vegas', '344'],
#         ['bang_olufsen', '340'],
#         ['ogg_vorbis', '336'],
#         ['oh_details_o', '336'],
#         ['clam_shell', '331'],
#         ['slice_bread', '326'],
#         ['otterbox_defender', '321'],
#         ['washington_dc', '321'],
#         ['anti_skate', '320'],
#         ['droid_razr', '320'],
#         ['sam_club', '319'],
#         ['angry_bird', '318'],
#         ['horror_stories', '317'],
#         ['east_coast', '317'],
#         ['cyber_acoustics', '315'],
#         ['hurricane_sandy', '314'],
#         ['acer_aspire', '310'],
#         ['powder_coat', '304'],
#         ['holy_cow', '302'],
#         ['kinivo_bn', '298'],
#         ['st_louis', '296'],
#         ['bi_amped', '294'],
#         ['nose_pliers', '287'],
#         ['oregon_scientific', '285'],
#         ['west_coast', '280'],
#         ['supra_aural', '276'],
#         ['hp_pavilion', '276'],
#         ['muy_bien', '274'],
#         ['jet_engines', '274'],
#         ['passive_radiator', '272'],
#         ['muy_buen', '271'],
#         ['et_al', '270'],
#         ['oppo_bdp', '269'],
#         ['ferrite_core', '267'],
#         ['bone_conduction', '263'],
#         ['http_amzn', '256'],
#         ['prospective_buyers', '253'],
#         ['buyer_remorse', '252'],
#         ['burr_brown', '252'],
#         ['cyberpower_cp', '251'],
#         ['rp_hje', '250'],
#         ['barnes_noble', '249'],
#         ['nokia_lumia', '248'],
#         ['str_dg', '247'],
#         ['co_ax', '246'],
#         ['inkjet_printable', '245'],
#         ['mechanically_incline', '243'],
#         ['muy_bueno', '242'],
#         ['infinity_primus', '241'],
#         ['microwave_oven', '235'],
#         ['muy_buena', '235'],
#         ['hair_dryers', '234'],
#         ['bi_amping', '231'],
#         ['shortly_thereafter', '228'],
#         ['rp_hc', '223'],
#         ['excelente_producto', '221'],
#         ['icf_mk', '220'],
#         ['dell_latitude', '216'],
#         ['passive_radiators', '216'],
#         ['buyers_remorse', '215'],
#         ['daft_punk', '215'],
#         ['snow_leopard', '215'],
#         ['sight_unseen', '213'],
#         ['parrot_zik', '211'],
#         ['san_jose', '210'],
#         ['att_uverse', '209'],
#         ['hockey_puck', '205'],
#         ['smoke_detectors', '201'],
#         ['sc_hc', '200'],
#         ['senior_citizen', '199'],
#         ['god_forbid', '197'],
#         ['pvc_pipe', '197'],
#         ['dknight_magicbox', '195'],
#         ['maha_powerex', '195'],
#         ['southern_california', '194'],
#         ['laser_pointer', '191'],
#         ['ali_julia', '190'],
#         ['self_destruct', '190'],
#         ['westone_um', '190'],
#         ['asus_xonar', '187'],
#         ['severe_thunderstorm', '187'],
#         ['photive_cyren', '187'],
#         ['yst_sw', '183'],
#         ['thermal_paste', '181'],
#         ['lenovo_thinkpad', '181'],
#         ['str_da', '181'],
#         ['este_producto', '180'],
#         ['vsonic_gr', '180'],
#         ['emi_rfi', '179'],
#         ['baofeng_uv', '179'],
#         ['itty_bitty', '178'],
#         ['razor_blade', '176'],
#         ['elbow_grease', '176'],
#         ['plantronics_backbeat', '176'],
#         ['rm_vl', '176'],
#         ['lenovo_yoga', '174'],
#         ['ject_debut', '174'],
#         ['tivo_roamio', '173'],
#         ['jury_rig', '169'],
#         ['michael_jackson', '169'],
#         ['ice_cream', '169'],
#         ['tennis_ball', '166'],
#         ['bs_lr', '165'],
#         ['cerwin_vegas', '164'],
#         ['mickey_mouse', '161'],
#         ['radar_detector', '161'],
#         ['garmin_nuvi', '161'],
#         ['rockford_fosgate', '161'],
#         ['hair_straightener', '159'],
#         ['swiss_army', '158'],
#         ['ff_rew', '158'],
#         ['tornado_alley', '157'],
#         ['neil_young', '157'],
#         ['ni_cad', '157'],
#         ['maha_mh', '156'],
#         ['plantronics_voyager', '155'],
#         ['blackberry_playbook', '154'],
#         ['ultrasone_hfi', '154'],
#         ['cp_pfclcd', '153'],
#         ['fiber_optics', '150'],
#         ['toaster_oven', '149'],
#         ['frank_sinatra', '148'],
#         ['czech_republic', '147'],
#         ['pipe_organ', '147'],
#         ['rp_htx', '147'],
#         ['north_carolina', '146'],
#         ['ge_superadio', '145'],
#         ['viera_tc', '145'],
#         ['lc_le', '144'],
#         ['san_antonio', '142'],
#         ['thinksound_ts', '142'],
#         ['jurassic_park', '141'],
#         ['rocket_scientist', '140'],
#         ['sams_club', '140'],
#         ['private_ryan', '140'],
#         ['slam_dunk', '139'],
#         ['bob_marley', '139'],
#         ['harbor_freight', '139'],
#         ['kidz_gear', '138'],
#         ['jerry_rig', '138'],
#         ['epson_ub', '137'],
#         ['emotiva_xpa', '137'],
#         ['debbie_lee', '137'],
#         ['tread_mill', '135'],
#         ['bla_bla', '135'],
#         ['taotronics_tt', '134'],
#         ['honda_civic', '133'],
#         ['vault_ceilings', '131'],
#         ['el_precio', '130'],
#         ['thermal_compound', '129'],
#         ['ref_', '129'],
#         ['buena_calidad', '129'],
#         ['rp_sma', '127'],
#         ['nomad_iic', '127'],
#         ['soundbot_sb', '126'],
#         ['symphonize_nrg', '126'],
#         ['debut_carbon', '126'],
#         ['timely_manor', '126'],
#         ['mt_wilson', '126'],
#         ['gopro_hero', '125'],
#         ['nuforce_udac', '125'],
#         ['ta_da', '125'],
#         ['martin_logans', '124'],
#         ['tenergy_centura', '121'],
#         ['curtain_rod', '121'],
#         ['canon_eos', '121'],
#         ['astro_mixamp', '121'],
#         ['honda_odyssey', '120'],
#         ['winegard_lna', '119'],
#         ['anodize_aluminum', '119'],
#         ['wharfedale_diamond', '118'],
#         ['powerex_mh', '116'],
#         ['frequent_flyer', '114'],
#         ['howard_stern', '113'],
#         ['jeep_wrangler', '112'],
#         ['lithium_polymer', '110'],
#         ['tron_legacy', '109'],
#         ['structural_integrity', '109'],
#         ['dave_matthews', '108'],
#         ['woo_hoo', '108'],
#         ['instant_gratification', '108'],
#         ['jds_labs', '107'],
#         ['sega_genesis', '106'],
#         ['planar_magnetic', '106'],
#         ['intensity_shuttle', '106'],
#         ['rtl_sdr', '105'],
#         ['rice_cooker', '105'],
#         ['nad_bee', '105'],
#         ['fh_lcr', '105'],
#         ['brooklyn_ny', '104'],
#         ['grundig_satellit', '104'],
#         ['jay_bird', '103'],
#         ['pig_tail', '103'],
#         ['dd_wrt', '103'],
#         ['llego_en', '103'],
#         ['taylor_swift', '102'],
#         ['epson_artisan', '102'],
#         ['compaq_presario', '102'],
#         ['irobot_roomba', '102'],
#         ['mech_mod', '101'],
#         ['silk_dome', '101'],
#         ['powerpoint_presentations', '101'],
#         ['ati_radeon', '101'],
#         ['photive_bth', '99'],
#         ['schiit_magni', '98'],
#         ['bic_acoustech', '98'],
#         ['cat_meow', '97'],
#         ['woefully_inadequate', '97'],
#         ['razr_maxx', '96'],
#         ['tj_maxx', '95'],
#         ['psc_redirect', '95'],
#         ['heaven_forbid', '95'],
#         ['ss_cn', '94'],
#         ['salvation_army', '93'],
#         ['johnny_cash', '93'],
#         ['jabra_revo', '92'],
#         ['lepai_tripath', '92'],
#         ['vise_versa', '91'],
#         ['ibasso_dx', '91'],
#         ['cdp_ce', '91'],
#         ['nvidia_gtx', '90'],
#         ['intel_nuc', '90'],
#         ['winegard_flatwave', '90'],
#         ['photive_hydra', '90'],
#         ['eric_clapton', '90'],
#         ['alpha_numeric', '90'],
#         ['srs_btx', '89'],
#         ['situational_awareness', '87'],
#         ['visa_versa', '87'],
#         ['anxiously_await', '86'],
#         ['calidad_del', '86'],
#         ['schiit_modi', '85'],
#         ['cough_cough', '85'],
#         ['bq_cc', '84'],
#         ['numeric_keypad', '84'],
#         ['adversely_affect', '84'],
#         ['shoe_lace', '83'],
#         ['muchas_gracias', '83'],
#         ['nascar_race', '82'],
#         ['noontec_zoro', '81'],
#         ['isport_victory', '81'],
#         ['isopropyl_alcohol', '81'],
#         ['isport_immersion', '80'],
#         ['nvidia_geforce', '80'],
#         ['unite_kingdom', '79'],
#         ['neodymium_magnets', '79'],
#         ['svs_pb', '79'],
#         ['toyota_sienna', '78'],
#         ['hilly_terrain', '78'],
#         ['fl_flatwave', '78'],
#         ['xvt_sv', '78'],
#         ['gordon_brothers', '78'],
#         ['portland_oregon', '77'],
#         ['buen_producto', '77'],
#         ['exacto_knife', '77'],
#         ['nad_viso', '77'],
#         ['phoenix_az', '77'],
#         ['tek_pal', '77'],
#         ['ocean_reef', '77'],
#         ['fcc_gov', '76'],
#         ['law_enforcement', '76'],
#         ['kubik_evo', '76'],
#         ['tom_tom', '76'],
#         ['lil_wayne', '76'],
#         ['los_recomiendo', '76'],
#         ['oh_o', '76'],
#         ['smsl_sa', '75'],
#         ['trans_atlantic', '75'],
#         ['dunu_dn', '75'],
#         ['arduino_uno', '74'],
#         ['elliptical_trainer', '74'],
#         ['jelly_bean', '73'],
#         ['krazy_glue', '73'],
#         ['alpatronix_ax', '72'],
#         ['senior_citizens', '72'],
#         ['cm_cr_rdp_perm', '72'],
#         ['ferrite_bead', '72'],
#         ['american_idol', '72'],
#         ['jaybird_bluebud', '72'],
#         ['microwave_ovens', '72'],
#         ['synology_nas', '71'],
#         ['highway_robbery', '71'],
#         ['dave_brubeck', '70'],
#         ['pacific_rim', '70'],
#         ['skull_crushers', '70'],
#         ['beyerdynamic_edt', '69'],
#         ['injection_mold', '69'],
#         ['nokia_bh', '69'],
#         ['estoy_muy', '69'],
#         ['yht_bl', '69'],
#         ['iron_maiden', '68'],
#         ['braven_brv', '67'],
#         ['ug_xw', '67'],
#         ['portta_pet', '66'],
#         ['peanut_butter', '66'],
#         ['brightech_brightplay', '66'],
#         ['fenix_pd', '66'],
#         ['tt_sk', '66'],
#         ['mz_rh', '66'],
#         ['flathead_screwdriver', '65'],
#         ['south_carolina', '65'],
#         ['urbanite_xl', '65'],
#         ['hind_sight', '65'],
#         ['aether_cone', '65'],
#         ['cush_fin', '64'],
#         ['cp_avrlcd', '64'],
#         ['nay_sayers', '64'],
#         ['shovel_snow', '64'],
#         ['singer_songwriter', '64'],
#         ['cathedral_ceilings', '63'],
#         ['ninja_turtle', '63'],
#         ['trans_pacific', '63'],
#         ['raleigh_nc', '62'],
#         ['kobo_aura', '62'],
#         ['bic_venturi', '62'],
#         ['homeworx_hw', '62'],
#         ['camden_square', '62'],
#         ['geforce_gtx', '61'],
#         ['nes_snes', '61'],
#         ['scuba_dive', '61'],
#         ['medical_transcription', '61'],
#         ['riva_turbo', '60'],
#         ['diesel_vektr', '60'],
#         ['yp_mt', '60'],
#         ['notmad_explorer', '60'],
#         ['fred_meyer', '59'],
#         ['dental_floss', '59'],
#         ['murphy_law', '59'],
#         ['pd_sim_e_', '59'],
#         ['steelseries_siberia', '59'],
#         ['dtv_gov', '59'],
#         ['kinivo_bth', '59'],
#         ['davis_tribute', '59'],
#         ['as_li_tl', '58'],
#         ['pete_sake', '57'],
#         ['deadbolt_banana', '57'],
#         ['nerve_wrack', '57'],
#         ['hall_mmf', '57'],
#         ['behave_erratically', '57'],
#         ['infinite_wisdom', '56'],
#         ['tragus_pierce', '56'],
#         ['cotton_swab', '56'],
#         ['cirrus_logic', '55'],
#         ['frequent_flier', '55'],
#         ['pm_jess', '55'],
#         ['basketball_court', '54'],
#         ['kickstarter_campaign', '54'],
#         ['hsu_vtf', '54'],
#         ['schiit_asgard', '53'],
#         ['latex_gloves', '53'],
#         ['celebrity_endorse', '53'],
#         ['lawn_mowers', '53'],
#         ['bach_toccata', '53'],
#         ['tcc_tc', '52'],
#         ['la_vie', '52'],
#         ['sewell_deadbolt', '52'],
#         ['smc_smt', '52'],
#         ['muy_buenos', '51'],
#         ['bald_eagle', '51'],
#         ['bruce_springsteen', '51'],
#         ['llego_tiempo', '51'],
#         ['sega_saturn', '50'],
#         ['zombie_apocalypse', '50'],
#         ['schiit_bifrost', '50'],
#         ['headfi_org', '50'],
#         ['slimx_imp', '50'],
#         ['rapid_succession', '49'],
#         ['john_williams', '49'],
#         ['arlington_lv', '49'],
#         ['xiaomi_piston', '48'],
#         ['velodyne_vpulse', '48'],
#         ['louisville_ky', '48'],
#         ['ping_pong', '48'],
#         ['gulf_coast', '48'],
#         ['xtrememac_tango', '48'],
#         ['parrot_ziks', '47'],
#         ['amd_radeon', '47'],
#         ['wolfson_wm', '47'],
#         ['evga_gtx', '47'],
#         ['carnegie_hall', '47'],
#         ['louis_armstrong', '47'],
#         ['systematic_habit', '47'],
#         ['violin_concerto', '47'],
#         ['oss_product', '47'],
#         ['kimber_kable', '46'],
#         ['allman_brothers', '46'],
#         ['fwd_rev', '46'],
#         ['saudi_arabia', '45'],
#         ['symphonize_glxy', '45'],
#         ['lazy_susan', '45'],
#         ['upstate_ny', '45'],
#         ['athena_ivoice', '45'],
#         ['o_o', '44'],
#         ['knick_knacks', '44'],
#         ['paul_simon', '44'],
#         ['xxx_xxx', '44'],
#         ['unite_arab', '43'],
#         ['sega_dreamcast', '43'],
#         ['sleepless_nights', '43'],
#         ['national_geographic', '43'],
#         ['al_vendedor', '43'],
#         ['etekcity_roverbeats', '42'],
#         ['icom_ic', '42'],
#         ['mow_lawns', '42'],
#         ['wms_ohs_product', '42'],
#         ['todo_bien', '42'],
#         ['jo_pim', '42'],
#         ['goo_gl', '41'],
#         ['mediasonic_hw', '41'],
#         ['soundmatters_foxl', '41'],
#         ['willie_nelson', '41'],
#         ['cyberpower_cpxxxpfclcd', '41'],
#         ['toyota_tacoma', '40'],
#         ['soap_operas', '40'],
#         ['krk_rokit', '40'],
#         ['vw_jetta', '40'],
#         ['santa_fe', '40'],
#         ['entrega_fue', '40'],
#         ['mech_mods', '39'],
#         ['toyota_corolla', '39'],
#         ['jacksonville_fl', '39'],
#         ['soundware_xs', '39'],
#         ['boombot_rex', '39'],
#         ['weed_eater', '39'],
#         ['hsp_hfp', '38'],
#         ['nat_king', '38'],
#         ['http_boldlist', '38'],
#         ['asus_zenbook', '38'],
#         ['grossly_overstate', '38'],
#         ['columbus_ohio', '38'],
#         ['x_', '38'],
#         ['zowie_fk', '37'],
#         ['ess_sabre', '37'],
#         ['nitecore_intellicharger', '37'],
#         ['razer_kraken', '36'],
#         ['nex_ia', '36'],
#         ['roomba_roomba', '36'],
#         ['hifimediy_sabre', '35'],
#         ['emotiva_xda', '35'],
#         ['vpl_hw', '35'],
#         ['constructive_criticism', '34'],
#         ['buenas_condiciones', '34'],
#         ['ifox_creations', '33'],
#         ['providence_ri', '33'],
#         ['mdrxb_ap', '33'],
#         ['symphonize_xtc', '33'],
#         ['braven_lux', '33'],
#         ['wacom_cintiq', '32'],
#         ['firestorm_xl', '32'],
#         ['tennis_court', '31'],
#         ['gusto_mucho', '31'],
#         ['havana_cuba', '31'],
#         ['nba_finals', '31'],
#         ['whoo_hoo', '30'],
#         ['ostry_kc', '30'],
#         ['mpow_freego', '30'],
#         ['kickstarter_backer', '30'],
#         ['vsonic_vsd', '30'],
#         ['pacific_northwest', '30'],
#         ['social_writeup', '30'],
#         ['dji_phantom', '29'],
#         ['xiaomi_pistons', '29'],
#         ['rome_florence', '29'],
#         ['petroleum_jelly', '28'],
#         ['glenn_miller', '28'],
#         ['soundcast_melody', '28'],
#         ['iomega_hipzip', '28'],
#         ['obd_fusion', '27'],
#         ['a_id', '21'],
#         ['cm_cr', '21'],
#         ['pd_cp_e_', '18'],
#         ['pe_', '17'],
#         ['cm_cr_pr_perm', '16'],
#         ['t_t', '15'],
#         ['revision_', '15'],
#         ['ntsc_m', '14'],
#         ['blu_ray', '14'],
#         ['video_ts', '13'],
#         ['jason_', '13'],
#         ['mp_s_a_', '12'],
#         ['service_info', '12'],
#         ['pd_sim_sbs_e_', '11'],
#         ['as_li_ss_tl', '11'],
#         ['pf_rd_m', '11'],
#         ['pf_rd_s', '11'],
#         ['pf_rd_r', '11'],
#         ['pf_rd_t', '11'],
#         ['pf_rd_p', '11'],
#         ['pf_rd_i', '11'],
#         ['xw_nas', '11'],
#         ['en_us', '10'],
#         ['cfb_at_prodpg', '10'],
#         ['cm_cr_dp_title', '10'],
#         ['mitchell_', '10'],
#         ['pro_eb', '10'],
#         ['nb_sb_noss_', '9'],
#         ['pal_b', '9'],
#         ['sr_ph', '9'],
#         ['active_pwr', '9'],
#         ['wp_', '8'],
#         ['nb_sb_noss', '8'],
#         ['pd_bbs_', '8'],
#         ['d_', '7'],
#         ['p_id', '7'],
#         ['pd_sim_', '7'],
#         ['cd_rw', '7'],
#         ['donald_', '7'],
#         ['utm_source', '6'],
#         ['utm_medium', '6'],
#         ['p_', '6'],
#         ['pd_bxgy_e_img_y', '6'],
#         ['s_', '6'],
#         ['amazon_bt', '6'],
#         ['nb_sb_ss_i_', '6'],
#         ['hdmi_mode', '6'],
#         ['cr_p', '6'],
#         ['zombie_x', '6'],
#         ['sammy_k', '6'],
#         ['sh_t', '6'],
#         ['pearl_jam', '6'],
#         ['post_', '5'],
#         ['dp_ob_title_ce', '5'],
#         ['pd_bxgy_', '5'],
#         ['cm_cd_asin_lnk', '5'],
#         ['cm_rdp_product', '5'],
#         ['cm_cr_dp_synop', '5'],
#         ['x_x', '5'],
#         ['page_headphones', '5'],
#         ['not_', '5'],
#         ['a__', '5'],
#         ['foo_upnp', '5'],
#         ['ds_store', '5'],
#         ['pct_amp', '5'],
#         ['d_skins', '5'],
#         ['time_set', '5'],
#         ['cm_cr_pr_sims_t', '4'],
#         ['cm_cr_thx_pdp', '4'],
#         ['headphone_price', '4'],
#         ['average_rating', '4'],
#         ['sound_rating', '4'],
#         ['build_rating', '4'],
#         ['comfort_rating', '4'],
#         ['vid_', '4'],
#         ['gno_cart_title_', '4'],
#         ['g_d', '4'],
#         ['hdmi_group', '4'],
#         ['hdmi_drive', '4'],
#         ['c_id', '4'],
#         ['cp_id', '4'],
#         ['cs_id', '4'],
#         ['s__t', '4'],
#         ['s___', '4'],
#         ['o_', '4'],
#         ['i_pod', '4'],
#         ['low_', '4'],
#         ['med_', '4'],
#         ['product_id', '4'],
#         ['cm_cr_pr_pb_t', '4'],
#         ['price_', '4'],
#         ['hd_dvr', '4'],
#         ['l___', '4'],
#         ['go_to', '4'],
#         ['elechouse_cc', '4'],
#         ['dumas_mc', '4'],
#         ['t_', '4'],
#         ['lh_ni_t', '3'],
#         ['smdk_fat', '3'],
#         ['utm_campaign', '3'],
#         ['file_id', '3'],
#         ['aag_m_pw_dp', '3'],
#         ['ac_sx', '3'],
#         ['airmobi_xxxxxx', '3'],
#         ['cd_r', '3'],
#         ['sabrent_a', '3'],
#         ['pid_', '3'],
#         ['t_v', '3'],
#         ['sr_sp', '3'],
#         ['asset_id', '3'],
#         ['contact_us', '3'],
#         ['a_e', '3'],
#         ['p_m', '3'],
#         ['v_moda', '3'],
#         ['gigacity_amn', '3'],
#         ['plug_and_play', '3'],
#         ['cm_cr_dp_cmt', '3'],
#         ['system_', '3'],
#         ['nstc_m', '3'],
#         ['line_', '3'],
#         ['h_', '3'],
#         ['vcc_mcu', '3'],
#         ['category_id', '3'],
#         ['com_wrapper', '3'],
#         ['cc_', '3'],
#         ['pd_ys_iyr', '3'],
#         ['sort_by', '3'],
#         ['erpzb_vc', '3'],
#         ['e___', '3'],
#         ['n___', '3'],
#         ['period___', '3'],
#         ['pd_bxgy_e_img_b', '3'],
#         ['r_sng', '3'],
#         ['pd_rhf_p_t_', '3'],
#         ['dvd_rw', '3'],
#         ['ml_ipod', '3'],
#         ['cricket_post', '3'],
#         ['proven_choice', '3'],
#         ['a_', '3'],
#         ['happy_sellers', '3'],
#         ['your_dir', '3'],
#         ['ac_sy', '3'],
#         ['ok_sp', '3'],
#         ['psdc_', '3'],
#         ['earth_', '2'],
#         ['cm_cd_asin_link', '2'],
#         ['da__', '2'],
#         ['b_', '2'],
#         ['s____', '2'],
#         ['the_', '2'],
#         ['clip_', '2'],
#         ['model_search', '2'],
#         ['ser_linux_zip', '2'],
#         ['ser_mac_zip', '2'],
#         ['mengo_aquacube', '2'],
#         ['pd_sim_cps_', '2'],
#         ['pd_ybh_', '2'],
#         ['pd_cp_pc_', '2'],
#         ['pd_sxp_f_pt', '2'],
#         ['pd_sim_sg_', '2'],
#         ['rtl_tcp', '2'],
#         ['tv_protector', '2'],
#         ['bxyhwx_uhcc', '2'],
#         ['m____', '2'],
#         ['cm_cr_pr_cmt', '2'],
#         ['digital_modes', '2'],
#         ['mp_', '2'],
#         ['spdif_o', '2'],
#         ['buddy_boy', '2'],
#         ['s_video', '2'],
#         ['lp_', '2'],
#         ['aem_hbdo', '2'],
#         ['img_', '2'],
#         ['wa____k', '2'],
#         ['eq_mode', '2'],
#         ['t__t', '2'],
#         ['rtl_fm', '2'],
#         ['micro_sd', '2'],
#         ['cm_cr_thx_view', '2'],
#         ['atf_title_', '2'],
#         ['n_wn_', '2'],
#         ['twister_b', '2'],
#         ['hdmi_hdmi', '2'],
#         ['template_id', '2'],
#         ['region_id', '2'],
#         ['w_', '2'],
#         ['edit_', '2'],
#         ['dsp_corrections', '2'],
#         ['micca_mb', '2'],
#         ['star_power', '2'],
#         ['a_s', '2'],
#         ['song__', '2'],
#         ['b___', '2'],
#         ['glimp_', '2'],
#         ['rv_cl', '2'],
#         ['sox_eq', '2'],
#         ['hdmi_safe', '2'],
#         ['nu_force', '2'],
#         ['r_', '2'],
#         ['cm_cr_dp_pdp', '2'],
#         ['sdbr_pcdrv_l', '2'],
#         ['cable_', '2'],
#         ['sub_woofer', '2'],
#         ['biddeal_co', '2'],
#         ['u_s_b', '2'],
#         ['etc_', '2'],
#         ['aag_d_sh', '2'],
#         ['phi_log', '2'],
#         ['am_fm', '2'],
#         ['ip_d', '2'],
#         ['ntsc_m_j', '2'],
#         ['update_', '2'],
#         ['product_details', '2'],
#         ['noise_removal', '2'],
#         ['manual_en', '2'],
#         ['pd_cp_hi_', '2'],
#         ['techspec_index', '2'],
#         ['base_sku', '2'],
#         ['brightside_sc', '2'],
#         ['back_up', '2'],
#         ['common_gwzx', '2'],
#         ['foo_out_asio', '2'],
#         ['red_phones', '2'],
#         ['station_id', '2'],
#         ['wl_it_dp_o_pdt', '2'],
#         ['pd_sim_hi_', '2'],
#         ['sh__', '2'],
#         ['pre_out', '2'],
#         ['rev_', '2'],
#         ['ಠ_ಠ', '2'],
#         ['img_xxxx', '2'],
#         ['g_eng_esp', '2'],
#         ['seeyqkz_a', '2'],
#         ['aux_in', '2'],
#         ['high_vhf', '2'],
#         ['builtin_dd', '2'],
#         ['pd_sxp_grid_i_', '2'],
#         ['overscan_left', '2'],
#         ['overscan_right', '2'],
#         ['overscan_top', '2'],
#         ['overscan_bottom', '2'],
#         ['n_n', '2'],
#         ['red_rtn', '2'],
#         ['green_rtn', '2'],
#         ['blue_rtn', '2'],
#         ['cm_sw_su_dp', '2'],
#         ['dpe_', '2'],
#         ['time_', '2'],
#         ['vhs_c', '2'],
#         ['src_vid', '2'],
#         ['annotation_id', '2'],
#         ['annotation_', '2'],
#         ['guy_', '2'],
#         ['xonar_dg', '2'],
#         ['hq_', '2'],
#         ['roger_russell', '2'],
#         ['link_', '2'],
#         ['wl_it_dp_o_pc', '2'],
#         ['bo_e', '2'],
#         ['shopping_help', '2'],
#         ['trs_connector', '2'],
#         ['j_mount', '2'],
#         ['slo_o_o_o_owly', '2'],
#         ['sony_dvd', '2'],
#         ['external_sd', '2'],
#         ['v_o_r', '2'],
#         ['quality_', '2'],
#         ['works_', '2'],
#         ['quality___', '2'],
#         ['words___', '2'],
#         ['j_tech', '2'],
#         ['slightly_', '2'],
#         ['quality__', '2'],
#         ['thoughts__', '2'],
#         ['cameo_artists', '2'],
#         ['dvd_r', '2'],
#         ['gel_caps', '2'],
#         ['advertised_', '2'],
#         ['a___', '2'],
#         ['comma___', '2'],
#         ['ord_cart_shr', '2'],
#         ['to_', '2'],
#         ['vbus_present', '2'],
#         ['audio_ts', '2'],
#         ['fifty_bucks', '2'],
#         ['xy_', '2'],
#         ['trivial_', '2'],
#         ['c_', '2'],
#         ['microsoft_user', '2'],
#         ['packing_inc', '2'],
#         ['pd_bbs_sr_', '2'],
#         ['warehouse_deals', '2'],
#         ['good_', '2'],
#         ['lame_enc', '2'],
#         ['chapter_', '2'],
#         ['enabled_', '2'],
#         ['sa_xr', '2'],
#         ['likely_', '2'],
#         ['onecall_com', '2'],
#         ['cm_aya_asin', '2'],
#         ['rionitrusflash_', '2'],
#         ['max_value', '2'],
#         ['fernando_f', '2'],
#         ['helen_n', '2'],
#         ['lot_', '2'],
#         ['trinity_', '2'],
#         ['title_', '2'],
#         ['e_drums', '2'],
#         ['mb_data', '2'],
#         ['prodfaq_', '2'],
#         ['how_', '2'],
#         ['pinky_powers', '2'],
#         ['aidozybq_', '2'],
#         ['input_', '2'],
#         ['output_', '2'],
#         ['max_mart', '2'],
#         ['p__k', '2'],
#         ['phone_', '1'],
#         ['kjgocyf_i', '1'],
#         ['instructions_', '1'],
#         ['olp_cg_pop', '1'],
#         ['soundmate_', '1'],
#         ['altitude_', '1'],
#         ['pd_sim_sbs_pc_', '1'],
#         ['sti_gl', '1'],
#         ['world_', '1'],
#         ['rene_roman', '1'],
#         ['cat_id', '1'],
#         ['v___', '1'],
#         ['utm_content', '1'],
#         ['m_kwz', '1'],
#         ['non_waterproof', '1'],
#         ['bafghwdh_', '1'],
#         ['w_a_y', '1'],
#         ['s_cked', '1'],
#         ['t___t', '1'],
#         ['p_dp_', '1'],
#         ['promo_key', '1'],
#         ['bi_amp', '1'],
#         ['com_content', '1'],
#         ['jc_sounds', '1'],
#         ['ambiance_', '1'],
#         ['sonnofa_______', '1'],
#         ['manual_frx', '1'],
#         ['fta_express', '1'],
#         ['trrs_standards', '1'],
#         ['over_the_ear', '1'],
#         ['white_thank', '1'],
#         ['woot_deals', '1'],
#         ['conrad_p', '1'],
#         ['e_ysjmv', '1'],
#         ['syl_scr', '1'],
#         ['com_frontpage', '1'],
#         ['dp_spec_v', '1'],
#         ['product_detail', '1'],
#         ['spk_velo', '1'],
#         ['station_finder', '1'],
#         ['rxyxgo_pmvs', '1'],
#         ['interphone_', '1'],
#         ['rate_converter', '1'],
#         ['speexrate_best', '1'],
#         ['zg_bs_', '1'],
#         ['pd_cp_mov_', '1'],
#         ['qmffmuet_o', '1'],
#         ['hl_', '1'],
#         ['mpu_', '1'],
#         ['g_dve', '1'],
#         ['airmobi_fcc', '1'],
#         ['rhkdil_', '1'],
#         ['snaec_ag', '1'],
#         ['br_other_cl', '1'],
#         ['liquidcristal_i', '1'],
#         ['rtl_', '1'],
#         ['specially_', '1'],
#         ['jewel_', '1'],
#         ['product_info', '1'],
#         ['products_id', '1'],
#         ['order___nice', '1'],
#         ['tv_wall_mounts', '1'],
#         ['cm_cd_ql_tlc_al', '1'],
#         ['dpd_sim_sg_', '1'],
#         ['onkyo_usa', '1'],
#         ['tv_dvr', '1'],
#         ['y_tepdy', '1'],
#         ['pd_cp_', '1'],
#         ['clear_', '1'],
#         ['bad_', '1'],
#         ['trtyiuop_', '1'],
#         ['rertyiop_', '1'],
#         ['all_service', '1'],
#         ['sales_pitch', '1'],
#         ['di_c', '1'],
#         ['was_er', '1'],
#         ['slippery_sleeve', '1'],
#         ['adpater_mini', '1'],
#         ['it_', '1'],
#         ['then_', '1'],
#         ['kindle_', '1'],
#         ['better_bought', '1'],
#         ['product_im', '1'],
#         ['btf_title_', '1'],
#         ['hk_aura', '1'],
#         ['h_t_c', '1'],
#         ['bi_wire', '1'],
#         ['pd_cp_k_', '1'],
#         ['mike_tina', '1'],
#         ['in_law', '1'],
#         ['udnxilq_x', '1'],
#         ['flat_', '1'],
#         ['start_up', '1'],
#         ['p__s', '1'],
#         ['molly_dog', '1'],
#         ['sh_', '1'],
#         ['ntt_srch_drd_b', '1'],
#         ['peking_hotels', '1'],
#         ['feat_diplo', '1'],
#         ['repeat_mode', '1'],
#         ['srs_wow', '1'],
#         ['b_repeat', '1'],
#         ['lyrics_sync', '1'],
#         ['delete_file', '1'],
#         ['d_re', '1'],
#         ['ultra_sturdy', '1'],
#         ['says_', '1'],
#         ['fallroman_i', '1'],
#         ['fallroman_ii', '1'],
#         ['d_ita', '1'],
#         ['x__', '1'],
#         ['plus_plus', '1'],
#         ['new_earbudi', '1'],
#         ['xx_psrp', '1'],
#         ['rnskm_', '1'],
#         ['wi_fi', '1'],
#         ['button_cell', '1'],
#         ['rtl_adr', '1'],
#         ['u_hooks', '1'],
#         ['e_son', '1'],
#         ['to_dvi', '1'],
#         ['guesst_t', '1'],
#         ['denon_e', '1'],
#         ['bl_sr_wireless', '1'],
#         ['on_', '1'],
#         ['brand_', '1'],
#         ['wal_', '1'],
#         ['ma__', '1'],
#         ['pin_', '1'],
#         ['kailani_jordan', '1'],
#         ['ciem_review', '1'],
#         ['utm_term', '1'],
#         ['yoga_style', '1'],
#         ['b__t', '1'],
#         ['b_y', '1'],
#         ['mlopez_', '1'],
#         ['mipow_boomax', '1'],
#         ['negative_aa', '1'],
#         ['airmobi_xxxx', '1'],
#         ['mysony_reciever', '1'],
#         ['fix_the_knob', '1'],
#         ['very_good', '1'],
#         ['d_a_b', '1'],
#         ['cons____', '1'],
#         ['z_fgek', '1'],
#         ['bert_', '1'],
#         ['hdmi_control', '1'],
#         ['docsis_system', '1'],
#         ['races_', '1'],
#         ['k_khz', '1'],
#         ['what_______', '1'],
#         ['version_', '1'],
#         ['suc_', '1'],
#         ['voltage_divider', '1'],
#         ['so_', '1'],
#         ['projector_', '1'],
#         ['any_questions', '1'],
#         ['b__', '1'],
#         ['c________d', '1'],
#         ['au_ction', '1'],
#         ['mike_helms', '1'],
#         ['ear_bud', '1'],
#         ['sp_c', '1'],
#         ['it_it', '1'],
#         ['iapp_controlapp', '1'],
#         ['cr_ppy', '1'],
#         ['fine_', '1'],
#         ['pinguy_os_', '1'],
#         ['like_pa', '1'],
#         ['l_cbl', '1'],
#         ['soundtouch_app', '1'],
#         ['m_audio', '1'],
#         ['mdr_', '1'],
#         ['m_series', '1'],
#         ['hdmi_switch', '1'],
#         ['sd_baja', '1'],
#         ['highres_', '1'],
#         ['k_____', '1'],
#         ['lame_ecn', '1'],
#         ['y_', '1'],
#         ['rip_off', '1'],
#         ['re_chargeable', '1'],
#         ['f___ck', '1'],
#         ['sylvie_rdlg', '1'],
#         ['twc_japan', '1'],
#         ['nelson_cartier', '1'],
#         ['n_blqfq', '1'],
#         ['on_for', '1'],
#         ['def_tech', '1'],
#         ['hp_common', '1'],
#         ['pre_amp', '1'],
#         ['mikjcgq_', '1'],
#         ['trsvyxyuo_m', '1'],
#         ['lkdqyx_koem', '1'],
#         ['tii_', '1'],
#         ['android_n', '1'],
#         ['m_rec', '1'],
#         ['de_p_', '1'],
#         ['bfilter_by', '1'],
#         ['reply_', '1'],
#         ['thumb_down', '1'],
#         ['p_qk', '1'],
#         ['jd_', '1'],
#         ['hsb_', '1'],
#         ['diagram_', '1'],
#         ['bs_', '1'],
#         ['adrian_landeira', '1'],
#         ['d_release', '1'],
#         ['zadig_xp_v', '1'],
#         ['zadig_v', '1'],
#         ['fahcore_', '1'],
#         ['eaeaea_', '1'],
#         ['one_battery', '1'],
#         ['aune_t', '1'],
#         ['basement_', '1'],
#         ['doxir_idwaw', '1'],
#         ['boot_delay', '1'],
#         ['bbp_s_iphone', '1'],
#         ['router_na', '1'],
#         ['review____', '1'],
#         ['this__', '1'],
#         ['dp_proddesc_', '1'],
#         ['crawl_', '1'],
#         ['girls_', '1'],
#         ['mini_book', '1'],
#         ['tv_dvd', '1'],
#         ['the_connection', '1'],
#         ['persist_app', '1'],
#         ['rom_v', '1'],
#         ['flypage_sc', '1'],
#         ['non_organic', '1'],
#         ['rm_hla', '1'],
#         ['pd_ys_iyr_img', '1'],
#         ['nema_connector', '1'],
#         ['extension_cord', '1'],
#         ['extension_cords', '1'],
#         ['live_sound', '1'],
#         ['pa_systems', '1'],
#         ['stagepas_', '1'],
#         ['b_buy', '1'],
#         ['sh_ts', '1'],
#         ['ex_bc', '1'],
#         ['e_r', '1'],
#         ['p_ds', '1'],
#         ['speaker_wire', '1'],
#         ['elephants_print', '1'],
#         ['menagerie_print', '1'],
#         ['here___', '1'],
#         ['d__che', '1'],
#         ['buds______', '1'],
#         ['product_', '1'],
#         ['batteries_', '1'],
#         ['cpu_fan', '1'],
#         ['amp_', '1'],
#         ['h_pas', '1'],
#         ['v_', '1'],
#         ['br_lf_m_', '1'],
#         ['sirius_xm', '1'],
#         ['hp_rel_topic', '1'],
#         ['f___ed', '1'],
#         ['eng_', '1'],
#         ['movie_', '1'],
#         ['perfect__', '1'],
#         ['blue_kanga', '1'],
#         ['ak_frost', '1'],
#         ['wsp_message', '1'],
#         ['m_f', '1'],
#         ['foo_input_dts', '1'],
#         ['foo_input_sacd', '1'],
#         ['pd_rhf_se_p_t_', '1'],
#         ['jphhq__rk', '1'],
#         ['radio_usb_si', '1'],
#         ['spdif_out', '1'],
#         ['music_lover', '1'],
#         ['amazing_deal', '1'],
#         ['limestone_lenny', '1'],
#         ['pd_cp_misc_', '1'],
#         ['worked_', '1'],
#         ['moore_', '1'],
#         ['view_question', '1'],
#         ['ypbpr_ansi', '1'],
#         ['headphone_pro', '1'],
#         ['leonard_bise', '1'],
#         ['dlfb_data', '1'],
#         ['fb_defio', '1'],
#         ['set_par', '1'],
#         ['son_kdf', '1'],
#         ['son_replacement', '1'],
#         ['however_', '1'],
#         ['sr_nr_p_', '1'],
#         ['cp_', '1'],
#         ['ha_eb', '1'],
#         ['plwitua_lhzlku', '1'],
#         ['dp_image_', '1'],
#         ['p_ssed', '1'],
#         ['b_o_l_s_e', '1'],
#         ['pd_sbs_sg_', '1'],
#         ['thought_how', '1'],
#         ['e_bikes', '1'],
#         ['kbt__inc', '1'],
#         ['sn_v', '1'],
#         ['chris_himself', '1'],
#         ['su_ks', '1'],
#         ['pdu_', '1'],
#         ['airzone_macaddr', '1'],
#         ['at_', '1'],
#         ['vj_vortex', '1'],
#         ['pr_', '1'],
#         ['pd_cp_vg_', '1'],
#         ['sr_st', '1'],
#         ['pl_', '1'],
#         ['handling_', '1'],
#         ['features_', '1'],
#         ['manual_oarno', '1'],
#         ['usb_sbt', '1'],
#         ['any_better_job', '1'],
#         ['buffer_get_ret', '1'],
#         ['buffer_get_int', '1'],
#         ['tractorbeam_u', '1'],
#         ['scout_outrack', '1'],
#         ['re_order', '1'],
#         ['cd_itrr', '1'],
#         ['shut_off', '1'],
#         ['usrp_interfaces', '1'],
#         ['i____', '1'],
#         ['bl_sr_mp', '1'],
#         ['display_', '1'],
#         ['fox_hd', '1'],
#         ['inch_', '1'],
#         ['gb_c', '1'],
#         ['tablet_w', '1'],
#         ['icf_s', '1'],
#         ['wl_mb_recs_', '1'],
#         ['wosang_pro', '1'],
#         ['play_', '1'],
#         ['pt_ae', '1'],
#         ['cm_cd_et_jump', '1'],
#         ['dec_trd_c', '1'],
#         ['dp_image_z_', '1'],
#         ['the_road', '1'],
#         ['pd_sbs_a_', '1'],
#         ['song_renumber', '1'],
#         ['setup____', '1'],
#         ['blue_ray', '1'],
#         ['tsx_', '1'],
#         ['g_grunfeld', '1'],
#         ['lmr_', '1'],
#         ['rx_v', '1'],
#         ['great_very', '1'],
#         ['cain_ak', '1'],
#         ['number_', '1'],
#         ['l_v', '1'],
#         ['amzl_us', '1'],
#         ['yo_ii_img', '1'],
#         ['happy_', '1'],
#         ['et_pwifud', '1'],
#         ['silly_p', '1'],
#         ['recording_', '1'],
#         ['a____', '1'],
#         ['xonar_u', '1'],
#         ['xonar_dx', '1'],
#         ['yyy_seq', '1'],
#         ['mini_dv', '1'],
#         ['a_c', '1'],
#         ['pd_sxp_grid_pt_', '1'],
#         ['power_supply', '1'],
#         ['charging_source', '1'],
#         ['update____', '1'],
#         ['m_____r', '1'],
#         ['q_q', '1'],
#         ['marcosr_', '1'],
#         ['ir_manual', '1'],
#         ['jay_z', '1'],
#         ['stm_', '1'],
#         ['bk_shark', '1'],
#         ['dvi_d', '1'],
#         ['s______t', '1'],
#         ['just___', '1'],
#         ['v_v', '1'],
#         ['oss_rev', '1'],
#         ['true_depth', '1'],
#         ['v__v', '1'],
#         ['pd_vtp_e_', '1'],
#         ['vol_', '1'],
#         ['chpt_', '1'],
#         ['o_e', '1'],
#         ['in_ear', '1'],
#         ['sw_', '1'],
#         ['mdr_ed', '1'],
#         ['rock_it', '1'],
#         ['hdmi_cable', '1'],
#         ['pp_play', '1'],
#         ['i_phones', '1'],
#         ['ap_', '1'],
#         ['bit_w', '1'],
#         ['yusuf_burke', '1'],
#         ['pd_sbs_hg_', '1'],
#         ['watchespn_com', '1'],
#         ['ez_rc', '1'],
#         ['hd_ma', '1'],
#         ['isolation_____', '1'],
#         ['tracks____', '1'],
#         ['docks_base', '1'],
#         ['pre_paid', '1'],
#         ['dvi_adapter', '1'],
#         ['fault_', '1'],
#         ['shop_online', '1'],
#         ['isolation___', '1'],
#         ['fernando_r', '1'],
#         ['car_dvr', '1'],
#         ['r____o', '1'],
#         ['isolation__', '1'],
#         ['red_', '1'],
#         ['purple__', '1'],
#         ['pci_atsc_hybrid', '1'],
#         ['sb_', '1'],
#         ['dcr_dvd', '1'],
#         ['line_in', '1'],
#         ['wpa_supplicant', '1'],
#         ['tv_power', '1'],
#         ['tv_change', '1'],
#         ['avr_power', '1'],
#         ['avr_change', '1'],
#         ['box_power', '1'],
#         ['voipad_', '1'],
#         ['he__', '1'],
#         ['pa_', '1'],
#         ['shi_', '1'],
#         ['czech_kid', '1'],
#         ['i___', '1'],
#         ['f_', '1'],
#         ['asus_video', '1'],
#         ['follow_up', '1'],
#         ['bronco_', '1'],
#         ['photo_', '1'],
#         ['bit_', '1'],
#         ['size_', '1'],
#         ['shshs___', '1'],
#         ['days_', '1'],
#         ['dx_c', '1'],
#         ['up_directions', '1'],
#         ['tv_only', '1'],
#         ['os_id', '1'],
#         ['lord_ad', '1'],
#         ['g_sensor', '1'],
#         ['tv_', '1'],
#         ['one_m', '1'],
#         ['motherf___', '1'],
#         ['completely_', '1'],
#         ['dennis_aiken', '1'],
#         ['wal___t', '1'],
#         ['in_thy_light', '1'],
#         ['tom_fox', '1'],
#         ['wesv_lp', '1'],
#         ['properly_', '1'],
#         ['notes___', '1'],
#         ['har_har', '1'],
#         ['are_', '1'],
#         ['cd_dvd', '1'],
#         ['ezcap_vista', '1'],
#         ['powerdvd_', '1'],
#         ['s_fbvqvra', '1'],
#         ['he__l', '1'],
#         ['c____guys', '1'],
#         ['alcohol_', '1'],
#         ['fuse_protected', '1'],
#         ['alt_delete', '1'],
#         ['memories_on_tv', '1'],
#         ['j_hilbert', '1'],
#         ['major_league', '1'],
#         ['i_____', '1'],
#         ['pd_bxgy_e_img_c', '1'],
#         ['pd_zg_hrsr_e_', '1'],
#         ['user_interfaces', '1'],
#         ['h_hx_x', '1'],
#         ['pd_rate_rs', '1'],
#         ['gpio_in_pin', '1'],
#         ['gpio_out_pin', '1'],
#         ['best_buy_outlet', '1'],
#         ['dvd_writers', '1'],
#         ['ya_aw_oh_pii', '1'],
#         ['afternoon_', '1'],
#         ['icf_c', '1'],
#         ['whoop_', '1'],
#         ['all_', '1'],
#         ['wt_', '1'],
#         ['canon_power', '1'],
#         ['seconds_', '1'],
#         ['hanni_buzz', '1'],
#         ['wl_it_dp_o', '1'],
#         ['maker_period', '1'],
#         ['flash_drive', '1'],
#         ['microsd_reader', '1'],
#         ['mr_gt_mustang', '1'],
#         ['crackberry_com', '1'],
#         ['denon_avr', '1'],
#         ['a__ed', '1'],
#         ['dm_mu_dp_trk', '1'],
#         ['play_record', '1'],
#         ['front_back', '1'],
#         ['w___', '1'],
#         ['s_air', '1'],
#         ['up____________', '1'],
#         ['product_arrived', '1'],
#         ['if_tg', '1'],
#         ['brite_view', '1'],
#         ['b__se', '1'],
#         ['half_', '1'],
#         ['b__e', '1'],
#         ['as______', '1'],
#         ['oss_t', '1'],
#         ['pros________', '1'],
#         ['cons________', '1'],
#         ['rahul_bhatia', '1'],
#         ['lame_cam', '1'],
#         ['f__', '1'],
#         ['s__k', '1'],
#         ['elechouse_', '1'],
#         ['smart_parts_usa', '1'],
#         ['hd___', '1'],
#         ['ear_buds', '1'],
#         ['i______i', '1'],
#         ['effo_t', '1'],
#         ['daughte_', '1'],
#         ['p_egnant', '1'],
#         ['keyboa_d', '1'],
#         ['seve_al', '1'],
#         ['text__', '1'],
#         ['ima_adpcm', '1'],
#         ['hvdvd_ts', '1'],
#         ['cm_cr_wr_img', '1'],
#         ['rj_tech', '1'],
#         ['easycap_d', '1'],
#         ['bd_re', '1'],
#         ['swapnil_saloni', '1'],
#         ['but__', '1'],
#         ['clap_on', '1'],
#         ['sue_winner', '1'],
#         ['mount_be', '1'],
#         ['ifu_eng', '1'],
#         ['line____', '1'],
#         ['viking_usa', '1'],
#         ['high_', '1'],
#         ['datasheets_pdf', '1'],
#         ['c_amazon', '1'],
#         ['r_dl', '1'],
#         ['f_cking', '1'],
#         ['f_ucking', '1'],
#         ['clips___', '1'],
#         ['nec_optiarc', '1'],
#         ['black_', '1'],
#         ['edocs_public', '1'],
#         ['display_entry', '1'],
#         ['chp_vr', '1'],
#         ['one_sentence', '1'],
#         ['sound_', '1'],
#         ['looks_', '1'],
#         ['dvds_cds', '1'],
#         ['o_stk', '1'],
#         ['artist_name', '1'],
#         ['album_name', '1'],
#         ['av_receiver', '1'],
#         ['yourself_', '1'],
#         ['dvd_vcr', '1'],
#         ['atonline_com', '1'],
#         ['four_hundred', '1'],
#         ['beersheb_books', '1'],
#         ['s__thouse', '1'],
#         ['smv_encode', '1'],
#         ['scotland_ace', '1'],
#         ['mini_sd', '1'],
#         ['awesome_sound', '1'],
#         ['thumbs_up', '1'],
#         ['meaning_don', '1'],
#         ['player_it', '1'],
#         ['s__ks', '1'],
#         ['all__', '1'],
#         ['spoofed_ans', '1'],
#         ['o_oa', '1'],
#         ['jia_george', '1'],
#         ['clueless_', '1'],
#         ['eng_chi', '1'],
#         ['is_audio_player', '1'],
#         ['wma_pro', '1'],
#         ['screen_size', '1'],
#         ['device_size', '1'],
#         ['mdr_ex', '1'],
#         ['hours_', '1'],
#         ['znvm_pcpatch_la', '1'],
#         ['these_', '1'],
#         ['manner_', '1'],
#         ['hd_dvd', '1'],
#         ['dozen_', '1'],
#         ['box_', '1'],
#         ['rating_', '1'],
#         ['f___', '1'],
#         ['den_n', '1'],
#         ['chaper_', '1'],
#         ['db_hp', '1'],
#         ['dp_return_', '1'],
#         ['mad_lynn', '1'],
#         ['dihle_lvsve', '1'],
#         ['plug_in', '1'],
#         ['audio_input', '1'],
#         ['s_cks', '1'],
#         ['my_song', '1'],
#         ['cable_type', '1'],
#         ['b_s_', '1'],
#         ['thing_if', '1'],
#         ['gp_converter', '1'],
#         ['small_', '1'],
#         ['two_hundred', '1'],
#         ['sd_', '1'],
#         ['backwards_', '1'],
#         ['rf_', '1'],
#         ['st_jx', '1'],
#         ['steve_is', '1'],
#         ['sansa_m', '1'],
#         ['da_ned', '1'],
#         ['o_ou', '1'],
#         ['product_name', '1'],
#         ['mdr_v', '1'],
#         ['l__', '1'],
#         ['o__o', '1'],
#         ['fact_', '1'],
#         ['kio_ifp', '1'],
#         ['very_very', '1'],
#         ['j__', '1'],
#         ['p___', '1'],
#         ['i______', '1'],
#         ['pd_ecc_rvi_', '1'],
#         ['in_line', '1'],
#         ['filemanager_', '1'],
#         ['x_update_xxx', '1'],
#         ['installer_', '1'],
#         ['t_money_', '1'],
#         ['counter_strike', '1'],
#         ['wesleys_dad', '1'],
#         ['pd_sbs_e_', '1'],
#         ['jose_ambriz', '1'],
#         ['audible_alex', '1'],
#         ['the_strokes', '1'],
#         ['sor_ree', '1'],
#         ['billy_vandory', '1'],
#         ['lyra_sys', '1'],
#         ['fragile_', '1'],
#         ['cd_da', '1'],
#         ['hi_md', '1'],
#         ['shared_assets', '1'],
#         ['us_en', '1'],
#         ['joe_tomico', '1'],
#         ['iaudio_', '1'],
#         ['iaudio_u', '1'],
#         ['charges_', '1'],
#         ['beware_', '1'],
#         ['gen_pur', '1'],
#         ['sony_wm', '1'],
#         ['archos_devices', '1'],
#         ['comments__this', '1'],
#         ['x___', '1'],
#         ['s_lots_of', '1'],
#         ['i_love_having', '1'],
#         ['list_satish', '1'],
#         ['problem_____the', '1'],
#         ['natalie_wilson_', '1'],
#         ['a_name', '1'],
#         ['b_name', '1'],
#         ['c_name', '1'],
#         ['dvr_a', '1'],
#         ['im_no_angel', '1'],
#         ['my_life', '1'],
#         ['max_fum_eng', '1'],
#         ['max_fur_eng', '1'],
#         ['you_', '1'],
#         ['music_on', '1'],
#         ['commercials_off', '1'],
#         ['question_the', '1'],
#         ['reception_', '1'],
#         ['ranma_', '1'],
#         ['mdr_rf', '1'],
#         ['gadget_guy', '1'],
#         ['orion_', '1'],
#         ['dvd_rom', '1'],
#         ['ws_ftp', '1'],
#         ['neuf_', '1'],
#         ['magick_karma_', '1'],
#         ['rkelly_', '1'],
#         ['david_carlin', '1'],
#         ['cm_wl_huc_item', '1'],
#         ['theater__it', '1'],
#         ['oontz_xl', '1'],
#         ['vh_', '1'],
#         ['pixie_willner', '1'],
#         ['ql_nqs', '1'],
#         ['khv_k', '1'],
#         ['vdr_m', '1'],
#         ['formatter_', '1'],
#         ['dt___', '1'],
#         ['afqjcnghd_s', '1'],
#         ['y_k', '1'],
#         ['aogw_', '1'],
#         ['t_fwkrdbv', '1'],
#         ['u_', '1'],
#         ['bn_guide', '1'],
#         ['whatever_', '1'],
#         ['superlux_hd', '1'],
#         ['bzuukp_pbfk', '1'],
#         ['multi_voltage', '1'],
#         ['x_boom', '1'],
#         ['e_yl', '1'],
#         ['dream_', '1'],
#         ['sigh_', '1'],
#         ['weekend_', '1'],
#         ['roar_', '1'],
#         ['trails_', '1'],
#         ['bc_rsatb', '1'],
#         ['rc_keymaps', '1'],
#         ['rcfn_jdzuka', '1'],
#         ['most_powerful', '1'],
#         ['ti____', '1'],
#         ['bcb_', '1'],
#         ['jof_n', '1'],
#         ['sa_', '1'],
#         ['scr_wed', '1'],
#         ['cwhog_nlr', '1'],
#         ['product__i', '1'],
#         ['paosanhueza_', '1'],
#         ['d_skin', '1'],
#         ['my_vsonic_gr', '1'],
#         ['m_rsemrok', '1'],
#         ['h_ll', '1'],
#         ['p___ks', '1'],
#         ['lvxaohg_', '1'],
#         ['cm_sw_r_awd_rgt', '1'],
#         ['p_leftorright', '1'],
#         ['cm_sw_r_tw_acp', '1'],
#         ['accessories_tab', '1'],
#         ['indv_k', '1'],
#         ['lmhl__w', '1'],
#         ['h_ww', '1'],
#         ['bgg_p', '1'],
#         ['u_cja', '1'],
#         ['dst_g', '1'],
#         ['t_t_t_t_t_that', '1'],
#         ['again_____more', '1'],
#         ['memorex___drive', '1'],
#         ['power_sentry', '1'],
#         ['whole_', '1'],
#         ['i_manual', '1'],
#         ['lfqv_uya', '1'],
#         ['hd_sdi', '1'],
#         ['content_', '1'],
#         ['u_u', '1'],
#         ['music__', '1'],
#         ['nc_ztjkw', '1'],
#         ['kb_columns', '1'],
#         ['download_start', '1'],
#         ['vendor_info', '1'],
#         ['mmc_bdr', '1'],
#         ['layer_jump', '1'],
#         ['cm_sw_r_awd_rrw', '1'],
#         ['sr_ph_', '1'],
#         ['a_b', '1'],
#         ['call_______', '1'],
#         ['sr_nr_n_', '1'],
#         ['search_query', '1'],
#         ['pd_cp_p_', '1'],
#         ['dgmbrc_', '1'],
#         ['x_xywksbeiqa', '1'],
#         ['h_d_t_v', '1'],
#         ['srf_m', '1'],
#         ['component_video', '1'],
#         ['composite_video', '1'],
#         ['rd_generation', '1'],
#         ['qsg_s', '1'],
#         ['danger_efest_', '1'],
#         ['amp_and', '1'],
#         ['xycsuep_j', '1'],
#         ['stcroix_man', '1'],
#         ['soundmate_xxx', '1'],
#         ['jason_m', '1'],
#         ['hwcxjwz_lk', '1'],
#         ['bi_amp_able', '1'],
#         ['home_en', '1'],
#         ['h_d', '1'],
#         ['media_universe', '1'],
#         ['veriz_n', '1'],
#         ['pd_sim_pc_', '1'],
#         ['micros__t', '1'],
#         ['ignore_db', '1'],
#         ['b_at', '1'],
#         ['b_x', '1'],
#         ['b__s_', '1'],
#         ['c_ddvds', '1'],
#         ['abt_bm', '1'],
#         ['link_faqs', '1'],
#         ['흫_흫', '1'],
#         ['cm_cd_naredir', '1'],
#         ['slight_', '1'],
#         ['hdmi_which_one', '1'],
#         ['science_', '1'],
#         ['str_de', '1'],
#         ['ekhsibm_', '1'],
#         ['dvd_', '1'],
#         ['sc_', '1'],
#         ['topic_id', '1'],
#         ['as_sl_pc_ss_til', '1'],
#         ['znrg_mejhx', '1'],
#         ['th_quarter_', '1'],
#         ['bebzrig_pws', '1'],
#         ['veb_esgiekg', '1'],
#         ['u_infqiu', '1'],
#         ['muti_point', '1'],
#         ['cd_quality', '1'],
#         ['fbcpudu_qgy', '1'],
#         ['h_uc', '1'],
#         ['hx_p', '1'],
#         ['ehthfbmya_g', '1'],
#         ['q_', '1'],
#         ['package_', '1'],
#         ['main_sr', '1'],
#         ['boco_fw_wcb', '1'],
#         ['dot_clean', '1'],
#         ['up_great', '1'],
#         ['w_price', '1'],
#         ['wing_nuts', '1'],
#         ['nknbekc_e', '1'],
#         ['hdmi_', '1'],
#         ['david_underland', '1'],
#         ['speaker_', '1'],
#         ['soundlink_on', '1'],
#         ['htr_', '1'],
#         ['bee_dac', '1'],
#         ['resource_tools', '1'],
#         ['e_q', '1'],
#         ['m_vc', '1'],
#         ['um_', '1'],
#         ['a_rcr', '1'],
#         ['um_rcr', '1'],
#         ['pd_rhf_cr_s_cp_', '1'],
#         ['bluetooth_win', '1'],
#         ['ct_bw', '1'],
#         ['context_', '1'],
#         ['c____', '1']], dtype='<U24'))

# %%
# # perform another 11 epochs of training
# t = time()
# w2v.train(processed_corpus, epochs=12, total_examples=w2v_gensim.corpus_count)
# w2v.save('saved_data_models/D11E_w2v_gensim13_nostem.model')
# print( time()-t,'s')
